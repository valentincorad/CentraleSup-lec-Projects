# %% [markdown]
# Commentaire final après soutenance :
#
# - Durer plus longtemps --> plus de diapos
# - j'aurais pu étudier la corrélation entre les indicateurs (comme dans le projet COVID)
# - Mettre une conclusion dans l'introduction du projet (comme dans une thèse)
# - Retirer et repérer doublon : nunique() / duplicate()
# - ne pas confondre commentaires pour expliquer le code et commentaire pour expliquer le déroulement du notebook
# - retirer les doublons sur ce dataset n'était pas nécessaire car ces données car World Bank
# - sélecter les indicateurs pertinents en regardant leurs taux de remplissage respectifs
# - revoir le fonctionnement de l'interpolation linéaire
# - "étant donné que je suis en parcours financé je dois FOCUS sur l'essentiel pour aller plus vite !"

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Projet-2-:-Analysez-des-données-de-systèmes-éducatifs" data-toc-modified-id="Projet-2-:-Analysez-des-données-de-systèmes-éducatifs-1">Projet 2 : Analysez des données de systèmes éducatifs</a></span><ul class="toc-item"><li><span><a href="#Contexte" data-toc-modified-id="Contexte-1.1">Contexte</a></span></li><li><span><a href="#Questions" data-toc-modified-id="Questions-1.2">Questions</a></span></li><li><span><a href="#Tâches" data-toc-modified-id="Tâches-1.3">Tâches</a></span></li><li><span><a href="#Importation-des-librairies" data-toc-modified-id="Importation-des-librairies-1.4">Importation des librairies</a></span></li></ul></li><li><span><a href="#1.-Description-des-données" data-toc-modified-id="1.-Description-des-données-2">1. Description des données</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.1-Dataframe-EdStatsData" data-toc-modified-id="1.1-Dataframe-EdStatsData-2.0.1">1.1 Dataframe EdStatsData</a></span></li><li><span><a href="#1.2-Dataframe-EdStatsCountry" data-toc-modified-id="1.2-Dataframe-EdStatsCountry-2.0.2">1.2 Dataframe EdStatsCountry</a></span></li></ul></li></ul></li><li><span><a href="#2.-Nettoyage-de-EdStatsData" data-toc-modified-id="2.-Nettoyage-de-EdStatsData-3">2. Nettoyage de EdStatsData</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#2.1-Retrait-des-colonnes-non-pertinentes" data-toc-modified-id="2.1-Retrait-des-colonnes-non-pertinentes-3.0.1">2.1 Retrait des colonnes non pertinentes</a></span></li><li><span><a href="#2.2-Selection-des-indicateurs-pertinents" data-toc-modified-id="2.2-Selection-des-indicateurs-pertinents-3.0.2">2.2 Selection des indicateurs pertinents</a></span></li><li><span><a href="#2.3-Focus-sur-les-valeurs-manquantes" data-toc-modified-id="2.3-Focus-sur-les-valeurs-manquantes-3.0.3">2.3 Focus sur les valeurs manquantes</a></span></li></ul></li></ul></li><li><span><a href="#3.-Analyse-des-indicateurs" data-toc-modified-id="3.-Analyse-des-indicateurs-4">3. Analyse des indicateurs</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#3.1-Méthodologie" data-toc-modified-id="3.1-Méthodologie-4.0.1">3.1 Méthodologie</a></span></li><li><span><a href="#3.2-Indicateur-économique-:-Produit-Intérieur-Brut" data-toc-modified-id="3.2-Indicateur-économique-:-Produit-Intérieur-Brut-4.0.2">3.2 Indicateur économique : Produit Intérieur Brut</a></span></li><li><span><a href="#3.3-Indicateur-technologique-:-Accès-à-internet" data-toc-modified-id="3.3-Indicateur-technologique-:-Accès-à-internet-4.0.3">3.3 Indicateur technologique : Accès à internet</a></span></li><li><span><a href="#3.4-Indicateur-démographique-:-Population-totale" data-toc-modified-id="3.4-Indicateur-démographique-:-Population-totale-4.0.4">3.4 Indicateur démographique : Population totale</a></span></li><li><span><a href="#3.5-Indicateur-démographique-:-Population-en-âge-pour-l'éducation-secondaire-supérieure" data-toc-modified-id="3.5-Indicateur-démographique-:-Population-en-âge-pour-l'éducation-secondaire-supérieure-4.0.5">3.5 Indicateur démographique : Population en âge pour l'éducation secondaire supérieure</a></span></li></ul></li></ul></li><li><span><a href="#4.-Création-d'un-indicateur-économique" data-toc-modified-id="4.-Création-d'un-indicateur-économique-5">4. Création d'un indicateur économique</a></span></li><li><span><a href="#5.-Conclusion" data-toc-modified-id="5.-Conclusion-6">5. Conclusion</a></span></li><li><span><a href="#6.-Ouverture" data-toc-modified-id="6.-Ouverture-7">6. Ouverture</a></span></li></ul></div>

# %% [markdown]
# # Projet 1 : Analysez des données de systèmes éducatifs

# %% [markdown]
# ## Contexte
#
# - public de niveau lycée et université
# - projet d’expansion à l’international de l’entreprise
#
# ## Questions
#
# - Quels sont les pays avec un fort potentiel de clients pour nos services ?
# - Pour chacun de ces pays, quelle sera l’évolution de ce potentiel de clients ?
# - Dans quels pays l'entreprise doit-elle opérer en priorité ?
#
# ## Tâches
#
# - Valider la qualité de ce jeu de données (comporte-t-il beaucoup de données manquantes, dupliquées ?)
# - Décrire les informations contenues dans le jeu de données (nombre de colonnes ? nombre de lignes ?)
# - Sélectionner les informations qui semblent pertinentes pour répondre à la problématique (quelles sont les colonnes contenant des informations qui peuvent être utiles pour répondre à la problématique de l’entreprise ?)
# - Déterminer des ordres de grandeurs des indicateurs statistiques classiques pour les différentes zones géographiques et pays du monde (moyenne/médiane/écart-type par pays et par continent ou bloc géographique)

# %% [markdown]
# ## Importation des librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import pprint
from sklearn.impute import SimpleImputer
import geopandas as gpd

# %%
# Modification de l'affichage
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Description des données

# %% [markdown]
# Cette partie consiste en la description des données :
# - nature des datasets,
# - nature des variables de chaque colonne
# - structure des datasets
#
# Par soucis de clarté seules les datasets intitulés "EdStatsData" et "EdStatsCountry" ont été analysés. En effet les  trois autres n'apportaient pas d'informations significatives pour traiter le sujet.

# %% [markdown]
# ### 1.1 Dataframe EdStatsData

# %%
# Lecture du dataframe
df_data = pd.read_csv(r"C:\Users\valen\Desktop\Formation Data Scientist\P2\Data\EdStatsData.csv")

# %%
# Affichage des 5 premières lignes du dataset
df_data.head(5)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975       1976  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 4  54.822121  54.894138  56.209438  57.267109  57.991138  59.36554  60.999962
#
#        1977      1978       1979       1980       1981       1982       1983  \
# 0       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 1       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 2       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 3       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 4  61.92268  62.69342  64.383186  65.617767  66.085152  66.608139  67.290451
#
#         1984       1985       1986      1987       1988       1989       1990  \
# 0        NaN        NaN        NaN       NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN       NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN       NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN       NaN        NaN        NaN        NaN
# 4  68.510094  69.033211  69.944908  71.04187  71.693779  71.699097  71.995819
#
#         1991       1992       1993       1994      1995       1996       1997  \
# 0        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 4  72.602837  70.032722  70.464821  72.645683  71.81176  73.903511  74.425201
#
#         1998       1999       2000       2001       2002       2003  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4  75.110817  76.254318  77.245682  78.800522  80.051399  80.805389
#
#         2004       2005       2006       2007       2008       2009  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4  81.607063  82.489487  82.685509  83.280342  84.011871  84.195961
#
#         2010      2011       2012      2013       2014  2015  2016  2017  \
# 0        NaN       NaN        NaN       NaN        NaN   NaN   NaN   NaN
# 1        NaN       NaN        NaN       NaN        NaN   NaN   NaN   NaN
# 2        NaN       NaN        NaN       NaN        NaN   NaN   NaN   NaN
# 3        NaN       NaN        NaN       NaN        NaN   NaN   NaN   NaN
# 4  85.211998  85.24514  86.101669  85.51194  85.320152   NaN   NaN   NaN
#
#    2020  2025  2030  2035  2040  2045  2050  2055  2060  2065  2070  2075  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2080  2085  2090  2095  2100  Unnamed: 69
# 0   NaN   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN   NaN   NaN          NaN

# %%
# Affichage des informations sur la nature des données du dataset
print(df_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
#  16  1982            37511 non-null   float64
#  17  1983            38460 non-null   float64
#  18  1984            38606 non-null   float64
#  19  1985            90296 non-null   float64
#  20  1986            39372 non-null   float64
#  21  1987            38641 non-null   float64
#  22  1988            38552 non-null   float64
#  23  1989            37540 non-null   float64
#  24  1990            124405 non-null  float64
#  25  1991            74437 non-null   float64
#  26  1992            75543 non-null   float64
#  27  1993            75793 non-null   float64
#  28  1994            77462 non-null   float64
#  29  1995            131361 non-null  float64
#  30  1996            76807 non-null   float64
#  31  1997            73453 non-null   float64
#  32  1998            84914 non-null   float64
#  33  1999            118839 non-null  float64
#  34  2000            176676 non-null  float64
#  35  2001            123509 non-null  float64
#  36  2002            124205 non-null  float64
#  37  2003            130363 non-null  float64
#  38  2004            128814 non-null  float64
#  39  2005            184108 non-null  float64
#  40  2006            140312 non-null  float64
#  41  2007            137272 non-null  float64
#  42  2008            134387 non-null  float64
#  43  2009            142108 non-null  float64
#  44  2010            242442 non-null  float64
#  45  2011            146012 non-null  float64
#  46  2012            147264 non-null  float64
#  47  2013            137509 non-null  float64
#  48  2014            113789 non-null  float64
#  49  2015            131058 non-null  float64
#  50  2016            16460 non-null   float64
#  51  2017            143 non-null     float64
#  52  2020            51436 non-null   float64
#  53  2025            51436 non-null   float64
#  54  2030            51436 non-null   float64
#  55  2035            51436 non-null   float64
#  56  2040            51436 non-null   float64
#  57  2045            51436 non-null   float64
#  58  2050            51436 non-null   float64
#  59  2055            51436 non-null   float64
#  60  2060            51436 non-null   float64
#  61  2065            51436 non-null   float64
#  62  2070            51436 non-null   float64
#  63  2075            51436 non-null   float64
#  64  2080            51436 non-null   float64
#  65  2085            51436 non-null   float64
#  66  2090            51436 non-null   float64
#  67  2095            51436 non-null   float64
#  68  2100            51436 non-null   float64
#  69  Unnamed: 69     0 non-null       float64
# dtypes: float64(66), object(4)
# memory usage: 473.7+ MB
# None

# %%
print("Le dataset contient {} lignes et {} colonnes.".format(df_data.shape[0], df_data.shape[1]))
# Out:
# Le dataset contient 886930 lignes et 70 colonnes.

# %%
# Nombre de valeurs uniques
print(df_data['Country Name'].nunique())
print(df_data['Country Code'].nunique())
print(df_data['Indicator Name'].nunique())
print(df_data['Indicator Code'].nunique())
# Out:
# 242
# 242
# 3665
# 3665

# %% [markdown]
# df_data contient 242 pays et 3665 indicateurs uniques pour lesquelles sont associés des codes

# %%
# Distribution 'Indicator Name'
sns.distplot(df_data['Indicator Name'].value_counts())
# Out:
# C:\Users\valen\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Distribution 'Country Name'
sns.distplot(df_data['Country Name'].value_counts())
# Out:
# C:\Users\valen\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Donc il y a 3665 indicateurs mesurées chacun pour les 242 pays/zones géographiques. La longueur du dataframe initial correspond au produit du nombre d'indicateur pas le nombre de pays (886930 = 3665 * 242)
#
# Le dataframe correspond à des mesures d'indicateurs par pays pour différentes années.

# %%
# Heatmap des données manquantes sur df_data

df_data.isna() 
plt.figure(figsize=(20,10))
plt.title('Répartition des valeurs manquantes')
sns.heatmap(df_data.isna(), cbar=False)

# %% [markdown]
# Le graphique ci-dessus représente les zones il y a des données manquantes (NaN), ici en beige.
#
# On constate déjà qu'il y a peu d'indicateurs pour les pays correspondant aux premières lignes ; et de même pour les périodes après 2015.

# %%
# Proportion de valeurs nulles
prop_nan_df_data=df_data.isna().sum().sum()/(df_data.shape[0]*df_data.shape[1])*100
print('Il y a {:.2f}% de NaN.'.format(prop_nan_df_data))
# Out:
# Il y a 86.10% de NaN.

# %% [markdown]
# ### 1.2 Dataframe EdStatsCountry

# %%
# Lecture du dataframe
df_country = pd.read_csv(r"C:\Users\valen\Desktop\Formation Data Scientist\P2\Data\EdStatsCountry.csv")

# %%
# Affichage des 5 premières lignes du dataset
df_country.head(3)
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
#
#                       Region          Income Group WB-2 code  \
# 0  Latin America & Caribbean  High income: nonOECD        AW
# 1                 South Asia            Low income        AF
# 2         Sub-Saharan Africa   Upper middle income        AO
#
#   National accounts base year  National accounts reference year  \
# 0                        2000                               NaN
# 1                     2002/03                               NaN
# 2                        2002                               NaN
#
#                     SNA price valuation Lending category Other groups  \
# 0     Value added at basic prices (VAB)              NaN          NaN
# 1     Value added at basic prices (VAB)              IDA         HIPC
# 2  Value added at producer prices (VAP)             IBRD          NaN
#
#                          System of National Accounts  \
# 0  Country uses the 1993 System of National Accou...
# 1  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
#
#   Alternative conversion factor PPP survey year  \
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                       1991–96            2005
#
#               Balance of Payments Manual in use  \
# 0  IMF Balance of Payments Manual, 6th edition.
# 1                                           NaN
# 2  IMF Balance of Payments Manual, 6th edition.
#
#   External debt Reporting status       System of trade  \
# 0                            NaN  Special trade system
# 1                         Actual  General trade system
# 2                         Actual  Special trade system
#
#      Government Accounting concept           IMF data dissemination standard  \
# 0                              NaN                                       NaN
# 1  Consolidated central government  General Data Dissemination System (GDDS)
# 2     Budgetary central government  General Data Dissemination System (GDDS)
#
#   Latest population census                            Latest household survey  \
# 0                     2010                                                NaN
# 1                     1979  Multiple Indicator Cluster Survey (MICS), 2010/11
# 2                     1970               Malaria Indicator Survey (MIS), 2011
#
#   Source of most recent Income and expenditure data  \
# 0                                               NaN
# 1           Integrated household survey (IHS), 2008
# 2           Integrated household survey (IHS), 2008
#
#   Vital registration complete Latest agricultural census  \
# 0                         Yes                        NaN
# 1                         NaN                    2013/14
# 2                         NaN                       2015
#
#    Latest industrial data  Latest trade data Latest water withdrawal data  \
# 0                     NaN             2012.0                          NaN
# 1                     NaN             2012.0                         2000
# 2                     NaN                NaN                         2005
#
#    Unnamed: 31
# 0          NaN
# 1          NaN
# 2          NaN

# %%
# Affichage des informations sur la nature des données du dataset
print(df_country.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country Code                                       241 non-null    object
#  1   Short Name                                         241 non-null    object
#  2   Table Name                                         241 non-null    object
#  3   Long Name                                          241 non-null    object
#  4   2-alpha code                                       238 non-null    object
#  5   Currency Unit                                      215 non-null    object
#  6   Special Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
#  8   Income Group                                       214 non-null    object
#  9   WB-2 code                                          240 non-null    object
#  10  National accounts base year                        205 non-null    object
#  11  National accounts reference year                   32 non-null     float64
#  12  SNA price valuation                                197 non-null    object
#  13  Lending category                                   144 non-null    object
#  14  Other groups                                       58 non-null     object
#  15  System of National Accounts                        215 non-null    object
#  16  Alternative conversion factor                      47 non-null     object
#  17  PPP survey year                                    145 non-null    object
#  18  Balance of Payments Manual in use                  181 non-null    object
#  19  External debt Reporting status                     124 non-null    object
#  20  System of trade                                    200 non-null    object
#  21  Government Accounting concept                      161 non-null    object
#  22  IMF data dissemination standard                    181 non-null    object
#  23  Latest population census                           213 non-null    object
#  24  Latest household survey                            141 non-null    object
#  25  Source of most recent Income and expenditure data  160 non-null    object
#  26  Vital registration complete                        111 non-null    object
#  27  Latest agricultural census                         142 non-null    object
#  28  Latest industrial data                             107 non-null    float64
#  29  Latest trade data                                  185 non-null    float64
#  30  Latest water withdrawal data                       179 non-null    object
#  31  Unnamed: 31                                        0 non-null      float64
# dtypes: float64(4), object(28)
# memory usage: 60.4+ KB
# None

# %%
print("Le dataset contient {} lignes et {} colonnes.".format(df_country.shape[0], df_country.shape[1]))
# Out:
# Le dataset contient 241 lignes et 32 colonnes.

# %%
# Nombre de valeurs uniques de 'Country Code'
print(df_country['Country Code'].nunique())
# Out:
# 241

# %%
# Distribution 'Country Code'
sns.distplot(df_country['Country Code'].value_counts())
# Out:
# C:\Users\valen\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# La variable 'Country Code' présente 242 unique pays/régions géographiques.

# %%
# Heatmap des données manquantes sur df_country
df_country.isna() 
plt.figure(figsize=(20,10))
sns.heatmap(df_country.isna(), cbar=False)

# %% [markdown]
# df_country correspond à des indicateurs géographiques et économiques de chaque pays.
# Il y a peu de valeurs manquantes dans df2.

# %%
# Proportion de valeurs nulles
prop_nan_df_country = df_country.isna().sum().sum()/(df_country.shape[0]*df_country.shape[1])*100
print('Il y a {:.2f}% de NaN.'.format(prop_nan_df_country))
# Out:
# Il y a 30.52% de NaN.

# %% [markdown]
# # 2. Nettoyage de EdStatsData

# %% [markdown]
# Cette partie a consisté a retirer les éventuels outliers, valeurs manquantes et remplacer ces dernières si nécessaire.

# %% [markdown]
# ### 2.1 Retrait des colonnes non pertinentes

# %%
# Supression de la dernière colonne
df_data.drop(columns='Unnamed: 69', inplace=True)

# Retrait des colonnes correspond aux années hors 1999-2015
df_data.drop(df_data.loc[:, '1970':'1998'], axis=1, inplace=True)
df_data.drop(df_data.loc[:, '2016':'2100'], axis=1, inplace=True)

# %%
# Visualisation des valeurs non nulles
msno.bar(df_data)

# %% [markdown]
# Malgré la suppression des périodes de temps non étudiées beaucoup de NaN sont toujours présentes, à un taux de plus de 80% entre 1999 et 2015.

# %% [markdown]
# ### 2.2 Selection des indicateurs pertinents

# %% [markdown]
# Dans cette partie est crée :
# - la liste des pays
# - la liste des continents
# - la liste des indicateurs pertinents.

# %%
# Affichage de tous les indicateurs uniques
liste_indicateurs = list(df_data['Indicator Name'].unique())
# pprint.pprint(liste_indicateurs)

# %%
# Sélection manuelle des indicateurs pertinents au regard du contexte

indicateurs_pertinents = [
    'Government expenditure on education as % of GDP (%)',
    'GDP per capita (current US$)',
    'Personal computers (per 100 people)',
    'Internet users (per 100 people)',
    'Population, total',
    'Population of the official age for upper secondary education, both sexes ''(number)'
]

# %%
# Nombre d'indicateurs pertinents
print("Nombre d\'indicateurs pertinents: {}".format(len(indicateurs_pertinents)))
# Out:
# Nombre d'indicateurs pertinents: 6

# %%
# Affichage de toutes les régions uniques
liste_regions = list(df_country['Region'].unique())
pprint.pprint(liste_regions)
# Out:
# ['Latin America & Caribbean',
#  'South Asia',
#  'Sub-Saharan Africa',
#  'Europe & Central Asia',
#  nan,
#  'Middle East & North Africa',
#  'East Asia & Pacific',
#  'North America']

# %% [markdown]
# Un Nan a été pris en compte dans la liste ci-dessus. Par la suite celle-ci a été retirée.

# %%
# Sélection manuelle des continents
liste_continents = ['Latin America & Caribbean',
                    'South Asia',
                    'Sub-Saharan Africa',
                    'Europe & Central Asia',
                    'Middle East & North Africa',
                    'East Asia & Pacific',
                    'North America']

# %%
# Affichage de tous les pays uniques
liste_pays=list(df_data['Country Name'].unique())
# pprint.pprint(liste_pays)

# %%
# Sélection manuelle de tous les pays uniques
liste_pays=[
 'Afghanistan',
 'Albania',
 'Algeria',
 'American Samoa',
 'Andorra',
 'Angola',
 'Antigua and Barbuda',
 'Argentina',
 'Armenia',
 'Aruba',
 'Australia',
 'Austria',
 'Azerbaijan',
 'Bahamas, The',
 'Bahrain',
 'Bangladesh',
 'Barbados',
 'Belarus',
 'Belgium',
 'Belize',
 'Benin',
 'Bermuda',
 'Bhutan',
 'Bolivia',
 'Bosnia and Herzegovina',
 'Botswana',
 'Brazil',
 'British Virgin Islands',
 'Brunei Darussalam',
 'Bulgaria',
 'Burkina Faso',
 'Burundi',
 'Cabo Verde',
 'Cambodia',
 'Cameroon',
 'Canada',
 'Cayman Islands',
 'Central African Republic',
 'Chad',
 'Channel Islands',
 'Chile',
 'China',
 'Colombia',
 'Comoros',
 'Congo, Dem. Rep.',
 'Congo, Rep.',
 'Costa Rica',
 "Cote d'Ivoire",
 'Croatia',
 'Cuba',
 'Curacao',
 'Cyprus',
 'Czech Republic',
 'Denmark',
 'Djibouti',
 'Dominica',
 'Dominican Republic',
 'Ecuador',
 'Egypt, Arab Rep.',
 'El Salvador',
 'Equatorial Guinea',
 'Eritrea',
 'Estonia',
 'Ethiopia',
 'Faroe Islands',
 'Fiji',
 'Finland',
 'France',
 'French Polynesia',
 'Gabon',
 'Gambia, The',
 'Georgia',
 'Germany',
 'Ghana',
 'Gibraltar',
 'Greece',
 'Greenland',
 'Grenada',
 'Guam',
 'Guatemala',
 'Guinea',
 'Guinea-Bissau',
 'Guyana',
 'Haiti',
 'Honduras',
 'Hong Kong SAR, China',
 'Hungary',
 'Iceland',
 'India',
 'Indonesia',
 'Iran, Islamic Rep.',
 'Iraq',
 'Ireland',
 'Isle of Man',
 'Israel',
 'Italy',
 'Jamaica',
 'Japan',
 'Jordan',
 'Kazakhstan',
 'Kenya',
 'Kiribati',
 'Korea, Dem. People’s Rep.',
 'Korea, Rep.',
 'Kosovo',
 'Kuwait',
 'Kyrgyz Republic',
 'Lao PDR',
 'Latvia',
 'Lebanon',
 'Lesotho',
 'Liberia',
 'Libya',
 'Liechtenstein',
 'Lithuania',
 'Luxembourg',
 'Macao SAR, China',
 'Macedonia, FYR',
 'Madagascar',
 'Malawi',
 'Malaysia',
 'Maldives',
 'Mali',
 'Malta',
 'Marshall Islands',
 'Mauritania',
 'Mauritius',
 'Mexico',
 'Micronesia, Fed. Sts.',
 'Moldova',
 'Monaco',
 'Mongolia',
 'Montenegro',
 'Morocco',
 'Mozambique',
 'Myanmar',
 'Namibia',
 'Nauru',
 'Nepal',
 'Netherlands',
 'New Caledonia',
 'New Zealand',
 'Nicaragua',
 'Niger',
 'Nigeria',
 'Northern Mariana Islands',
 'Norway',
 'Oman',
 'Pakistan',
 'Palau',
 'Panama',
 'Papua New Guinea',
 'Paraguay',
 'Peru',
 'Philippines',
 'Poland',
 'Portugal',
 'Puerto Rico',
 'Qatar',
 'Romania',
 'Russian Federation',
 'Rwanda',
 'Samoa',
 'San Marino',
 'Sao Tome and Principe',
 'Saudi Arabia',
 'Senegal',
 'Serbia',
 'Seychelles',
 'Sierra Leone',
 'Singapore',
 'Sint Maarten (Dutch part)',
 'Slovak Republic',
 'Slovenia',
 'Solomon Islands',
 'Somalia',
 'South Africa',
 'South Sudan',
 'Spain',
 'Sri Lanka',
 'St. Kitts and Nevis',
 'St. Lucia',
 'St. Martin (French part)',
 'St. Vincent and the Grenadines',
 'Sudan',
 'Suriname',
 'Swaziland',
 'Sweden',
 'Switzerland',
 'Syrian Arab Republic',
 'Tajikistan',
 'Tanzania',
 'Thailand',
 'Timor-Leste',
 'Togo',
 'Tonga',
 'Trinidad and Tobago',
 'Tunisia',
 'Turkey',
 'Turkmenistan',
 'Turks and Caicos Islands',
 'Tuvalu',
 'Uganda',
 'Ukraine',
 'United Arab Emirates',
 'United Kingdom',
 'United States',
 'Uruguay',
 'Uzbekistan',
 'Vanuatu',
 'Venezuela, RB',
 'Vietnam',
 'Virgin Islands (U.S.)',
 'West Bank and Gaza',
 'Yemen, Rep.',
 'Zambia',
 'Zimbabwe'
 ]

# %% [markdown]
# ### 2.3 Focus sur les valeurs manquantes

# %% [markdown]
# Dans cette partie, le dataframe EdStatsData est filtré pour ne projeter que les lignes contenants les indicateurs précèdemment sélectionnés. Dans un second temps un travail est fait sur les valeurs manquantes.

# %%
# Retrait des lignes où ne sont pas présents les indicateurs sélectionnés
df_ind = df_data[df_data['Indicator Name'].isin(indicateurs_pertinents)]

# %%
# Taux de remplissage du dataframe par indicateur
df_ind_taux_remplissage = pd.concat([df_ind.loc[:,'1999':'2015'], df_ind.loc[:,'Indicator Name']], axis=1)
df_ind_taux_remplissage.set_index('Indicator Name', inplace= True)
df_ind_taux_remplissage = df_ind_taux_remplissage.notnull()

# Visualisation du remplissage 
groupes_ind = df_ind_taux_remplissage.groupby('Indicator Name').mean()
fig = plt.figure(figsize=(20,4))
sns.heatmap(groupes_ind, square=True, linewidths=0.1, annot=True, ax=None)
plt.title("Proportion de données renseignées par année et indicateurs \n", fontsize=12)
plt.ylabel('Indicateurs', fontsize=12)
plt.show()

# %% [markdown]
# Eu égard du graphique ci-dessus les indicateurs 'Government expenditure on education as % of GDP (%)' et 'Personal computers (per 100 people)' ne seront finalement pas pris en compte. Ces derniers ont respectivement des taux de remplissage allant de 0  environ 50% et ce sur plusieurs années.

# %%
# Mise à jour de la liste d'indicateur pertinent
indicateurs_pertinents = [i for i in indicateurs_pertinents if i not in ('Government expenditure on education as % of GDP (%)',
'Personal computers (per 100 people)')]

# %%
# Mise à jour de df_ind
df_ind = df_ind[df_ind['Indicator Name'].isin(indicateurs_pertinents)]

# %% [markdown]
# Dans la partie ci-dessous les outliers ont été retirés en sélectionnant les indicateurs par ligne. Retirer les outliers par colonne n'aurait pas eu de sens car chaque "colonne année" indique des valeurs pour des indicateurs de différentes et différents pays.

# %%
# Définition colonnes clés
df_clés = df_ind.loc[:, 'Country Name':'Indicator Code']
print(df_clés.head(2))
# Out:
#      Country Name Country Code                   Indicator Name  \
# 1245   Arab World          ARB     GDP per capita (current US$)
# 1375   Arab World          ARB  Internet users (per 100 people)
#
#       Indicator Code
# 1245  NY.GDP.PCAP.CD
# 1375  IT.NET.USER.P2

# %%
# Sélection des "colonnes années"
df_temps = df_ind.loc[:, '1999':'2015']

# %%
# Retrait des lignes contenant uniquement des NaN
df_temps.dropna(axis=0, how='all', inplace=True)
print(df_temps.head(2))
# Out:
#              1999         2000         2001         2002         2003  \
# 1245  2332.064342  2615.682751  2515.077869  2499.335429  2754.304985
# 1375     0.598582     1.139541     1.561288     2.693061     3.645881
#
#              2004         2005         2006         2007         2008  \
# 1245  3168.186426  3796.021804  4414.093398  5046.817058  6255.761156
# 1375     7.006812     8.393142    11.654648    14.205902    18.593531
#
#              2009         2010         2011         2012         2013  2014  \
# 1245  5267.552563  6032.961957  7005.479541  7571.402403  7715.998677   NaN
# 1375    22.973689    26.747251    29.707761    34.014224    36.868602   NaN
#
#       2015
# 1245   NaN
# 1375   NaN

# %%
# Transposé du dataset correspondant aux colonnes années
df_temps_T = df_temps.T
df_temps_T.head(2)
# Out:
#            1245      1375        2332         2533         4910      5040    \
# 1999  2332.064342  0.598582  18707008.0  271912978.0  3784.780623  3.406408
# 2000  2615.682751  1.139541  19110638.0  277561423.0  4055.709092  5.592680
#
#           5997          6198       8575      8705        9662          9863    \
# 1999  95908816.0  2.025301e+09  883.10810  0.853352  87855640.0  1.795289e+09
# 2000  98040272.0  2.044496e+09  962.75629  1.897116  90153024.0  1.813302e+09
#
#             12240      12370       13327        13528         15905   \
# 1999  22230.745128  15.240451  12690496.0  320258899.0  12355.925681
# 2000  20190.188991  22.524339  12619282.0  321310785.0  11626.213353
#
#          16035       16992        17193        19570     19700       20657   \
# 1999   9.244020  36871388.0  861380105.0  1638.116465  1.142024  16223210.0
# 2000  13.184147  36930156.0  862304084.0  1813.342178  2.023515  16365455.0
#
#            20858         23235      23365       24322        24523   \
# 1999  397071924.0  19447.595160  14.582698  21910876.0  487179992.0
# 2000  397083969.0  18051.195528  20.556694  21776276.0  487975692.0
#
#           26900     27030       27987        28188         30565      30695   \
# 1999  310.611410  0.106460  27419232.0  461899663.0  25404.947856  22.907304
# 2000  327.547359  0.173378  28289350.0  474935556.0  25768.958146  30.689400
#
#           31652         31853        34230     34360       35317   \
# 1999  45230120.0  1.063829e+09  3964.232209  2.052490  29632232.0
# 2000  45230076.0  1.070496e+09  4310.148147  3.903713  30420900.0
#
#            35518        37895     38025       38982        39183       41560   \
# 1999  517324341.0  3790.546047  1.897094  28166788.0  492708788.0  279.399839
# 2000  524829248.0  4141.572963  3.400631  28934678.0  499996505.0  309.096513
#
#         41690       42647        42848        45225     45355        46312   \
# 1999  0.057145  42983100.0  648229112.0  1099.858306  0.723486  310035712.0
# 2000  0.099376  44146676.0  664804763.0  1182.710628  1.454682  317298176.0
#
#             46513       48890     49020       49977        50178       52555   \
# 1999  4.974238e+09  235.936545  0.072117  25008052.0  413745647.0  553.370678
# 2000  5.047579e+09  265.066741  0.113522  25792330.0  425129552.0  574.904220
#
#         52685        53642         53843        56220     56350       57307   \
# 1999  0.280821  168593696.0  2.296630e+09  2787.100748  0.918918  23350558.0
# 2000  0.559820  172013440.0  2.337779e+09  3049.298394  1.693013  23901522.0
#
#            57508        59885     60015       60972        61173   \
# 1999  311053183.0  1580.201181  0.416627  21383954.0  275840061.0
# 2000  317129227.0  1607.588310  0.842208  21947540.0  280955290.0
#
#            63550     63680        64637         64838         67215   \
# 1999  1178.748457  0.778700  285493088.0  4.560492e+09  33397.980910
# 2000  1267.829331  1.574868  291984896.0  4.622449e+09  35242.064196
#
#          67345       68302        68503         70880      71010       71967   \
# 1999  35.882480  13089800.0  309600485.0  23122.016751  20.691520  52506884.0
# 2000  43.879374  13331363.0  312993944.0  23434.428927  27.928073  52537920.0
#
#             72168       74545     74675        75632         75833   \
# 1999  1.148125e+09  434.184716  0.226317  115232608.0  1.361054e+09
# 2000  1.156314e+09  443.385841  0.473921  117559296.0  1.386505e+09
#
#           78210     78340       79297        79498       81875     82005   \
# 1999  525.659419  0.359685  41179956.0  652354818.0  524.761434  0.358972
# 2000  548.924553  0.501116  42344712.0  669818179.0  548.065951  0.500289
#
#           82962        83163        85540     85670        86627   \
# 1999  41173524.0  652274408.0  1813.324161  1.285019  116899408.0
# 2000  42338196.0  669737048.0  1976.966655  2.531930  119971464.0
#
#             86828        89205     89335        90292         90493   92870   \
# 1999  2.263862e+09  5384.311328  4.653865  355733280.0  6.038067e+09     NaN
# 2000  2.284670e+09  5486.458835  6.770067  363008864.0  6.118075e+09     NaN
#
#       93000      93957       94158        96535     96665     97622   \
# 1999     NaN  1203174.0  19403676.0  1098.425463  0.081437  237593.0
# 2000     NaN  1245988.0  20093756.0  1175.788981  0.114097  240167.0
#
#          97823        100200    100330     101287      101488  103865  \
# 1999  3108778.0  1581.004564  0.199524  2237094.0  30765613.0     NaN
# 2000  3089027.0  1757.017797  0.491706  2276884.0  31183660.0     NaN
#
#        105153        107530     107660   108818      111195    111325  \
# 1999  56770.0  19261.710504   7.635686  64370.0  385.768853  0.071964
# 2000  57521.0  21936.530101  10.538836  65390.0  555.296942  0.105046
#
#          112282      112483       114860    114990  115947   116148  \
# 1999   993494.0  15949766.0  9363.186640  5.300681  2480.0  81831.0
# 2000  1025185.0  16440924.0  9932.029681  6.482226  2510.0  83584.0
#
#            118525    118655     119612      119813      122190    122320  \
# 1999  7736.369623  3.284482  1942652.0  36648068.0  597.433482  0.970738
# 2000  7669.273916  7.038683  1949319.0  37057452.0  622.742748  1.300470
#
#         123277     123478        125855     125985  126942   127143  \
# 1999  119410.0  3089017.0  19356.203389   4.506179  3683.0  89005.0
# 2000  122462.0  3069588.0  20620.700626  15.442823  3796.0  90853.0
#
#             129520     129650    130607      130808        133185     133315  \
# 1999  20561.476783  40.783784  523856.0  18926000.0  27174.297156  23.044317
# 2000  21690.920999  46.756116  529432.0  19153000.0  24564.458295  33.730133
#
#         134272     134473      136850    136980    137937     138138  \
# 1999  383821.0  7992324.0  573.890256  0.099229  308908.0  7982750.0
# 2000  385661.0  8011566.0  655.097433  0.147758  337846.0  8048600.0
#
#             140515    140645   141602    141803        144180    144310  \
# 1999  20505.947434  3.764558  17238.0  293572.0  10401.480449  4.720358
# 2000  21241.236698  8.000000  17265.0  297890.0  13636.346684  6.153733
#
#        145267    145468      147845    147975      148932       149133  \
# 1999  30400.0  636545.0  397.354822  0.036170  11855777.0  129029691.0
# 2000  30683.0  664614.0  405.603307  0.071039  12028254.0  131581243.0
#
#             151510    151640  152597    152798       155175    155305  \
# 1999  11200.577633  2.376247  8210.0  268922.0  1210.611600  0.494881
# 2000  11567.666122  3.973678  8164.0  269847.0  1276.288034  1.860398
#
#         156262      156463        158840     158970    159927      160128  \
# 1999  321767.0  10026738.0  25444.139258  13.772214  487199.0  10226419.0
# 2000  325037.0   9979610.0  23207.405911  29.431692  486989.0  10251250.0
#
#            162505    162635   163592    163793      166170    166300  \
# 1999  3065.492248  4.076741  10965.0  239026.0  403.623704  0.154907
# 2000  3364.423711  5.963835  11192.0  247315.0  374.192394  0.225248
#
#         167257     167458        169835     169965  170922   171123  \
# 1999  408687.0  6664098.0  54245.459737  39.947589  3039.0  61285.0
# 2000  422240.0  6865951.0  56284.168648  42.949860  3100.0  61833.0
#
#           173500    173630   174587    174788       177165    177295  \
# 1999  751.575772  0.137572  24488.0  557543.0  1012.509773  0.981815
# 2000  765.863236  0.400944  25460.0  573416.0  1007.002869  1.442764
#
#         178252     178453       180830    180960     182118       184495  \
# 1999  727608.0  8182712.0  1246.497114  0.194374  3759118.0  3226.295674
# 2000  737977.0  8339512.0  1461.750520  1.082961  3766706.0  3349.068823
#
#         184625   185582     185783       188160    188290      189247  \
# 1999  1.122391  84154.0  1699862.0  3469.503972  2.038732  10439179.0
# 2000  2.902667  85505.0  1728340.0  3739.119036  2.870685         NaN
#
#            189448  192912        195490    195620   196577    196778  \
# 1999  172759243.0     NaN  14097.931588  7.671041  22132.0  326289.0
# 2000  175287587.0     NaN  18008.448259  8.996285  22125.0  333241.0
#
#            199155    199285    200242     200443      202820   202950  \
# 1999  1643.609895  2.908154  332745.0  8210624.0  265.340116  0.06178
# 2000  1609.280586  5.370923  325327.0  8170172.0  226.475981  0.07708
#
#         203907      204108      206485    206615    207572     207773  \
# 1999  705140.0  11282701.0  128.696440  0.039204  403172.0  6278940.0
# 2000  728819.0  11607942.0  135.998445  0.077248  422907.0  6400706.0
#
#            210150    210280   211237    211438      213815    213945  \
# 1999  1389.719796  1.159982  40088.0  426285.0  295.973596  0.031970
# 2000  1239.377855  1.822444  30801.0  435079.0  300.685095  0.047023
#
#         214902      215103      217480    217610     218567      218768  \
# 1999  880115.0  11883636.0  751.978291  0.129068   979396.0  14891891.0
# 2000  994578.0  12152354.0  660.192697  0.252120  1018138.0  15274234.0
#
#             221145    221275     222232      222433  224810  224940   226098  \
# 1999  22167.225850  36.18644  1233891.0  30499200.0     NaN     NaN  39808.0
# 2000  24124.169175  51.30000  1247988.0  30769700.0     NaN     NaN  41687.0
#
#           228475    228605    229562     229763      232140    232270  \
# 1999  271.855117  0.040894  227140.0  3676508.0  190.835983  0.012322
# 2000  243.542932  0.053394  233738.0  3754986.0  166.023178  0.035707
#
#         233227     233428        235805    237093       239470     239600  \
# 1999  483363.0  8041846.0  42405.497145  147687.0  4986.007417   4.103419
# 2000  502983.0  8342559.0  43299.401141  148725.0  5101.368479  16.600000
#
#          240557      240758      243135    243265      244222        244423  \
# 1999  1019401.0  15076952.0  873.287062  0.708188  57799332.0  1.252735e+09
# 2000  1041400.0  15262754.0  959.372484  1.775913  59692664.0  1.262645e+09
#
#            246800    246930     247887      248088      250465    250595  \
# 1999  2164.432929  1.697731  1683090.0  39819279.0  420.877934  0.148163
# 2000  2472.197831  2.207533  1690738.0  40403958.0  375.852857  0.271741
#
#        251552    251753      254130    254260     255217      255418  \
# 1999  34782.0  528848.0  102.644799  0.001009  3953699.0  45898667.0
# 2000  36093.0  542357.0  405.469653  0.005902  4076161.0  47076387.0
#
#           257795    257925    258882     259083       261460    261590  \
# 1999  750.526550  0.016791  194365.0  3136344.0  3688.398314  3.904323
# 2000  998.196892  0.026355  198064.0  3225727.0  3808.363689  5.800253
#
#         262547     262748      265125    265255     266212      266413  \
# 1999  154130.0  3848723.0  759.292203  0.118686   985159.0  16300233.0
# 2000  157114.0  3925443.0  642.254714  0.231462  1008714.0  16686561.0
#
#            268790    268920    269877     270078       272455    272585  \
# 1999  5135.473341  4.405359  247182.0  4554000.0  2553.069760  0.314691
# 2000  4919.628069  6.644883  244523.0  4426000.0  2741.110542  0.541183
#
#         273542      273743  277207    277408        279785     279915  \
# 1999  436014.0  11110004.0     NaN  139428.0  15457.644364  11.342399
# 2000  444601.0  11150736.0     NaN  133860.0  14672.882058  15.255394
#
#        280872    281073       283450    283580    284537      284738  \
# 1999  33778.0  926050.0  6307.698004  6.832802  594283.0  10283860.0
# 2000  34797.0  943286.0  6011.615220  9.780528  559765.0  10255063.0
#
#             287115     287245    288202     288403      290780    290910  \
# 1999  33440.801620  30.592041  173862.0  5321799.0  765.720488  0.105762
# 2000  30743.559174  39.172431  168133.0  5339616.0  768.176077  0.194501
#
#        291867    292068       294445    294575  295532   295733       298110  \
# 1999  43630.0  700099.0  3830.175253  2.932164  2878.0  69903.0  2575.565104
# 2000  43348.0  717584.0  4820.107567  8.814844  2929.0  69676.0  2802.420042
#
#         298240    299197     299398       301775    301905    302862  \
# 1999  1.104744  717868.0  8429112.0  1584.463443  0.823372  757989.0
# 2000  3.704692  727528.0  8562622.0  1451.290776  1.462189  770437.0
#
#           303063       305440    305570     306527      306728       309105  \
# 1999  12398691.0  1321.799713  0.290445  4621066.0  68626664.0  2139.793967
# 2000  12628596.0  1428.183004  0.641265  4773923.0  69905988.0  2238.401016
#
#         309235    310192     310393       312770    312900   313857    314058  \
# 1999  0.845429  345715.0  5825187.0  1052.852818  0.097416  22094.0  589938.0
# 2000  1.177397  345491.0  5867626.0  1702.684901  0.132355  24225.0  614323.0
#
#           316435    316565    317522     317723       320100     320230  \
# 1999  208.620975  0.025495  360829.0  3302263.0  4119.347394  14.500897
# 2000  208.196949  0.136712  377514.0  3392801.0  4070.032827  28.576954
#
#        321187     321388      323765    323895     324852      325053  \
# 1999  60612.0  1390244.0  119.134082  0.012542  2597565.0  64640054.0
# 2000  60980.0  1396985.0  123.876206  0.015264  2725399.0  66537331.0
#
#             327430     327560   328718       331095    331225   332182  \
# 1999  23982.880671  22.297538  46937.0  2408.165466  0.942462  53255.0
# 2000  22479.578988  32.916392  47258.0  2076.013308  1.496855  53711.0
#
#         332383        334760     334890    335847     336048        338425  \
# 1999  806494.0  26178.791785  32.295092  200079.0  5165474.0  24799.296010
# 2000  811223.0  24253.250425  37.248462  200417.0  5176209.0  22465.641841
#
#          338555     339512      339713        342090    342220    343378  \
# 1999   9.125318  2319498.0  60496715.0  16299.564154  3.448900  232952.0
# 2000  14.307924  2346482.0  60912498.0  14530.777204  6.357064  237258.0
#
#            345755    345885   346842     347043      349420    349550  \
# 1999  3883.325188  0.249010  72283.0  1200773.0  681.537418  0.715827
# 2000  4116.460693  1.216141  74745.0  1231122.0  635.563758  0.921795
#
#        350507     350708      353085    353215    354172     354373  \
# 1999  77025.0  1195420.0  628.865652  0.416344  151530.0  4452500.0
# 2000  79596.0  1231844.0  691.997710  0.484746  152227.0  4418300.0
#
#             356750     356880     357837      358038      360415    360545  \
# 1999  26795.991132  20.845983  2673582.0  82100243.0  417.767991  0.104895
# 2000  23718.746699  30.216347  2722950.0  82211508.0  263.112468  0.153615
#
#          361502      361703     364210  365167   365368        367745  \
# 1999  1584242.0  18477612.0   5.936978     NaN  30991.0  13245.189463
# 2000  1625014.0  18938762.0  19.131638     NaN  31180.0  12042.953731
#
#         367875    368832      369033        371410     371540   372698  \
# 1999  6.877292  447978.0  10761698.0  20170.438416  21.602613  56100.0
# 2000  9.138837  436805.0  10805808.0  19004.107291  31.747811  56200.0
#
#            375075    375205  376162    376363  378740     378870    380028  \
# 1999  4751.575978  2.473166  4743.0  101442.0     NaN   8.497176  153953.0
# 2000  5117.589923  4.063908  4900.0  101619.0     NaN  16.113127  155329.0
#
#            382405    382535    383492      383693      386070    386200  \
# 1999  1608.692890  0.592653  534069.0  11387203.0  399.973964  0.060809
# 2000  1655.596261  0.712333  545670.0  11650743.0  340.051692  0.095425
#
#         387157     387358      389735    389865   390822     391023  \
# 1999  498630.0  8653769.0  183.853011  0.117702  55089.0  1220794.0
# 2000  511226.0  8808546.0  297.751944  0.230103  57256.0  1243229.0
#
#           393400    393530   394487    394688      397065    397195    398152  \
# 1999  919.866577  3.966355  29864.0  755278.0  494.232421  0.070658  765969.0
# 2000  946.059937  6.611492  28355.0  753301.0  462.480652  0.231271  794318.0
#
#          398353       400730    400860    401817     402018        404395  \
# 1999  8404398.0   845.108823  0.573575  287288.0  6357221.0  25091.666600
# 2000  8549200.0  1088.783165  1.203856  293220.0  6524283.0  25756.663778
#
#          404525    405482     405683       408060    408190    409147  \
# 1999  21.230682  357993.0  6606500.0  4802.958760  5.857841  570080.0
# 2000  27.827761  365300.0  6665000.0  4633.312923  6.999676  536928.0
#
#           409348        411725     411855   412812    413013      415390  \
# 1999  10237530.0  32198.908579  41.294567  17038.0  277381.0  437.586118
# 2000  10210971.0  31813.373441  44.470534  17127.0  281205.0  438.864630
#
#         415520      416477        416678      419055    419185      420142  \
# 1999  0.273224  86498432.0  1.034539e+09  714.545331  0.444416  13199231.0
# 2000  0.527532  88120752.0  1.053051e+09  830.584588  0.925564  13336636.0
#
#            420343       422720    422850     423807      424008  426385  \
# 1999  208612556.0  1749.827783  0.378569  6948034.0  65062660.0     NaN
# 2000  211540429.0  1657.169748  0.934190  7150982.0  66131854.0     NaN
#
#       426515     427472      427673        430050     430180    431137  \
# 1999     NaN  1537893.0  22878156.0  26284.304776  10.933809  141931.0
# 2000     NaN  1571638.0  23565413.0  26241.514513  17.850467  141654.0
#
#          431338        433715   435003        437380     437510    438467  \
# 1999  3754786.0  21784.879598  71952.0  19133.048198  13.436122  313608.0
# 2000  3805174.0  21551.779359  72554.0  21042.981600  20.873790  315701.0
#
#          438668        441045     441175     442132      442333       444710  \
# 1999  6125000.0  21936.823129  14.378410  3130307.0  56916317.0  3338.200840
# 2000  6289000.0  20051.242155  23.110874  3055682.0  56942108.0  3360.870402
#
#         444840    445797     445998        448375    448505     449462  \
# 1999  2.355689  103059.0  2634882.0  36026.556075  21.39129  4604920.0
# 2000  3.115778  103622.0  2656864.0  38532.040875  29.99074  4497368.0
#
#            449663       452040    452170    453127     453328       455705  \
# 1999  126631000.0  1624.979100  2.526965  219328.0  5014899.0  1130.113592
# 2000  126843000.0  1657.889256  2.623275  224871.0  5103130.0  1229.000958
#
#         455835    456792      456993      459370    459500     460457  \
# 1999  0.464277  562940.0  14928426.0  421.432885  0.114256  3061139.0
# 2000  0.668594  562240.0  14883626.0  403.979713  0.318060  3148487.0
#
#           460658      463035    463165  464122   464323  466830     467787  \
# 1999  30600397.0  832.054794  1.211578  5392.0  82966.0     0.0  1151475.0
# 2000  31450483.0  796.793763  1.785225  5603.0  84406.0     0.0  1166580.0
#
#           467988        470365     470495     471452      471653       474030  \
# 1999  22731985.0  10409.326888  23.552194  2259203.0  46616677.0          NaN
# 2000  22929075.0  11947.579128  44.700000  2177283.0  47008111.0  1087.762401
#
#          475318        477695    477825    478782     478983      481360  \
# 1999  1762000.0  15391.345736  4.756222  109808.0  1957066.0  258.049340
# 2000  1700000.0  18389.384328  6.731396  114887.0  2050741.0  279.620523
#
#         481490    482447     482648      485025    485155    486112  \
# 1999  0.204711  199863.0  4840400.0  277.495103  0.037781  352019.0
# 2000  1.041401  205991.0  4898400.0  324.845050  0.111044  364219.0
#
#          486313       488690    488820    489777     489978       492355  \
# 1999  5241284.0  3151.325802  4.387409  102841.0  2390482.0  5509.346429
# 2000  5329304.0  3352.731296  6.319062  104843.0  2367550.0  5334.903329
#
#         492485    493442     493643      496020    496150   497107     497308  \
# 1999  5.376809  184722.0  3156646.0  493.249377  0.053804  87721.0  1850527.0
# 2000  7.952744  185714.0  3235366.0  474.819791  0.211806  88986.0  1868699.0
#
#           499685    499815    500772     500973       503350    503480  \
# 1999  161.564122  0.011329  173722.0  2734518.0  6821.312519  0.133617
# 2000  183.414999  0.017703  185658.0  2884522.0  7145.628494  0.187043
#
#         504437     504638        507015    507145  508102   508303  \
# 1999  363434.0  5274163.0  81116.439165       NaN     NaN  32842.0
# 2000  365615.0  5355751.0  74624.559959  36.51523     NaN  33286.0
#
#            510680    510810    511767     511968        514345     514475  \
# 1999  3113.546428  2.923055  102015.0  3524238.0  51654.402795  17.387958
# 2000  3297.354701  6.427067  103812.0  3499536.0  48735.995492  22.887328
#
#        515432    515633        518010     518140   519097    519298  \
# 1999  18829.0  430475.0  15505.278745   9.212005  18556.0  418604.0
# 2000  19136.0  436300.0  15702.855528  13.608590  19859.0  427979.0
#
#            521675    521805    522762     522963      525340    525470  \
# 1999  1814.512523  1.497330  135377.0  2024394.0  243.252751  0.168609
# 2000  1854.145956  2.485566  136439.0  2034819.0  245.939066  0.196395
#
#         526427      526628      529005    529135    530092      530293  \
# 1999  901109.0  15282521.0  160.798877  0.087279  471638.0  11044356.0
# 2000  919153.0  15766806.0  153.259487  0.126781  488904.0  11376172.0
#
#            532670     532800     533757      533958       536335    536465  \
# 1999  3493.465229  12.305502  1833160.0  22656286.0  2104.427691  1.119909
# 2000  4045.170471  21.384731  1869556.0  23185608.0  2182.997011  2.203873
#
#        537422    537623      540000    540130    541087      541288  \
# 1999  14058.0  280000.0  322.538680  0.060910  694223.0  10663723.0
# 2000  14792.0  286000.0  269.348383  0.142546  714223.0  10967690.0
#
#             543665     543795   544752    544953       547330    547460  \
# 1999  10648.988896   7.759798  11754.0  387578.0  2073.367384  0.966072
# 2000  11039.056507  13.113709  11682.0  390087.0  2126.913860  1.534272
#
#       548417   548618      550995    551125    552082     552283       554660  \
# 1999  5674.0  52079.0  534.715944  0.118464  169416.0  2628803.0  3651.232286
# 2000  5910.0  52159.0  477.476102  0.192031  174048.0  2709359.0  3861.032414
#
#         554790   555747     555948       558325    558455     559412  \
# 1999  4.652213  80899.0  1175267.0  5777.231681  1.857436  6367056.0
# 2000  7.281535  79404.0  1186873.0  6720.902113  5.081384  6397627.0
#
#            559613       561990    562120   563077    563278      565655  \
# 1999  100300579.0  2046.639645  2.797594  11180.0  107816.0  321.026796
# 2000  101719673.0  2170.920210  3.734862  11256.0  107432.0  354.003732
#
#         565785    566742     566943        569320     569450   570608  \
# 1999  0.600695  134074.0  3647001.0  91383.940493        NaN  31800.0
# 2000  1.282846  140836.0  3639592.0  82534.873767  42.184863  32082.0
#
#           572985    573115    574072     574273       576650  576780   577737  \
# 1999  445.006943  0.508472  103965.0  2376162.0          NaN     NaN  39430.0
# 2000  474.213336  1.255652  105247.0  2397436.0  1627.042893     NaN  39729.0
#
#         577938       580315    580445     581402      581603      583980  \
# 1999  606001.0  1444.989055  0.175595  1966217.0  28514798.0  301.539472
# 2000  604950.0  1332.382358  0.693791  1998356.0  28849621.0  277.648659
#
#         584110    585067      585268     587645    587775     588732  \
# 1999  0.056251  774784.0  17584869.0        NaN  0.000152  2160337.0
# 2000  0.109593  793098.0  18067687.0  193.18748       NaN  2136260.0
#
#           588933       591310    591440   592397     592598  596062  \
# 1999  45539435.0  2055.364975  0.336218  78441.0  1858042.0   416.0
# 2000  46095462.0  2057.995057  1.644740  79413.0  1899257.0   415.0
#
#           598640    598770     599727      599928        602305     602435  \
# 1999  215.980592  0.146669  2005958.0  23305994.0  27951.734289  39.176007
# 2000  231.425500  0.204652  2046545.0  23740911.0  25921.127941  43.984351
#
#         603392      603593        605970     606100    607258        609635  \
# 1999  542381.0  15812088.0  14611.832803   5.688147  209214.0  15322.088513
# 2000  547275.0  15925513.0  12579.595106  13.939549  213230.0  13641.102718
#
#          609765    610722     610923       613300    613430    614387  \
# 1999  41.494483  164548.0  3835100.0   981.020489  0.497902  239321.0
# 2000  47.379557  168973.0  3857700.0  1016.020743  0.980216  243472.0
#
#          614588      616965    617095    618052      618253      620630  \
# 1999  4949660.0  184.346477  0.028136  589312.0  10947829.0  300.609008
# 2000  5026796.0  158.405597  0.036261  598346.0  11352973.0  379.119326
#
#         620760     621717       621918  624295   625583        627960  628090  \
# 1999  0.041039  7896140.0  119327073.0     NaN  67755.0  36371.395788    40.0
# 2000  0.064081  8091424.0  122352009.0     NaN  69094.0  38146.715392    52.0
#
#         629047     629248       631625    631755    632712     632913  \
# 1999  157125.0  4461913.0  6967.059664  2.515666  147861.0  2254918.0
# 2000  157438.0  4490967.0  8601.185906  3.520421  147454.0  2267991.0
#
#           635290    635420      636377       636578       638955  639085  \
# 1999  465.075766  0.055357  12132384.0  135405584.0  6011.176439     NaN
# 2000  533.862411       NaN  12600461.0  138523285.0  7709.653194     NaN
#
#       640042   640243       642620    642750    643707     643908      646285  \
# 1999     NaN  18879.0  4082.614583  3.836865  175840.0  2971197.0  640.286085
# 2000     NaN  19175.0  4060.299035  6.554796  177594.0  3030347.0  631.946853
#
#         646415    647372     647573       649950    650080    651037  \
# 1999  0.667113  224893.0  5430479.0  1614.903106  0.381657  349546.0
# 2000  0.835249  228913.0  5572222.0  1545.626423  0.747631  358469.0
#
#          651238       653615    653745     654702      654903       657280  \
# 1999  5196937.0  1963.410567  1.952498  1074666.0  25561299.0  1087.237365
# 2000  5302700.0  1996.719689  3.076431  1090526.0  25914879.0  1038.910977
#
#         657410     658367      658568       660945    661075     662032  \
# 1999  1.431609  1653838.0  76335812.0  4389.976415  5.456444  2709610.0
# 2000  1.982253  1693023.0  77991569.0  4492.727604  7.285429  2725182.0
#
#           662233        664610     664740    665697      665898        668275  \
# 1999  38660271.0  12474.818082  14.742338  431072.0  10217828.0  15220.979237
# 2000  38258629.0  11502.396813  16.430468  419652.0  10289898.0  16192.129596
#
#          668405    669362     669563        671940    672070   673027  \
# 1999   5.265683  190648.0  3800081.0  21763.450976  4.070729  24048.0
# 2000  10.474648  189094.0  3810605.0  29986.290153  4.863679  25190.0
#
#         673228       675605    675735     676692      676893       679270  \
# 1999  569447.0  1610.134370  2.697580  1418934.0  22472040.0  1330.751464
# 2000  592267.0  1668.162731  3.613717  1380733.0  22442971.0  1771.586602
#
#         679400     680357       680558      682935    683065    684022  \
# 1999  1.018985  4778481.0  147214392.0  239.378127  0.067176  522902.0
# 2000  1.977230  4874976.0  146596557.0  216.172747  0.062831  565358.0
#
#          684223       686600    686730   687687    687888        690265  \
# 1999  7593239.0  1489.647875  0.285308  19152.0  173755.0  44862.894513
# 2000  8025703.0  1540.689023  0.566393  19127.0  174610.0  40188.820185
#
#          690395  691352   691553  693930    694060  695017    695218  \
# 1999  42.803316     NaN  27096.0     NaN  0.363203  9068.0  135886.0
# 2000  48.799495     NaN  27418.0     NaN  4.638517  8886.0  138606.0
#
#            697595    697725     698682      698883      701260    701390  \
# 1999  7968.548574  0.493585  1212629.0  20294406.0  533.285122  0.311091
# 2000  9126.954277  2.210692  1192267.0  20764312.0  473.450034  0.403967
#
#         702347     702548       704925  705055    706012     706213  \
# 1999  614331.0  9645957.0  2441.430389     NaN  405712.0  7540401.0
# 2000  631104.0  9884052.0   870.136525     NaN  406098.0  7516346.0
#
#            708590    708720  709677   709878      712255    712385    713342  \
# 1999  7747.612159  6.229055  6433.0  80410.0  150.836972  0.048491  260452.0
# 2000  7578.851053  7.395629  6517.0  81131.0  139.314773  0.118254  266870.0
#
#          713543        715920     716050     717208   720873       723250  \
# 1999  4437803.0  21795.696957  24.155437  3958723.0  31084.0  5636.579532
# 2000  4564297.0  23792.607070  36.000000  4027887.0  30519.0  5402.929754
#
#         723380    724337     724538        726915     727045    728002  \
# 1999  5.437758  368378.0  5396020.0  11441.997025  12.610938  115704.0
# 2000  9.426803  361720.0  5388720.0  10227.736770  15.110260  113059.0
#
#          728203       730580    730710   731667    731868  734245   734375  \
# 1999  1983045.0  1200.917702  0.494541  35688.0  401538.0     NaN  0.01391
# 2000  1988925.0  1054.518572  0.481297  36293.0  412609.0     NaN  0.02000
#
#         735332     735533       737910   738040     738997      739198  \
# 1999  581019.0  8720231.0  3088.863784  4.11625  2739707.0  44233730.0
# 2000  602116.0  9011479.0  3037.225030  5.34856  2784760.0  44896856.0
#
#       741575  742662     742863        745240     745370     746327  \
# 1999     NaN     NaN  6362201.0  15678.215235   7.085040  1119161.0
# 2000     NaN     NaN  6652984.0  14676.706088  13.624961  1066288.0
#
#           746528      748905    749035     749992      750193       752570  \
# 1999  40386875.0  844.826671  0.348414  1498344.0  18532000.0  8700.348672
# 2000  40567864.0  875.412178  0.647410  1477039.0  18655000.0  9267.754831
#
#        752700  753657   753858       756235    756365  757322    757523  \
# 1999  4.40044  1782.0  44824.0  5000.482141  1.932106  6461.0  155172.0
# 2000  5.86281  1787.0  45374.0  4996.267719  5.090483  6629.0  156949.0
#
#        761188       763565    763695  764652    764853      767230    767360  \
# 1999  29305.0  3621.794106  2.782002  4759.0  107880.0  323.571795  0.008795
# 2000  28384.0  3672.635267  3.245037  4698.0  107898.0  361.030584  0.025785
#
#          768317      768518       770895    771025   771982    772183  \
# 1999  1844205.0  26607042.0  1896.013914  1.891871  17045.0  467003.0
# 2000  1874622.0  27250535.0  1888.618290  2.506411  17704.0  472390.0
#
#            774560    774690   775647     775848        778225     778355  \
# 1999  1480.338095  0.470718  51621.0  1045629.0  30577.081774  41.432783
# 2000  1637.450072  0.926192  53773.0  1061468.0  29283.005046  45.687652
#
#         779312     779513        781890  782020    782977     783178  \
# 1999  297614.0  8857874.0  40581.307052    34.0  321729.0  7143991.0
# 2000  297926.0  8872109.0  37868.323060    47.1  326620.0  7184250.0
#
#            785555    785685     786642      786843      789220    789350  \
# 1999   991.120429  0.124295  1156997.0  16016092.0  177.692172  0.032792
# 2000  1177.629268  0.181699  1182474.0  16410848.0  138.436603  0.048600
#
#         790307     790508      792885    793015     793972      794173  \
# 1999  258673.0  6114886.0  299.786754  0.075131  1385855.0  33291540.0
# 2000  269205.0  6216205.0  306.723827  0.117194  1423926.0  34178042.0
#
#            796550    796680     797637      797838      800215  800345  \
# 1999  2032.992147  2.426242  3335355.0  62306651.0         NaN     NaN
# 2000  2007.564826  3.689041  3306936.0  62958021.0  402.006653     NaN
#
#        801302    801503      803880    804010    804967     805168  \
# 1999  52025.0  863269.0  326.604070  0.590363  314626.0  4825704.0
# 2000  55414.0  871607.0  260.393294  0.800000  324428.0  4970367.0
#
#            807545    807675  808632   808833       811210    811340   812297  \
# 1999  2015.418170  1.017967  4819.0  97591.0  5383.552427  5.814251  59088.0
# 2000  2063.207236  2.434398  4693.0  98082.0  6430.947262  7.721411  59503.0
#
#          812498       814875    815005    815962     816163       818540  \
# 1999  1264775.0  2389.036036  1.602495  818537.0  9603742.0  4108.127878
# 2000  1267984.0  2213.914088  2.750740  829955.0  9699197.0  4316.553895
#
#         818670     819627      819828      822205    822335    823292  \
# 1999  2.292118  3906747.0  62287326.0  548.726876  0.045021  189378.0
# 2000  3.761685  3904682.0  63240121.0  643.175011  0.133282  195311.0
#
#          823493   827158       829535   829665  830622  830823      833200  \
# 1999  4466132.0  17864.0  1464.648593      NaN     NaN  9345.0  257.747800
# 2000  4516131.0  18873.0  1458.817097  5.24164   456.0  9420.0  257.630361
#
#         833330     834287      834488      836865    836995     837952  \
# 1999  0.105544   986150.0  23272995.0  635.766242  0.405385  1540275.0
# 2000  0.163714  1021054.0  24039274.0  635.708964  0.716184  1529637.0
#
#           838153        840530     840660    841617     841818        844195  \
# 1999  49673350.0  28260.005017  14.942699  117391.0  2988162.0  28383.668905
# 2000  49175848.0  33071.268687  23.625301  116575.0  3154925.0  27982.355764
#
#          844325     845282      845483        847860     847990      848947  \
# 1999  21.293638  2876069.0  58682466.0  34620.928899  35.848724  11852870.0
# 2000  26.821754  2918478.0  58892514.0  36449.855116  43.079163  12080275.0
#
#            849148       851525     851655    852612     852813      855190  \
# 1999  279040000.0  7247.398162   9.972765  152000.0  3309318.0  702.480744
# 2000  282162411.0  6871.897677  10.539058  151710.0  3321245.0  558.221144
#
#         855320     856277      856478       858855    858985   859942  \
# 1999  0.030688  1029117.0  24311650.0  1477.841822  0.538300  12052.0
# 2000  0.484347  1064979.0  24650400.0  1469.849149  2.108337  12365.0
#
#         860143       862520    862650     863607      863808      866185  \
# 1999  181345.0  4077.496123  2.839826   982517.0  24028689.0  374.476433
# 2000  185063.0  4783.530592  3.359597  1003049.0  24488340.0  401.547817
#
#         866315     867272      867473  869850     869980    871138  \
# 1999  0.128927  4961174.0  76596700.0     NaN  11.074606  108596.0
# 2000  0.254248  5052437.0  77630900.0     NaN  13.815081  108639.0
#
#            873515    873645    874602     874803      877180    877310  \
# 1999  1499.492177       NaN  128377.0  2848431.0  439.697211  0.056629
# 2000  1476.171850  1.111306  133190.0  2922153.0  539.104365  0.082500
#
#          878267      878468      880845    880975    881932      882133  \
# 1999  1158625.0  17378098.0  332.461627  0.147053  696965.0  10239714.0
# 2000  1210589.0  17874725.0  341.905562  0.191072  713675.0  10531221.0
#
#           884510    884640     885597      885798
# 1999  568.443953  0.161676  1277042.0  12064537.0
# 2000  547.358878  0.401434  1301540.0  12222251.0

# %%
# Retrait des outliers - Remplacement des valeurs dont |Z-score| > 2 par Nan
df_temps_T_o = df_temps_T.mask(df_temps_T.sub(df_temps_T.mean()).div(df_temps_T.std()).abs().gt(2))
# print(df_temps_T_o.head(2))

# %% [markdown]
# Après plusieurs valeurs testées, un Z-score de 2 a été choisi pour permettre un retrait optimal des outliers.

# %%
# Affichage des 2 premières lignes de df_temps_T_o
df_temps_T_o.head(2)
# Out:
#            1245      1375        2332         2533         4910      5040    \
# 1999  2332.064342  0.598582         NaN  271912978.0  3784.780623  3.406408
# 2000  2615.682751  1.139541  19110638.0  277561423.0  4055.709092  5.592680
#
#           5997          6198       8575      8705        9662          9863    \
# 1999  95908816.0  2.025301e+09  883.10810  0.853352  87855640.0  1.795289e+09
# 2000  98040272.0  2.044496e+09  962.75629  1.897116  90153024.0  1.813302e+09
#
#             12240      12370       13327        13528         15905   \
# 1999  22230.745128  15.240451  12690496.0  320258899.0  12355.925681
# 2000  20190.188991  22.524339  12619282.0  321310785.0  11626.213353
#
#          16035       16992        17193        19570     19700       20657   \
# 1999   9.244020  36871388.0  861380105.0  1638.116465  1.142024  16223210.0
# 2000  13.184147  36930156.0  862304084.0  1813.342178  2.023515  16365455.0
#
#            20858         23235      23365       24322        24523   \
# 1999  397071924.0  19447.595160  14.582698  21910876.0  487179992.0
# 2000  397083969.0  18051.195528  20.556694  21776276.0  487975692.0
#
#           26900     27030       27987        28188         30565    30695   \
# 1999  310.611410  0.106460  27419232.0  461899663.0  25404.947856      NaN
# 2000  327.547359  0.173378  28289350.0  474935556.0  25768.958146  30.6894
#
#           31652         31853        34230     34360       35317   \
# 1999  45230120.0  1.063829e+09  3964.232209  2.052490         NaN
# 2000  45230076.0  1.070496e+09  4310.148147  3.903713  30420900.0
#
#            35518        37895     38025       38982        39183       41560   \
# 1999  517324341.0  3790.546047  1.897094         NaN  492708788.0  279.399839
# 2000  524829248.0  4141.572963  3.400631  28934678.0  499996505.0  309.096513
#
#         41690       42647        42848        45225     45355        46312   \
# 1999  0.057145  42983100.0  648229112.0  1099.858306  0.723486          NaN
# 2000  0.099376  44146676.0  664804763.0  1182.710628  1.454682  317298176.0
#
#             46513       48890     49020       49977        50178       52555   \
# 1999  4.974238e+09  235.936545  0.072117  25008052.0  413745647.0  553.370678
# 2000  5.047579e+09  265.066741  0.113522  25792330.0  425129552.0  574.904220
#
#         52685        53642         53843        56220     56350       57307   \
# 1999  0.280821          NaN  2.296630e+09  2787.100748  0.918918  23350558.0
# 2000  0.559820  172013440.0  2.337779e+09  3049.298394  1.693013  23901522.0
#
#            57508        59885     60015       60972        61173   \
# 1999  311053183.0  1580.201181  0.416627  21383954.0  275840061.0
# 2000  317129227.0  1607.588310  0.842208  21947540.0  280955290.0
#
#            63550     63680        64637         64838         67215   \
# 1999  1178.748457  0.778700  285493088.0  4.560492e+09  33397.980910
# 2000  1267.829331  1.574868  291984896.0  4.622449e+09  35242.064196
#
#          67345       68302        68503         70880      71010       71967   \
# 1999        NaN  13089800.0  309600485.0  23122.016751  20.691520  52506884.0
# 2000  43.879374  13331363.0  312993944.0  23434.428927  27.928073  52537920.0
#
#             72168       74545     74675        75632         75833   \
# 1999  1.148125e+09  434.184716  0.226317  115232608.0  1.361054e+09
# 2000  1.156314e+09  443.385841  0.473921  117559296.0  1.386505e+09
#
#           78210     78340       79297        79498       81875     82005   \
# 1999  525.659419  0.359685  41179956.0  652354818.0  524.761434  0.358972
# 2000  548.924553  0.501116  42344712.0  669818179.0  548.065951  0.500289
#
#           82962        83163        85540     85670        86627   \
# 1999  41173524.0  652274408.0  1813.324161  1.285019  116899408.0
# 2000  42338196.0  669737048.0  1976.966655  2.531930  119971464.0
#
#             86828        89205     89335        90292         90493   92870   \
# 1999  2.263862e+09  5384.311328  4.653865          NaN  6.038067e+09     NaN
# 2000  2.284670e+09  5486.458835  6.770067  363008864.0  6.118075e+09     NaN
#
#       93000      93957       94158        96535     96665     97622   \
# 1999     NaN  1203174.0  19403676.0  1098.425463  0.081437  237593.0
# 2000     NaN  1245988.0  20093756.0  1175.788981  0.114097  240167.0
#
#          97823        100200    100330     101287      101488  103865  \
# 1999  3108778.0  1581.004564  0.199524  2237094.0  30765613.0     NaN
# 2000  3089027.0  1757.017797  0.491706  2276884.0  31183660.0     NaN
#
#        105153        107530     107660   108818      111195    111325  \
# 1999  56770.0  19261.710504   7.635686  64370.0  385.768853  0.071964
# 2000  57521.0  21936.530101  10.538836  65390.0  555.296942  0.105046
#
#          112282      112483       114860    114990  115947   116148  \
# 1999   993494.0  15949766.0  9363.186640  5.300681  2480.0  81831.0
# 2000  1025185.0  16440924.0  9932.029681  6.482226  2510.0  83584.0
#
#            118525    118655     119612      119813      122190    122320  \
# 1999  7736.369623  3.284482  1942652.0  36648068.0  597.433482  0.970738
# 2000  7669.273916  7.038683  1949319.0  37057452.0  622.742748  1.300470
#
#         123277     123478        125855     125985  126942   127143  \
# 1999  119410.0  3089017.0  19356.203389   4.506179     NaN      NaN
# 2000  122462.0  3069588.0  20620.700626  15.442823  3796.0  90853.0
#
#             129520     129650    130607      130808        133185     133315  \
# 1999  20561.476783        NaN  523856.0  18926000.0  27174.297156  23.044317
# 2000  21690.920999  46.756116  529432.0  19153000.0  24564.458295  33.730133
#
#         134272     134473      136850    136980    137937     138138  \
# 1999  383821.0  7992324.0  573.890256  0.099229  308908.0  7982750.0
# 2000  385661.0  8011566.0  655.097433  0.147758  337846.0  8048600.0
#
#             140515    140645   141602    141803        144180    144310  \
# 1999  20505.947434  3.764558  17238.0  293572.0  10401.480449  4.720358
# 2000  21241.236698  8.000000  17265.0  297890.0  13636.346684  6.153733
#
#        145267    145468      147845    147975      148932       149133  \
# 1999  30400.0  636545.0  397.354822  0.036170         NaN  129029691.0
# 2000  30683.0  664614.0  405.603307  0.071039  12028254.0  131581243.0
#
#             151510    151640  152597    152798       155175    155305  \
# 1999  11200.577633  2.376247  8210.0  268922.0  1210.611600  0.494881
# 2000  11567.666122  3.973678  8164.0  269847.0  1276.288034  1.860398
#
#         156262      156463        158840     158970    159927      160128  \
# 1999  321767.0  10026738.0  25444.139258        NaN  487199.0  10226419.0
# 2000  325037.0   9979610.0  23207.405911  29.431692  486989.0  10251250.0
#
#            162505    162635   163592    163793      166170    166300  \
# 1999  3065.492248  4.076741  10965.0  239026.0  403.623704  0.154907
# 2000  3364.423711  5.963835  11192.0  247315.0  374.192394  0.225248
#
#         167257     167458        169835     169965  170922   171123  \
# 1999  408687.0  6664098.0  54245.459737  39.947589  3039.0      NaN
# 2000  422240.0  6865951.0  56284.168648  42.949860  3100.0  61833.0
#
#           173500    173630  174587    174788       177165    177295    178252  \
# 1999  751.575772  0.137572     NaN  557543.0  1012.509773  0.981815  727608.0
# 2000  765.863236  0.400944     NaN  573416.0  1007.002869  1.442764  737977.0
#
#          178453       180830    180960     182118       184495    184625  \
# 1999  8182712.0  1246.497114  0.194374  3759118.0  3226.295674  1.122391
# 2000  8339512.0  1461.750520  1.082961  3766706.0  3349.068823  2.902667
#
#        185582     185783       188160    188290      189247       189448  \
# 1999      NaN  1699862.0  3469.503972  2.038732  10439179.0  172759243.0
# 2000  85505.0  1728340.0  3739.119036  2.870685         NaN  175287587.0
#
#       192912        195490    195620   196577    196778       199155  \
# 1999     NaN  14097.931588  7.671041  22132.0  326289.0  1643.609895
# 2000     NaN  18008.448259  8.996285  22125.0  333241.0  1609.280586
#
#         199285    200242     200443      202820   202950    203907  \
# 1999  2.908154  332745.0  8210624.0  265.340116  0.06178  705140.0
# 2000  5.370923  325327.0  8170172.0  226.475981  0.07708  728819.0
#
#           204108      206485    206615    207572     207773       210150  \
# 1999  11282701.0  128.696440  0.039204  403172.0  6278940.0  1389.719796
# 2000  11607942.0  135.998445  0.077248  422907.0  6400706.0  1239.377855
#
#         210280   211237    211438      213815    213945    214902      215103  \
# 1999  1.159982  40088.0  426285.0  295.973596  0.031970       NaN  11883636.0
# 2000  1.822444  30801.0  435079.0  300.685095  0.047023  994578.0  12152354.0
#
#           217480    217610     218567      218768        221145  221275  \
# 1999  751.978291  0.129068   979396.0  14891891.0  22167.225850     NaN
# 2000  660.192697  0.252120  1018138.0  15274234.0  24124.169175    51.3
#
#          222232      222433  224810  224940   226098      228475    228605  \
# 1999  1233891.0  30499200.0     NaN     NaN  39808.0  271.855117  0.040894
# 2000  1247988.0  30769700.0     NaN     NaN  41687.0  243.542932  0.053394
#
#         229562     229763      232140    232270    233227     233428  \
# 1999  227140.0  3676508.0  190.835983  0.012322  483363.0  8041846.0
# 2000  233738.0  3754986.0  166.023178  0.035707  502983.0  8342559.0
#
#             235805    237093       239470     239600     240557      240758  \
# 1999  42405.497145  147687.0  4986.007417   4.103419  1019401.0  15076952.0
# 2000  43299.401141  148725.0  5101.368479  16.600000  1041400.0  15262754.0
#
#           243135    243265      244222        244423       246800    246930  \
# 1999  873.287062  0.708188  57799332.0  1.252735e+09  2164.432929  1.697731
# 2000  959.372484  1.775913  59692664.0  1.262645e+09  2472.197831  2.207533
#
#          247887      248088      250465    250595   251552    251753  \
# 1999  1683090.0  39819279.0  420.877934  0.148163  34782.0  528848.0
# 2000  1690738.0  40403958.0  375.852857  0.271741  36093.0  542357.0
#
#           254130    254260     255217      255418      257795    257925  \
# 1999  102.644799  0.001009  3953699.0  45898667.0  750.526550  0.016791
# 2000  405.469653  0.005902  4076161.0  47076387.0  998.196892  0.026355
#
#         258882     259083       261460    261590    262547     262748  \
# 1999  194365.0  3136344.0  3688.398314  3.904323       NaN  3848723.0
# 2000  198064.0  3225727.0  3808.363689  5.800253  157114.0  3925443.0
#
#           265125    265255     266212      266413       268790    268920  \
# 1999  759.292203  0.118686   985159.0  16300233.0  5135.473341  4.405359
# 2000  642.254714  0.231462  1008714.0  16686561.0  4919.628069  6.644883
#
#         269877     270078       272455    272585    273542      273743  \
# 1999  247182.0  4554000.0  2553.069760  0.314691  436014.0  11110004.0
# 2000  244523.0  4426000.0  2741.110542  0.541183  444601.0  11150736.0
#
#       277207    277408        279785     279915   280872    281073  \
# 1999     NaN  139428.0  15457.644364  11.342399  33778.0  926050.0
# 2000     NaN  133860.0  14672.882058  15.255394  34797.0  943286.0
#
#            283450    283580    284537      284738        287115     287245  \
# 1999  6307.698004  6.832802  594283.0  10283860.0  33440.801620        NaN
# 2000  6011.615220  9.780528  559765.0  10255063.0  30743.559174  39.172431
#
#         288202     288403      290780    290910   291867    292068  \
# 1999  173862.0  5321799.0  765.720488  0.105762  43630.0  700099.0
# 2000  168133.0  5339616.0  768.176077  0.194501  43348.0  717584.0
#
#            294445    294575  295532   295733       298110    298240    299197  \
# 1999  3830.175253  2.932164  2878.0  69903.0  2575.565104  1.104744  717868.0
# 2000  4820.107567  8.814844  2929.0  69676.0  2802.420042  3.704692  727528.0
#
#          299398       301775    301905    302862      303063       305440  \
# 1999  8429112.0  1584.463443  0.823372  757989.0  12398691.0  1321.799713
# 2000  8562622.0  1451.290776  1.462189  770437.0  12628596.0  1428.183004
#
#         305570     306527      306728       309105    309235    310192  \
# 1999  0.290445  4621066.0  68626664.0  2139.793967  0.845429  345715.0
# 2000  0.641265  4773923.0  69905988.0  2238.401016  1.177397  345491.0
#
#          310393       312770    312900   313857    314058      316435  \
# 1999  5825187.0  1052.852818  0.097416  22094.0  589938.0  208.620975
# 2000  5867626.0  1702.684901  0.132355  24225.0  614323.0  208.196949
#
#         316565    317522     317723       320100     320230   321187  \
# 1999  0.025495       NaN  3302263.0  4119.347394        NaN  60612.0
# 2000  0.136712  377514.0  3392801.0  4070.032827  28.576954  60980.0
#
#          321388      323765    323895     324852      325053        327430  \
# 1999  1390244.0  119.134082  0.012542  2597565.0  64640054.0  23982.880671
# 2000  1396985.0  123.876206  0.015264  2725399.0  66537331.0  22479.578988
#
#          327560   328718       331095    331225   332182    332383  \
# 1999        NaN      NaN  2408.165466  0.942462  53255.0  806494.0
# 2000  32.916392  47258.0  2076.013308  1.496855  53711.0  811223.0
#
#             334760     334890    335847     336048        338425     338555  \
# 1999  26178.791785        NaN  200079.0  5165474.0  24799.296010   9.125318
# 2000  24253.250425  37.248462  200417.0  5176209.0  22465.641841  14.307924
#
#          339512      339713        342090    342220    343378       345755  \
# 1999  2319498.0  60496715.0  16299.564154  3.448900  232952.0  3883.325188
# 2000  2346482.0  60912498.0  14530.777204  6.357064  237258.0  4116.460693
#
#         345885   346842     347043      349420    349550   350507     350708  \
# 1999  0.249010  72283.0  1200773.0         NaN  0.715827  77025.0  1195420.0
# 2000  1.216141  74745.0  1231122.0  635.563758  0.921795  79596.0  1231844.0
#
#           353085    353215    354172     354373        356750     356880  \
# 1999  628.865652  0.416344  151530.0  4452500.0  26795.991132        NaN
# 2000  691.997710  0.484746  152227.0  4418300.0  23718.746699  30.216347
#
#          357837      358038      360415    360545     361502      361703  \
# 1999  2673582.0  82100243.0  417.767991  0.104895  1584242.0  18477612.0
# 2000  2722950.0  82211508.0  263.112468  0.153615  1625014.0  18938762.0
#
#          364210  365167   365368        367745    367875    368832  \
# 1999   5.936978     NaN  30991.0  13245.189463  6.877292  447978.0
# 2000  19.131638     NaN  31180.0  12042.953731  9.138837  436805.0
#
#           369033        371410     371540   372698       375075    375205  \
# 1999  10761698.0  20170.438416        NaN  56100.0  4751.575978  2.473166
# 2000  10805808.0  19004.107291  31.747811  56200.0  5117.589923  4.063908
#
#       376162    376363  378740     378870    380028       382405    382535  \
# 1999  4743.0  101442.0     NaN   8.497176       NaN  1608.692890  0.592653
# 2000  4900.0  101619.0     NaN  16.113127  155329.0  1655.596261  0.712333
#
#         383492      383693      386070    386200    387157     387358  \
# 1999  534069.0  11387203.0  399.973964  0.060809  498630.0  8653769.0
# 2000  545670.0  11650743.0  340.051692  0.095425  511226.0  8808546.0
#
#           389735    389865   390822     391023      393400    393530   394487  \
# 1999  183.853011  0.117702  55089.0  1220794.0  919.866577  3.966355  29864.0
# 2000  297.751944  0.230103  57256.0  1243229.0  946.059937  6.611492  28355.0
#
#         394688      397065    397195    398152     398353       400730  \
# 1999  755278.0  494.232421  0.070658       NaN  8404398.0   845.108823
# 2000  753301.0  462.480652  0.231271  794318.0  8549200.0  1088.783165
#
#         400860    401817     402018        404395     404525    405482  \
# 1999  0.573575  287288.0  6357221.0  25091.666600        NaN  357993.0
# 2000  1.203856  293220.0  6524283.0  25756.663778  27.827761  365300.0
#
#          405683       408060    408190    409147      409348        411725  \
# 1999  6606500.0  4802.958760  5.857841  570080.0  10237530.0  32198.908579
# 2000  6665000.0  4633.312923  6.999676  536928.0  10210971.0  31813.373441
#
#       411855   412812    413013      415390    415520      416477  \
# 1999     NaN  17038.0  277381.0  437.586118  0.273224  86498432.0
# 2000     NaN  17127.0  281205.0  438.864630  0.527532  88120752.0
#
#             416678      419055    419185      420142       420343  \
# 1999  1.034539e+09  714.545331  0.444416  13199231.0  208612556.0
# 2000  1.053051e+09  830.584588  0.925564  13336636.0  211540429.0
#
#            422720    422850     423807      424008  426385  426515     427472  \
# 1999  1749.827783  0.378569  6948034.0  65062660.0     NaN     NaN  1537893.0
# 2000  1657.169748  0.934190  7150982.0  66131854.0     NaN     NaN  1571638.0
#
#           427673        430050     430180    431137     431338        433715  \
# 1999  22878156.0  26284.304776  10.933809  141931.0  3754786.0  21784.879598
# 2000  23565413.0  26241.514513  17.850467  141654.0  3805174.0  21551.779359
#
#        435003        437380     437510    438467     438668        441045  \
# 1999  71952.0  19133.048198  13.436122  313608.0  6125000.0  21936.823129
# 2000  72554.0  21042.981600  20.873790  315701.0  6289000.0  20051.242155
#
#          441175     442132      442333       444710    444840    445797  \
# 1999  14.378410        NaN  56916317.0  3338.200840  2.355689  103059.0
# 2000  23.110874  3055682.0  56942108.0  3360.870402  3.115778  103622.0
#
#          445998        448375    448505     449462       449663       452040  \
# 1999  2634882.0  36026.556075       NaN  4604920.0          NaN  1624.979100
# 2000  2656864.0  38532.040875  29.99074  4497368.0  126843000.0  1657.889256
#
#         452170    453127     453328       455705    455835    456792  \
# 1999  2.526965  219328.0  5014899.0  1130.113592  0.464277  562940.0
# 2000  2.623275  224871.0  5103130.0  1229.000958  0.668594  562240.0
#
#           456993      459370    459500     460457      460658      463035  \
# 1999  14928426.0  421.432885  0.114256  3061139.0  30600397.0  832.054794
# 2000  14883626.0  403.979713  0.318060  3148487.0  31450483.0  796.793763
#
#         463165  464122   464323  466830     467787      467988        470365  \
# 1999  1.211578  5392.0  82966.0     0.0  1151475.0  22731985.0  10409.326888
# 2000  1.785225  5603.0  84406.0     0.0  1166580.0  22929075.0  11947.579128
#
#       470495     471452      471653       474030     475318        477695  \
# 1999     NaN        NaN  46616677.0          NaN  1762000.0  15391.345736
# 2000    44.7  2177283.0  47008111.0  1087.762401  1700000.0  18389.384328
#
#         477825    478782     478983      481360    481490    482447  \
# 1999  4.756222  109808.0  1957066.0  258.049340  0.204711  199863.0
# 2000  6.731396  114887.0  2050741.0  279.620523  1.041401  205991.0
#
#          482648      485025    485155    486112     486313       488690  \
# 1999  4840400.0  277.495103  0.037781  352019.0  5241284.0  3151.325802
# 2000  4898400.0  324.845050  0.111044  364219.0  5329304.0  3352.731296
#
#         488820    489777     489978       492355    492485    493442  \
# 1999  4.387409  102841.0  2390482.0  5509.346429  5.376809  184722.0
# 2000  6.319062  104843.0  2367550.0  5334.903329  7.952744  185714.0
#
#          493643      496020    496150   497107     497308      499685  \
# 1999  3156646.0  493.249377  0.053804  87721.0  1850527.0  161.564122
# 2000  3235366.0  474.819791  0.211806  88986.0  1868699.0  183.414999
#
#         499815    500772     500973       503350    503480    504437  \
# 1999  0.011329  173722.0  2734518.0  6821.312519  0.133617  363434.0
# 2000  0.017703  185658.0  2884522.0  7145.628494  0.187043  365615.0
#
#          504638        507015    507145  508102   508303       510680  \
# 1999  5274163.0  81116.439165       NaN     NaN  32842.0  3113.546428
# 2000  5355751.0  74624.559959  36.51523     NaN  33286.0  3297.354701
#
#         510810    511767     511968        514345     514475   515432  \
# 1999  2.923055  102015.0  3524238.0  51654.402795  17.387958  18829.0
# 2000  6.427067  103812.0  3499536.0  48735.995492  22.887328  19136.0
#
#         515633        518010     518140   519097    519298       521675  \
# 1999  430475.0  15505.278745   9.212005  18556.0  418604.0  1814.512523
# 2000  436300.0  15702.855528  13.608590  19859.0  427979.0  1854.145956
#
#         521805    522762     522963      525340    525470    526427  \
# 1999  1.497330  135377.0        NaN  243.252751  0.168609  901109.0
# 2000  2.485566  136439.0  2034819.0  245.939066  0.196395  919153.0
#
#           526628      529005    529135    530092      530293       532670  \
# 1999  15282521.0  160.798877  0.087279  471638.0  11044356.0  3493.465229
# 2000  15766806.0  153.259487  0.126781  488904.0  11376172.0  4045.170471
#
#          532800     533757      533958       536335    536465   537422  \
# 1999        NaN  1833160.0  22656286.0  2104.427691  1.119909  14058.0
# 2000  21.384731  1869556.0  23185608.0  2182.997011  2.203873  14792.0
#
#         537623      540000    540130    541087      541288        543665  \
# 1999  280000.0  322.538680  0.060910  694223.0  10663723.0  10648.988896
# 2000  286000.0  269.348383  0.142546  714223.0  10967690.0  11039.056507
#
#          543795   544752    544953       547330    547460  548417   548618  \
# 1999   7.759798  11754.0  387578.0  2073.367384  0.966072  5674.0  52079.0
# 2000  13.113709  11682.0  390087.0  2126.913860  1.534272  5910.0  52159.0
#
#           550995    551125    552082     552283       554660    554790  \
# 1999  534.715944  0.118464  169416.0  2628803.0  3651.232286  4.652213
# 2000  477.476102  0.192031  174048.0  2709359.0  3861.032414  7.281535
#
#        555747     555948       558325    558455     559412       559613  \
# 1999  80899.0        NaN  5777.231681  1.857436  6367056.0  100300579.0
# 2000  79404.0  1186873.0  6720.902113  5.081384  6397627.0  101719673.0
#
#            561990    562120   563077    563278      565655    565785  \
# 1999  2046.639645  2.797594  11180.0  107816.0  321.026796  0.600695
# 2000  2170.920210  3.734862  11256.0  107432.0  354.003732  1.282846
#
#         566742     566943        569320     569450   570608      572985  \
# 1999  134074.0  3647001.0  91383.940493        NaN  31800.0  445.006943
# 2000  140836.0  3639592.0  82534.873767  42.184863  32082.0  474.213336
#
#         573115    574072     574273       576650  576780   577737    577938  \
# 1999  0.508472  103965.0  2376162.0          NaN     NaN  39430.0  606001.0
# 2000  1.255652  105247.0  2397436.0  1627.042893     NaN  39729.0  604950.0
#
#            580315    580445     581402      581603      583980    584110  \
# 1999  1444.989055  0.175595  1966217.0  28514798.0  301.539472  0.056251
# 2000  1332.382358  0.693791  1998356.0  28849621.0  277.648659  0.109593
#
#         585067      585268     587645    587775     588732      588933  \
# 1999  774784.0  17584869.0        NaN  0.000152        NaN  45539435.0
# 2000  793098.0  18067687.0  193.18748       NaN  2136260.0  46095462.0
#
#            591310    591440   592397     592598  596062      598640    598770  \
# 1999  2055.364975  0.336218  78441.0  1858042.0   416.0  215.980592  0.146669
# 2000  2057.995057  1.644740  79413.0  1899257.0   415.0  231.425500  0.204652
#
#          599727      599928        602305     602435    603392      603593  \
# 1999  2005958.0  23305994.0  27951.734289        NaN  542381.0  15812088.0
# 2000  2046545.0  23740911.0  25921.127941  43.984351  547275.0  15925513.0
#
#             605970     606100    607258        609635     609765    610722  \
# 1999  14611.832803   5.688147  209214.0  15322.088513  41.494483       NaN
# 2000  12579.595106  13.939549  213230.0  13641.102718  47.379557  168973.0
#
#          610923       613300    613430    614387     614588      616965  \
# 1999  3835100.0   981.020489  0.497902       NaN  4949660.0  184.346477
# 2000  3857700.0  1016.020743  0.980216  243472.0  5026796.0  158.405597
#
#         617095    618052      618253      620630    620760     621717  \
# 1999  0.028136  589312.0  10947829.0  300.609008  0.041039  7896140.0
# 2000  0.036261  598346.0  11352973.0  379.119326  0.064081  8091424.0
#
#            621918  624295   625583        627960  628090    629047     629248  \
# 1999  119327073.0     NaN  67755.0  36371.395788     NaN  157125.0  4461913.0
# 2000  122352009.0     NaN  69094.0  38146.715392    52.0  157438.0  4490967.0
#
#            631625    631755    632712     632913      635290    635420  \
# 1999  6967.059664  2.515666  147861.0  2254918.0  465.075766  0.055357
# 2000  8601.185906  3.520421  147454.0  2267991.0  533.862411       NaN
#
#           636377       636578       638955  639085  640042   640243  \
# 1999         NaN  135405584.0  6011.176439     NaN     NaN  18879.0
# 2000  12600461.0  138523285.0  7709.653194     NaN     NaN  19175.0
#
#            642620    642750    643707     643908      646285    646415  \
# 1999  4082.614583  3.836865  175840.0  2971197.0  640.286085  0.667113
# 2000  4060.299035  6.554796  177594.0  3030347.0  631.946853  0.835249
#
#         647372     647573       649950    650080    651037     651238  \
# 1999  224893.0  5430479.0  1614.903106  0.381657       NaN  5196937.0
# 2000  228913.0  5572222.0  1545.626423  0.747631  358469.0  5302700.0
#
#            653615    653745     654702      654903       657280    657410  \
# 1999  1963.410567  1.952498        NaN  25561299.0  1087.237365  1.431609
# 2000  1996.719689  3.076431  1090526.0  25914879.0  1038.910977  1.982253
#
#          658367      658568       660945    661075     662032      662233  \
# 1999  1653838.0  76335812.0  4389.976415  5.456444  2709610.0         NaN
# 2000  1693023.0  77991569.0  4492.727604  7.285429  2725182.0  38258629.0
#
#             664610     664740    665697      665898        668275     668405  \
# 1999  12474.818082  14.742338       NaN         NaN  15220.979237   5.265683
# 2000  11502.396813  16.430468  419652.0  10289898.0  16192.129596  10.474648
#
#         669362     669563        671940    672070   673027    673228  \
# 1999  190648.0  3800081.0  21763.450976  4.070729  24048.0  569447.0
# 2000  189094.0  3810605.0  29986.290153  4.863679  25190.0  592267.0
#
#            675605    675735     676692      676893       679270    679400  \
# 1999  1610.134370  2.697580  1418934.0  22472040.0  1330.751464  1.018985
# 2000  1668.162731  3.613717  1380733.0  22442971.0  1771.586602  1.977230
#
#          680357       680558      682935    683065    684022     684223  \
# 1999  4778481.0          NaN  239.378127  0.067176       NaN  7593239.0
# 2000  4874976.0  146596557.0  216.172747  0.062831  565358.0  8025703.0
#
#            686600    686730   687687    687888        690265     690395  \
# 1999  1489.647875  0.285308  19152.0  173755.0  44862.894513        NaN
# 2000  1540.689023  0.566393  19127.0  174610.0  40188.820185  48.799495
#
#       691352   691553  693930    694060  695017    695218       697595  \
# 1999     NaN  27096.0     NaN  0.363203  9068.0  135886.0  7968.548574
# 2000     NaN  27418.0     NaN  4.638517  8886.0  138606.0  9126.954277
#
#         697725     698682      698883      701260    701390    702347  \
# 1999  0.493585  1212629.0  20294406.0  533.285122  0.311091  614331.0
# 2000  2.210692  1192267.0  20764312.0  473.450034  0.403967  631104.0
#
#          702548       704925  705055    706012     706213       708590  \
# 1999  9645957.0  2441.430389     NaN  405712.0  7540401.0  7747.612159
# 2000  9884052.0   870.136525     NaN  406098.0  7516346.0  7578.851053
#
#         708720  709677   709878      712255    712385    713342     713543  \
# 1999  6.229055  6433.0  80410.0  150.836972  0.048491  260452.0  4437803.0
# 2000  7.395629  6517.0  81131.0  139.314773  0.118254  266870.0  4564297.0
#
#             715920  716050     717208   720873       723250    723380  \
# 1999  21795.696957     NaN  3958723.0  31084.0  5636.579532  5.437758
# 2000  23792.607070    36.0  4027887.0  30519.0  5402.929754  9.426803
#
#         724337     724538        726915     727045    728002     728203  \
# 1999  368378.0  5396020.0  11441.997025  12.610938  115704.0  1983045.0
# 2000  361720.0  5388720.0  10227.736770  15.110260  113059.0  1988925.0
#
#            730580    730710   731667    731868  734245   734375    735332  \
# 1999  1200.917702  0.494541  35688.0  401538.0     NaN  0.01391  581019.0
# 2000  1054.518572  0.481297  36293.0  412609.0     NaN  0.02000  602116.0
#
#          735533       737910   738040     738997      739198  741575  742662  \
# 1999  8720231.0  3088.863784  4.11625        NaN  44233730.0     NaN     NaN
# 2000  9011479.0  3037.225030  5.34856  2784760.0  44896856.0     NaN     NaN
#
#          742863        745240     745370     746327      746528      748905  \
# 1999  6362201.0  15678.215235   7.085040  1119161.0  40386875.0  844.826671
# 2000  6652984.0  14676.706088  13.624961  1066288.0  40567864.0  875.412178
#
#         749035     749992      750193       752570   752700  753657   753858  \
# 1999  0.348414        NaN  18532000.0  8700.348672  4.40044  1782.0  44824.0
# 2000  0.647410  1477039.0  18655000.0  9267.754831  5.86281  1787.0  45374.0
#
#            756235    756365  757322    757523   761188       763565    763695  \
# 1999  5000.482141  1.932106  6461.0  155172.0  29305.0  3621.794106  2.782002
# 2000  4996.267719  5.090483  6629.0  156949.0  28384.0  3672.635267  3.245037
#
#       764652    764853      767230    767360     768317      768518  \
# 1999  4759.0  107880.0  323.571795  0.008795  1844205.0  26607042.0
# 2000  4698.0  107898.0  361.030584  0.025785  1874622.0  27250535.0
#
#            770895    771025   771982    772183       774560    774690  \
# 1999  1896.013914  1.891871  17045.0  467003.0  1480.338095  0.470718
# 2000  1888.618290  2.506411  17704.0  472390.0  1637.450072  0.926192
#
#        775647     775848        778225     778355    779312     779513  \
# 1999      NaN  1045629.0  30577.081774        NaN  297614.0  8857874.0
# 2000  53773.0  1061468.0  29283.005046  45.687652  297926.0  8872109.0
#
#             781890  782020    782977     783178       785555    785685  \
# 1999  40581.307052     NaN  321729.0  7143991.0   991.120429  0.124295
# 2000  37868.323060    47.1  326620.0  7184250.0  1177.629268  0.181699
#
#          786642      786843      789220    789350    790307     790508  \
# 1999        NaN  16016092.0  177.692172  0.032792       NaN  6114886.0
# 2000  1182474.0  16410848.0  138.436603  0.048600  269205.0  6216205.0
#
#           792885    793015     793972      794173       796550    796680  \
# 1999  299.786754  0.075131  1385855.0  33291540.0  2032.992147  2.426242
# 2000  306.723827  0.117194  1423926.0  34178042.0  2007.564826  3.689041
#
#          797637      797838      800215  800345   801302    801503  \
# 1999  3335355.0  62306651.0         NaN     NaN  52025.0  863269.0
# 2000  3306936.0  62958021.0  402.006653     NaN  55414.0  871607.0
#
#           803880    804010    804967     805168       807545    807675  \
# 1999  326.604070  0.590363  314626.0  4825704.0  2015.418170  1.017967
# 2000  260.393294  0.800000  324428.0  4970367.0  2063.207236  2.434398
#
#       808632   808833       811210    811340   812297     812498       814875  \
# 1999  4819.0  97591.0  5383.552427  5.814251  59088.0  1264775.0  2389.036036
# 2000  4693.0  98082.0  6430.947262  7.721411  59503.0  1267984.0  2213.914088
#
#         815005    815962     816163       818540    818670     819627  \
# 1999  1.602495  818537.0  9603742.0  4108.127878  2.292118  3906747.0
# 2000  2.750740  829955.0  9699197.0  4316.553895  3.761685  3904682.0
#
#           819828      822205    822335    823292     823493   827158  \
# 1999  62287326.0  548.726876  0.045021  189378.0  4466132.0  17864.0
# 2000  63240121.0  643.175011  0.133282  195311.0  4516131.0  18873.0
#
#            829535   829665  830622  830823      833200    833330     834287  \
# 1999  1464.648593      NaN     NaN  9345.0  257.747800  0.105544   986150.0
# 2000  1458.817097  5.24164   456.0  9420.0  257.630361  0.163714  1021054.0
#
#           834488      836865    836995     837952      838153        840530  \
# 1999  23272995.0  635.766242  0.405385  1540275.0  49673350.0  28260.005017
# 2000  24039274.0  635.708964  0.716184  1529637.0  49175848.0  33071.268687
#
#          840660    841617     841818        844195     844325     845282  \
# 1999  14.942699  117391.0  2988162.0  28383.668905        NaN        NaN
# 2000  23.625301  116575.0  3154925.0  27982.355764  26.821754  2918478.0
#
#           845483        847860     847990      848947       849148  \
# 1999  58682466.0  34620.928899        NaN         NaN  279040000.0
# 2000  58892514.0  36449.855116  43.079163  12080275.0  282162411.0
#
#            851525     851655    852612     852813      855190    855320  \
# 1999  7247.398162   9.972765  152000.0  3309318.0  702.480744  0.030688
# 2000  6871.897677  10.539058  151710.0  3321245.0  558.221144  0.484347
#
#          856277      856478       858855    858985   859942    860143  \
# 1999  1029117.0  24311650.0  1477.841822  0.538300  12052.0  181345.0
# 2000  1064979.0  24650400.0  1469.849149  2.108337  12365.0  185063.0
#
#            862520    862650     863607      863808      866185    866315  \
# 1999  4077.496123  2.839826        NaN  24028689.0  374.476433  0.128927
# 2000  4783.530592  3.359597  1003049.0  24488340.0  401.547817  0.254248
#
#          867272      867473  869850     869980    871138       873515  \
# 1999  4961174.0  76596700.0     NaN  11.074606  108596.0  1499.492177
# 2000  5052437.0  77630900.0     NaN  13.815081  108639.0  1476.171850
#
#         873645    874602     874803      877180    877310     878267  \
# 1999       NaN  128377.0  2848431.0  439.697211  0.056629  1158625.0
# 2000  1.111306  133190.0  2922153.0  539.104365  0.082500  1210589.0
#
#           878468      880845    880975    881932      882133      884510  \
# 1999  17378098.0  332.461627  0.147053  696965.0  10239714.0  568.443953
# 2000  17874725.0  341.905562  0.191072  713675.0  10531221.0  547.358878
#
#         884640     885597      885798
# 1999  0.161676        NaN  12064537.0
# 2000  0.401434  1301540.0  12222251.0

# %%
# Proportion de valeurs nulles
prop_nan_df_temps_T_o = df_temps_T_o.isna().sum().sum(
)/(df_temps_T_o.shape[0]*df_temps_T_o.shape[1])*100
print('Il y a {:.2f}% de NaN.'.format(prop_nan_df_temps_T_o))
# Out:
# Il y a 3.38% de NaN.

# %%
# Transposé de la transposé
df_temps_T_o_T=df_temps_T_o.T
df_temps_T_o_T.head(2)
# Out:
#              1999         2000         2001         2002         2003  \
# 1245  2332.064342  2615.682751  2515.077869  2499.335429  2754.304985
# 1375     0.598582     1.139541     1.561288     2.693061     3.645881
#
#              2004         2005         2006         2007         2008  \
# 1245  3168.186426  3796.021804  4414.093398  5046.817058  6255.761156
# 1375     7.006812     8.393142    11.654648    14.205902    18.593531
#
#              2009         2010         2011         2012         2013  2014  \
# 1245  5267.552563  6032.961957  7005.479541  7571.402403  7715.998677   NaN
# 1375    22.973689    26.747251    29.707761    34.014224    36.868602   NaN
#
#       2015
# 1245   NaN
# 1375   NaN

# %%
# Interpolation sur les années
df_temps_T_o_T.interpolate(method="linear", axis=1, limit=6, limit_direction="both", inplace=True)

# %% [markdown]
# Les valeurs manquantes restantes sont imputées le long des années (axis = 1) par interpolation linéaire. Une limite de 6 a été selectionnée pour obtenir un proportion de valeur nulle la plus faible possible (voir ci-dessous). Au delà de 6, il n'y a pas de différence significative au niveau des graphiques générés plus loin.
#
# - 'linear': Ignore the index and treat the values as equally spaced
# - 'limit': Maximum number of consecutive NaNs to fill. Must be greater than 0
# - 'limit_direction': If limit is specified, consecutive NaNs will be filled in this direction

# %%
# Forme des datasets
print(df_clés.shape)
print(df_temps_T_o_T.shape)
# Out:
# (968, 4)
# (927, 17)

# %%
# Regroupement interne des deux datasets intermédiaires par leurs indexes
df = pd.concat([df_clés, df_temps_T_o_T], axis=1, join='inner')

# %%
# Proportion de valeurs nulles
prop_nan_df = df.isna().sum().sum()/(df.shape[0]*df.shape[1])*100
print('Il y a {:.2f}% de NaN.'.format(prop_nan_df))
# Out:
# Il y a 0.30% de NaN.

# %% [markdown]
# # 3. Analyse des indicateurs

# %% [markdown]
# Dans cette partie les indicateurs sont analysées. Il s'est avéré qu'il était plus judicieux d'analyser certains uniquement par continents, d'autres uniquement par pays et parfois les deux.
#
# Trois types de graphiques (boxplot, histogramme et lineplot) et une carte choroplèthe ont été crées.
#
# Les histogrammes crées prennent en compte l'année 2015. Les boxplots prennent en compte l'ensemble de la période de temps étudié allant de 1999 à 2015. Enfin concernant l'analyse par pays, sont pris en compte les 10 premiers pays ayant eu pour l'année 2015 la valeur la plus haute de l'indicateur étudié.

# %% [markdown]
# ### 3.1 Méthodologie

# %% [markdown]
# Création des fonctions permettant de générer les graphiques pour l'analyse par pays ou par continents ainsi que les cartes choroplèthes

# %%
# Dataset continent et pays
df_cont=df[df['Country Name'].isin(liste_continents)]
df_pays=df[df['Country Name'].isin(liste_pays)]

# %%
# Fonction pour un indicateur - analyse par continent

def plot_cont(indicator, title_barplot, xlabel_barplot, title_boxplot,
              xlabel_boxplot, title_lineplot, ylabel_lineplot):

    # Filtrage de dataset continent par indicateur
    df_cont_ind = df_cont[df_cont["Indicator Name"] == indicator]

    # Mise en place d'une condition si l'indicateur analysé n'est pas pris en compte
    if df_cont_ind.empty == True:
        print('Indicateur \'{}\' non pris en compte pour l\'analyse par continent'.format(
            indicator))
    else:
        # Barplot du dataset continent de l'indicateur pour 2015

        plt.figure(figsize=(8, 4))
        plt.style.use('ggplot')
        sns.barplot(x='2015', y='Country Name',
                    data=df_cont_ind.sort_values(by=['2015'], ascending=False))
        plt.title(title_barplot)
        plt.xticks(rotation=0)
        plt.ylabel("Continent")
        plt.xlabel(xlabel_barplot)
        plt.show()

    # Changement d'index du dataset continent - indicateur
        series = df_cont_ind.set_index('Country Name')
        series.head(3)

    # Sélection des colonnes années et transposition
        seriesT = series.loc[:, '1999':'2015'].T

    # Boxplots du dataset continent pour l'indicateur sur l'ensemble de la période de temps étudié : 1999 à 2015
    # Trie des boxplots par leurs médianes

        ordre = seriesT.median()
        ordre.sort_values(ascending=False, inplace=True)
        seriesT_sorted = seriesT[ordre.index]
        plt.figure(figsize=(8, 4))
        plt.title(title_boxplot)
        sns.boxplot(data=seriesT_sorted, orient="h").set(
            xlabel=xlabel_boxplot, ylabel="Continent")

    # Changement d'index du dataset continent - indicateur
        df_cont_ind_set = df_cont_ind.set_index('Country Name')

        plt.figure(figsize=(8, 4))
        for country in df_cont_ind_set.index:
            df_cont_ind_plot = df_cont_ind_set.loc[country, '1999':'2015']
            plt.plot(df_cont_ind_plot.index,
                     df_cont_ind_plot.values, label=country)
        plt.title(title_lineplot)
        plt.xticks(rotation=45)
        plt.ylabel(ylabel_lineplot)
        plt.xlabel("Année")
        plt.style.use('ggplot')
        plt.legend(bbox_to_anchor=(1.05, 1),
                   loc='upper left', borderaxespad=0.)
        plt.show()

# %%
# Fonction pour un indicateur - analyse par pays

def plot_pays(indicator, title_barplot, xlabel_barplot, title_boxplot, xlabel_boxplot, title_lineplot, ylabel_lineplot):

    # Filtrage de dataset pays par indicateur test
    df_pays_ind = df_pays[df_pays["Indicator Name"] == indicator]

    # Mise en place d'une condition si l'indicateur analysé n'est pas pris en compte
    if df_pays_ind.empty == True:
        print('Indicateur \'{}\' non pris en compte pour l\'analyse par pays'.format(
            indicator))
    else:

        # Barplot du dataset pays de l'indicateur pour 2015 - affichage des 10 premiers pays avec l'indicateur 
        # le plus haut en 2015
        plt.figure(figsize=(8, 4))
        plt.style.use('ggplot')

        sns.barplot(x='2015', y='Country Name', data=df_pays_ind.sort_values(
            by=['2015'], ascending=False).head(10))

        plt.title(title_barplot)
        plt.xticks(rotation=45)
        plt.ylabel('Pays')
        plt.xlabel(xlabel_barplot)
        plt.show()

    # Changement d'index du dataset pays - indicateur test
        series_pays = df_pays_ind.set_index('Country Name')

    # Sélection des colonnes années et transposition
        series_paysT = series_pays.loc[:, '1999':'2015'].T

    # Boxplots des 10 premiers pays triés par leurs médianes
        ordre = series_paysT.median()
        ordre.sort_values(ascending=False, inplace=True)
        series_paysT = series_paysT[ordre.index]

        plt.figure(figsize=(8, 4))
        plt.title(title_boxplot)
        sns.boxplot(data=series_paysT.iloc[:, 0:10], orient="h").set(
            xlabel=xlabel_boxplot, ylabel='Pays')

    # Lineplot : Comparaison des évolutions de l'indicateur pour les 10 premiers pays
    # ayant eu l'indicateur analysé le plus élevé en 2015
        df_pays_ind_sorted = df_pays_ind.sort_values(
            by=['2015'], ascending=False).head(10)
        df_pays_ind_set_sorted = df_pays_ind_sorted.set_index('Country Name')

        fig = plt.figure(figsize=(8, 4))
        plt.style.use('ggplot')

        for country in df_pays_ind_set_sorted.index:
            df_pays_ind_plot = df_pays_ind_set_sorted.loc[country,
                                                          '1999':'2015']
            plt.plot(df_pays_ind_plot.index,
                     df_pays_ind_plot.values, label=country)
        plt.title(title_lineplot)

        plt.xticks(rotation=45)
        plt.ylabel(ylabel_lineplot)
        plt.xlabel("Année")
        plt.legend(bbox_to_anchor=(1.05, 1),
                   loc='upper left', borderaxespad=0.)
        plt.show()

# %%
# Dataframe world - Visualisation géospatiale de la map monde
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
print(world.head(2))
# Out:
#     pop_est continent      name iso_a3  gdp_md_est  \
# 0    920938   Oceania      Fiji    FJI      8374.0
# 1  53950935    Africa  Tanzania    TZA    150600.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...

# %%
# Modification des valeurs erronnées du dataframe world
world['iso_a3'][43]='FRA'
world['iso_a3'][21]='NOR'
world['iso_a3'][174]='XKX'
# Out:
# C:\Users\valen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\valen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\valen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Fonction choropleth map avec colorbar pour un indicateur

def plot_map(indicator, title):

    # Projection de l'année 2015 par pays et indicateur
    df_map = df[df['Indicator Name'] ==
                indicator].loc[:, ['Country Code', '2015']]

    # Fusion des deux datasets en utilisant code/iso_a3 comme identifiants uniques
    for_plotting = world.merge(
        df_map, left_on='iso_a3', right_on='Country Code')

    # Package pour aligner verticalement les axes du graphe avec celui de la légende
    from mpl_toolkits.axes_grid1 import make_axes_locatable

    # Création de la figure et des axes avec Matplotlib
    fig, ax = plt.subplots(1, 1, figsize=(16, 16))
    divider = make_axes_locatable(ax)

    # Création de la colorbar
    cax = divider.append_axes("right", size="5%", pad=0.1)

    # Création de la carte
    for_plotting.dropna().plot(column='2015', cmap='YlGnBu',
                               figsize=(15, 9), ax=ax, legend=True, cax=cax)

    # Titre de la carte
    ax.set_title(title, fontdict={'fontsize': 25})

    # Retrait des axes
    ax.set_axis_off()

    # Exportation de la carte
    fig.savefig('map_export.png', dpi=300)

# %% [markdown]
# "Un indicateur est une variable qui décrit un élement de situation ou une évolution d'un point de vue quantitatif. C'est un outil d'aide à la décision, dont l'utilisation s'inscrit dans une démarche qui répond à un objectif et se situe dans un contexte donnée. L'indicateur n'a d'intérêt que par les choix qu'il aide à faire dans ce cadre."

# %% [markdown]
# ### 3.2 Indicateur économique : Produit Intérieur Brut

# %%
# Graphiques indicateur économique

plot_cont(indicator='GDP per capita (current US$)',
          title_barplot='Produit Intérieur Brut par habitant en US$ - année 2015',
          xlabel_barplot='US$',
          title_boxplot='Produit Intérieur Brut par habitant en US$ entre 1999 et 2015',
          xlabel_boxplot='US$',
          title_lineplot='Evolution du Produit Intérieur Brut par habitant en US$ entre 1999 et 2015',
          ylabel_lineplot='US$')

# %%
# Carte indicateur économique

plot_map('GDP per capita (current US$)', 'Produit Intérieur Brut par habitant en US$ - année 2015')

# %% [markdown]
# L'Amérique du Nord possède le PIB le plus élevé. Il est nettement supérieur à ceux des autres continents quelque soit l'année.
# Le PIB de chaque continent n'a fait qu'augmenter entre 1999 et 2015. Par comparaison avec l'Europe/Asie Centrale et l'Amérique du Nord l'augmentation des PIB des autres continents n'est pas très significative.
#
# L'analyse par pays est plus contrastée. En effet des pays européens tels que la Suisse ou la Norvège ont un PIB par habitant plus élevé que les Etats-Unis.

# %% [markdown]
# ### 3.3 Indicateur technologique : Accès à internet

# %%
# Graphiques indicateur technologique

plot_cont(indicator='Internet users (per 100 people)',
          title_barplot='Couverture du réseau internet pour 100 habitants - année 2015',
          xlabel_barplot='%',
          title_boxplot='Couverture du réseau internet pour 100 habitants entre 1999 et 2015',
          xlabel_boxplot='%',
          title_lineplot='Evolution de la Couverture du réseau internet pour 100 habitants entre 1999 et 2015',
          ylabel_lineplot='%')

# %% [markdown]
# Entre 1999 et 2015 il y a eu une forte croissance de la couverture internet à travers le monde et en particulier pour l'Europe et l'Amérique du Nord qui arrivent en 2015 à des taux proches. De fortes variabilités sont observés pour l'Europe/Asie Centrale. L'Asie du Sud et l'Afrique Sub-Saharienne malgré une certaine croissance de leurs réseaux internet peinent à rivaliser avec les autres continents.

# %%
# Carte indicateur technologique

plot_map('Internet users (per 100 people)', 'Couverture du réseau internet pour 100 habitants - année 2015')

# %% [markdown]
# Il est clairement observé que les pays de l'hémisphère Nord ont une couverture internet plus élevé que l'autre hémisphère hormis l'Australie et la Nouvelle Zélande par exemple. Quelques pays d'Afrique se démarquent par rapport au reste du continents : Afrique du Sud et Maroc.

# %%
# Graphiques indicateur technologique : Focus sur les 10 premiers pays en 2015

plot_pays(indicator='Internet users (per 100 people)',
          title_barplot='Couverture du réseau internet pour 100 habitants - année 2015',
          xlabel_barplot='%',
          title_boxplot='Couverture du réseau internet pour 100 habitants entre 1999 et 2015 \n Classement par médiane décroissante',
          xlabel_boxplot='%',
          title_lineplot='Evolution de la Couverture du réseau internet pour 100 habitants entre 1999 et 2015',
          ylabel_lineplot='%')

# %% [markdown]
# Le lineplot et le barplot représentent les pays ayant eu la couverture internet la plus élevé en 2015. Sur la période de temps étudiée de fortes croissances sont observés. Ces 10 pays avaient tous en 1999 un taux en dessous de 60% puis ils ont évolué vers un taux proche de 90% - 100%. Ceci est particulièrement le cas pour les pays d'Europe du Nord.

# %% [markdown]
# ### 3.4 Indicateur démographique : Population totale

# %%
# Graphiques indicateur démographique

plot_cont(indicator='Population, total',
          title_barplot='Population mondiale - année 2015',
          xlabel_barplot='Nombre d\'habitant',
          title_boxplot='Population mondiale entre 1999 et 2015',
          xlabel_boxplot='Nombre d\'habitant',
          title_lineplot='Evolution de la Population mondiale entre 1999 et 2015',
          ylabel_lineplot='Nombre d\'habitant')

# %%
# Carte indicateur démographique - Population mondiale

plot_map('Population, total', 'Population mondiale - année 2015')

# %% [markdown]
# La population du continent asiatique (Nord et Est/Pacifique) et sub-africain a considérablement augmenté. La Chine et l'Inde sont en 2015 les deux pays les plus peuplés.

# %% [markdown]
# ### 3.5 Indicateur démographique : Population en âge pour l'éducation secondaire supérieure

# %%
# Carte indicateur démographique - Population mondiale

plot_map('Population of the official age for upper secondary education, both sexes (number)', 
         'Population en âge pour l\'éducation secondaire supérieure - année 2015')

# %% [markdown]
# La Chine et l'Inde en plus d'être les deux pays les plus peuplés possèdent la population de personnes en âge pour l'éducation secondaire supérieure la plus élevée en 2015.

# %% [markdown]
# # 4. Création d'un indicateur économique

# %% [markdown]
# Pour synthétiser l'ensemble des indicateurs sélectionnés un indicateur dit "indicateur projet" a été crée et cela uniquement pour l'année 2015.
#
# La création de cet indicateur est basée sur la formule de l'IDH : Indicateur de Développement Humain.
#
# Depuis 2011, la formule suivante est utilisée :
#
# $\text{IDH}=\sqrt[3]{I_{Vie} \times I_{\text{É}ducation} \times I_{Revenu}}$
#
# où$\ I_{Vie}$,$\ I_{\text{É}ducation}$ et$\ I_{Revenu}$, sont respectivement les indices de longévité, le niveau d'éducation et le niveau de revenu.
#
# L'IDH se fonde sur une moyenne géométrique. De plus le logarithme néperien est utilisé sur la composante Revenu. L'objectif est d'éviter qu'un très mauvais score sur l'une des composantes de l'indice puisse être intégralement compensé par un bon résultat sur une autre des composantes.
#
# Enfin chaque variable de la formule correspond à un indice dimensionnel dont la formule est appliqué à chaque indicateur.
#
# ${\text{Indice dimensionnel}} = \frac{\text{valeur r}\mathrm{\acute{e}}\text{elle - valeur minimale}}{\text{valeur maximale - valeur minimale}}$
#
#
#
# Source : https://fr.wikipedia.org/wiki/Indice_de_d%C3%A9veloppement_humain?veaction=edit&section=4
#
# La formule de l'indicateur projet est la suivante :
#
# $\ {I_{Projet-2015}}=\sqrt[3]{I_{Population} \times I_{GDP} \times I_{Internet}}$
#
# où$\ I_{Population}$,$\ I_{GDP}$ et$\ I_{Internet}$, sont respectivement les indices de la population en âge pour l'éducation secondaire supérieure, le Produit Intérieur Brut et le niveau de couverture internet pour l'année 2015.
#
# Le logarithme néperien est utilisé pour le calcul des indices dimensionnels pour les composantes GDP et Population en âge pour l'éducation secondaire supérieure.
#
# Ce nouvel indicateur sera projeté sur une carte choroplèthe permettant ainsi de visualiser les pays avec le potentiel de client le plus haut.

# %%
# Calcul des valeurs minimales et maximales

pop_min=df_pays[df_pays['Indicator Name']=='Population of the official age for upper secondary education, both sexes ''(number)']['2015'].min()
pop_max=df_pays[df_pays['Indicator Name']=='Population of the official age for upper secondary education, both sexes ''(number)']['2015'].max()

internet_min=df_pays[df_pays['Indicator Name']=='Internet users (per 100 people)']['2015'].min()
internet_max=df_pays[df_pays['Indicator Name']=='Internet users (per 100 people)']['2015'].max()

GDP_min=df_pays[df_pays['Indicator Name']=='GDP per capita (current US$)']['2015'].min()
GDP_max=df_pays[df_pays['Indicator Name']=='GDP per capita (current US$)']['2015'].max()

# %%
# Calcul des indices dimensionnels

I_GDP = (np.log(df_pays[df_pays['Indicator Name'] ==
                        'GDP per capita (current US$)']['2015'])
         - np.log(GDP_min))/(np.log(GDP_max)-np.log(GDP_min))

I_internet = ((df_pays[df_pays['Indicator Name'] ==
                        'Internet users (per 100 people)']['2015'])
         - internet_min)/(internet_max-internet_min)

I_pop = (np.log(df_pays[df_pays['Indicator Name'] ==
                        'Population of the official age for upper secondary education, both sexes ''(number)']['2015'])
         - np.log(pop_min))/(np.log(pop_max)-np.log(pop_min))

# %%
# Création du dataframe regroupant les trois indices selon le code pays

    # Concatenation avec la colonne 'Contry Code'
df_I_GDP = pd.concat([df_pays['Country Code'], I_GDP], axis=1, join='inner').set_index('Country Code')
df_I_internet = pd.concat([df_pays['Country Code'], I_internet], axis=1, join='inner').set_index('Country Code')
df_I_pop = pd.concat([df_pays['Country Code'], I_pop], axis=1, join='inner').set_index('Country Code')

df_I_GDP.rename(columns={"2015": "I_GDP_2015"}, inplace = True)
df_I_internet.rename(columns={"2015": "I_internet_2015"}, inplace = True)
df_I_pop.rename(columns={"2015": "I_pop_2015"}, inplace = True)

df_I_projet = pd.concat([df_I_GDP, df_I_internet, df_I_pop], axis=1, join='inner')

print(df_I_projet.head(5))
# Out:
#               I_GDP_2015  I_internet_2015  I_pop_2015
# Country Code
# AFG             0.100981         0.084008    0.696648
# ALB             0.406478         0.643314    0.479770
# DZA             0.415280         0.300030    0.679451
# AGO             0.396569         0.103739    0.670897
# ATG             0.603193         0.711935    0.165348

# %%
# Création du nouvel indicateur par application de la formule

df_I_projet['I_projet_2015'] = (df_I_projet['I_GDP_2015'] * df_I_projet['I_internet_2015'] * df_I_projet['I_pop_2015'])**(1/3)
print(df_I_projet.head(5))
# Out:
#               I_GDP_2015  I_internet_2015  I_pop_2015  I_projet_2015
# Country Code
# AFG             0.100981         0.084008    0.696648       0.180797
# ALB             0.406478         0.643314    0.479770       0.500608
# DZA             0.415280         0.300030    0.679451       0.439091
# AGO             0.396569         0.103739    0.670897       0.302208
# ATG             0.603193         0.711935    0.165348       0.414093

# %%
# Affichage de l'indicateur projet

df_I_projet.drop(['I_GDP_2015', 'I_internet_2015', 'I_pop_2015'], axis=1, inplace=True)

# %%
# Carte chloroplèthe de l'indicateur projet en 2015

# Fusion des deux datasets en utilisant code/iso_a3 comme identifiants uniques
for_plotting_2 = world.merge(
    df_I_projet, left_on='iso_a3', right_on='Country Code')

# Package pour aligner verticalement les axes du graphe avec celui de la légende
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Création de la figure et des axes avec Matplotlib
fig, ax = plt.subplots(1, 1, figsize=(16, 16))
divider = make_axes_locatable(ax)

# Création de la colorbar
cax = divider.append_axes("right", size="5%", pad=0.1)

# Création de la carte
for_plotting_2.dropna().plot(column='I_projet_2015', cmap='YlGnBu',
                           figsize=(15, 9), ax=ax, legend=True, cax=cax)

# Titre de la carte
ax.set_title('Pays à fort potentiel en 2015', fontdict={'fontsize': 25})

# Retrait des axes
ax.set_axis_off()

# %%
# Projection des 10 premiers pays à fort potentiel
df_I_projet.sort_values(by='I_projet_2015', ascending=False).round(2).head(10)
# Out:
#               I_projet_2015
# Country Code
# GBR                    0.81
# USA                    0.81
# JPN                    0.80
# DEU                    0.79
# CAN                    0.77
# FRA                    0.77
# KOR                    0.76
# NLD                    0.76
# CHE                    0.76
# NOR                    0.75

# %% [markdown]
# Les pays d'Europe de l'Ouest et d'Amérique du Nord présentent les meilleurs potentiels de client. Certains pays d'Asie tels que la Chine et l'Arabie Saoudite et enfin l'Amérique du Sud présentent aussi des potentiels intéressants en moindre mesure.

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# Au regard de la période de temps analysé (1999 - 2015) il y a fort à parier que la valeur de l'indicateur projet va croître dans les prochaines années et ce en particulier pour les pays occidentaux. Cependant l'Amérique du Sud et la Chine tendent à se démarquer et pourraient rattraper leurs retards.
#
# Même si l'année 2020 n'a pas pu être analysé de par le manque de données ; on peut émettre l'hypothèse qu'il n'y a pas eu de changement majeur entre 2015 et 2020.
#
# De ce fait, les pays européens et d'Amérique du Nord sont les principaux pays dans lesquels l'entreprise doit opérer.

# %% [markdown]
# # 6. Ouverture

# %% [markdown]
# Il serait utile de calculer l'indicateur $\ {I_{Projet}}$ pour toutes les années du dataset possédant suffisamment de données et ainsi créer une série temporelle. Un algorithme de prédiction pourrait être utilisé sur cette série pour déterminer le potentiel à venir de certains pays.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Sommaire" data-toc-modified-id="Sommaire-1">Sommaire</a></span></li><li><span><a href="#1.-Préparation-finale-du-dataset" data-toc-modified-id="1.-Préparation-finale-du-dataset-2">1. Préparation finale du dataset</a></span></li><li><span><a href="#2.-Définition-d'un-scoring-adapté-à-problématique-métier" data-toc-modified-id="2.-Définition-d'un-scoring-adapté-à-problématique-métier-3">2. Définition d'un scoring adapté à problématique métier</a></span></li><li><span><a href="#3.-Comparaison-de-plusieurs-Classifiers-et-definition-de-fonctions" data-toc-modified-id="3.-Comparaison-de-plusieurs-Classifiers-et-definition-de-fonctions-4">3. Comparaison de plusieurs Classifiers et definition de fonctions</a></span></li><li><span><a href="#4.-Optimization-des-performances---Logistic-Regression" data-toc-modified-id="4.-Optimization-des-performances---Logistic-Regression-5">4. Optimization des performances - Logistic Regression</a></span></li><li><span><a href="#4.1-Rebalancing-par-le-paramètre-du-classifier-class_weight-=-'balanced'" data-toc-modified-id="4.1-Rebalancing-par-le-paramètre-du-classifier-class_weight-=-'balanced'-6">4.1 Rebalancing par le paramètre du classifier class_weight = 'balanced'</a></span></li><li><span><a href="#4.2-Rebalancing-par-oversampling-de-la-classe-minoritaire-(SMOTE)" data-toc-modified-id="4.2-Rebalancing-par-oversampling-de-la-classe-minoritaire-(SMOTE)-7">4.2 Rebalancing par oversampling de la classe minoritaire (SMOTE)</a></span></li><li><span><a href="#4.3-Rebalancing-par-undersampling-de-la-classe-majoritaire" data-toc-modified-id="4.3-Rebalancing-par-undersampling-de-la-classe-majoritaire-8">4.3 Rebalancing par undersampling de la classe majoritaire</a></span></li><li><span><a href="#5.-Optimization-des-performances---Random-Forest-Classifier" data-toc-modified-id="5.-Optimization-des-performances---Random-Forest-Classifier-9">5. Optimization des performances - Random Forest Classifier</a></span></li><li><span><a href="#5.1-Rebalancing-par-le-paramètre-du-classifier-class_weight-=-'balanced'" data-toc-modified-id="5.1-Rebalancing-par-le-paramètre-du-classifier-class_weight-=-'balanced'-10">5.1 Rebalancing par le paramètre du classifier class_weight = 'balanced'</a></span></li><li><span><a href="#5.2-Rebalancing-par-oversampling-de-la-classe-minoritaire-SMOTE" data-toc-modified-id="5.2-Rebalancing-par-oversampling-de-la-classe-minoritaire-SMOTE-11">5.2 Rebalancing par oversampling de la classe minoritaire SMOTE</a></span></li><li><span><a href="#5.3-Rebalancing-par-undersampling-de-la-classe-majoritaire" data-toc-modified-id="5.3-Rebalancing-par-undersampling-de-la-classe-majoritaire-12">5.3 Rebalancing par undersampling de la classe majoritaire</a></span></li><li><span><a href="#6.-Optimization-des-performances---LGBM-Classifier" data-toc-modified-id="6.-Optimization-des-performances---LGBM-Classifier-13">6. Optimization des performances - LGBM Classifier</a></span></li><li><span><a href="#6.1-Rebalancing-par-le-paramètre-du-classifier-class_weight-=-'balanced'" data-toc-modified-id="6.1-Rebalancing-par-le-paramètre-du-classifier-class_weight-=-'balanced'-14">6.1 Rebalancing par le paramètre du classifier class_weight = 'balanced'</a></span></li><li><span><a href="#6.2-Rebalancing-par-oversampling-de-la-classe-minoritaire" data-toc-modified-id="6.2-Rebalancing-par-oversampling-de-la-classe-minoritaire-15">6.2 Rebalancing par oversampling de la classe minoritaire</a></span></li><li><span><a href="#6.3-Rebalancing-par-undersampling-de-la-classe-majoritaire" data-toc-modified-id="6.3-Rebalancing-par-undersampling-de-la-classe-majoritaire-16">6.3 Rebalancing par undersampling de la classe majoritaire</a></span></li><li><span><a href="#7.-Analyse-des-résultats" data-toc-modified-id="7.-Analyse-des-résultats-17">7. Analyse des résultats</a></span></li><li><span><a href="#8.-Interprétabilité-du-modèle" data-toc-modified-id="8.-Interprétabilité-du-modèle-18">8. Interprétabilité du modèle</a></span><ul class="toc-item"><li><span><a href="#8.1-Analyse-globale-du-modèle:-importance-des-variables" data-toc-modified-id="8.1-Analyse-globale-du-modèle:-importance-des-variables-18.1">8.1 Analyse globale du modèle: importance des variables</a></span></li><li><span><a href="#8.2-Analyse-locale-du-modèle:-SHAP" data-toc-modified-id="8.2-Analyse-locale-du-modèle:-SHAP-18.2">8.2 Analyse locale du modèle: SHAP</a></span><ul class="toc-item"><li><span><a href="#Préparation-du-modèle" data-toc-modified-id="Préparation-du-modèle-18.2.1">Préparation du modèle</a></span></li><li><span><a href="#Summary-Plot" data-toc-modified-id="Summary-Plot-18.2.2">Summary Plot</a></span></li><li><span><a href="#Force-Plot" data-toc-modified-id="Force-Plot-18.2.3">Force Plot</a></span></li></ul></li></ul></li></ul></div>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import os

import warnings
warnings.filterwarnings('ignore')

# %%
# Fonction pour réduire l'utilisation de la mémoire par le dataframe consolidé

def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type to reduce memory usage        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
# Import du dataframe consolidé et réduction de la taille de la mémoire

data_red = pd.read_csv("data_clean.csv", parse_dates=True, keep_date_col=True)
data_red = reduce_mem_usage(data_red)
# Out:
# Memory usage of dataframe is 535.45 MB
# Memory usage after optimization is: 83.24 MB
# Decreased by 84.5%

# %%
data_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356255 entries, 0 to 356254
# Columns: 197 entries, SK_ID_CURR to TARGET
# dtypes: float16(31), float32(4), int16(2), int32(1), int8(159)
# memory usage: 83.2 MB

# %%
# Chargement des modules

from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score, fbeta_score
from sklearn.metrics import precision_score, recall_score, roc_auc_score
from sklearn.dummy import DummyClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
import lightgbm as lgb
from sklearn.svm import SVC

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler, NearMiss 
from collections import Counter

import pickle 

plt.style.use('ggplot')

# %% [markdown]
# # Sommaire
#
# [1. Préparation finale du dataset](#section1)
#
#
# [2. Définition d'un scoring adapté à problématique métier](#section2)
#
#
# [3. Comparaison de plusieurs Classifiers et definition de fonctions](#section3)
#
#
# [4. Optimization des performances - Logistic Regression ](#section4)
#
# * [4.1 Rebalancing par le paramètre du classifier class_weight = 'balanced' ](#section4.1)
# * [4.2 Rebalancing par oversampling de la classe minoritaire SMOTE](#section4.2)
# * [4.3 Rebalancing par undersampling de la classe majoritaire](#section4.3)
#
#
# [5. Optimization des performances - RandomForestClassifier ](#section5)
#
# * [5.1 Rebalancing par le paramètre du classifier class_weight = 'balanced' ](#section5.1)
# * [5.2 Rebalancing par oversampling de la classe minoritaire SMOTE](#section5.2)
# * [5.3 Rebalancing par undersampling de la classe majoritaire](#section5.3)
#
#
# [6. Optimization des performances - LGBM Classifier ](#section6)
#
# * [6.1 Rebalancing par le paramètre du classifier class_weight = 'balanced' ](#section6.1)
# * [6.2 Rebalancing par oversampling de la classe minoritaire SMOTE](#section6.2)
# * [6.3 Rebalancing par undersampling de la classe majoritaire](#section6.3)
#
#
# [7. Synthèse des résultats ](#section7)
#
#
# [8. Interprétabilité du modèle](#section8)
#
# * [8.1 Analyse globale du modèle: importance des variables](#section8.1)
# * [8.2 Analyse locale du modèle: SHAP](#section8.2)

# %% [markdown]
# <a id="section1"> </a>
# # 1. Préparation finale du dataset

# %%
# Conservation uniquement des données avec Target

data_red = data_red[data_red.train_test == 1]

# %%
# Suppression des variables faisant partie des paires corrélées telles qu'identifiées dans analyse explo

col_to_delete = ['AMT_CREDIT','REGION_RATING_CLIENT', 'OBS_60_CNT_SOCIAL_CIRCLE','DAYS_EMPLOYED']

data_red = data_red.drop(col_to_delete, axis = 1)

# %%
# Sampling aléatoire et séparation entre variables indépendantes et Target

data_sample = data_red.sample(15000, random_state=1)

X = data_sample.drop(columns = ['TARGET', 'SK_ID_CURR'])
Y = data_sample['TARGET']

# %%
# Split Train / Test en conservant les proportions de la variable cible (stratify = Y)

Xtrain, Xtest, ytrain, ytest = train_test_split(X, Y, train_size=0.75, random_state=2, stratify=Y)

# %%
# Confirmation que les données sont déséquilibrées avec une sous-représentation de la variable Target = 1

fig, ax = plt.subplots(1,2, figsize=(8,4))
ytrain.value_counts().plot.pie(autopct='%1.2f%%', ax=ax[0], title='Train Set');
ytest.value_counts().plot.pie(autopct='%1.2f%%', ax=ax[1], title='Test Set');
fig.subplots_adjust(wspace=0.5);

# %%
# Scaling des variables Xtrain et Xtest

scaler = RobustScaler().fit(Xtrain)

Xtrain = pd.DataFrame(scaler.transform(Xtrain), index = Xtrain.index, columns = Xtrain.columns)
Xtest = pd.DataFrame(scaler.transform(Xtest), index = Xtest.index, columns = Xtest.columns)

# %% [markdown]
# Afin de voir si les données sont potentiellement séparables facilement, je vais utiliser une visualisation UMAP des deux classes

# %%
# Visualisation UMAP 2D pour voir si les données sont potentiellement séparables

import umap

umap = umap.UMAP()
matrix_2d = umap.fit_transform(X)

# Préparation d'un DataFrame avec les données UMAP

colors = ['G' if i==0 else 'R' for i in Y]

df_umap = pd.DataFrame(matrix_2d)
df_umap['Class'] = pd.DataFrame(Y)["TARGET"].values
df_umap['color'] = colors
df_umap.columns = ['x','y','Class','color']
cols = ['Class','color','x','y']
df_umap = df_umap[cols]

# Visualisation graphique

fig, ax = plt.subplots(figsize=(15,10))

ax.scatter(df_umap[df_umap['Class']==1].x.values, df_umap[df_umap['Class']==1].y.values,
           c='red', s=10, alpha=0.7, label='Default')

ax.scatter(df_umap[df_umap['Class']==0].x.values, df_umap[df_umap['Class']==0].y.values,
           c='green', s=10, alpha=0.5, label='Paid')
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend()
plt.show();

# %% [markdown]
# On remarque que les données ne sont pas clairement séparées entre défaut et prêts remboursés. Nous verrons si nous pouvons remédier à cela via différentes techniques

# %% [markdown]
# <a id="section2"> </a>
# # 2. Définition d'un scoring adapté à problématique métier

# %% [markdown]
# Afin de pouvoir évaluer notre modèle, il convient de trouver la mesure la plus pertinente pour notre besoin métier.
#
# Etant une banque, outre la bonne détection des prêts accordés ou refusés correctement (True Negative ou True Positives), il nous faut aussi minimiser autant que possible les cas où un emprunteur serait identifié comme solvable alors qu'il ne l'est pas (False Negative).
#
# Il est moins crucial de se concentrer sur les emprunteurs identifiés comme insolvables alors qu'ils le sont, même si cela a aussi un coût pour la banque (d'opportunité, en premier lieu, mais aussi potentiellement réputationnel).
#
# Minimiser les FN revient donc à maximiser la mesure de Recall par rapport à celle de Precision.
#
# Pour ce faire, je vais utiliser la mesure dite 'F2-measure', qui est une application de la mesure Fbeta avec un beta de 2 (qui a pour effet d'augmenter l'importance du Recall)
#
# beta = Cost of False Negative/Cost of False Positive

# %%
import cv2

img = cv2.imread("Fbeta.png")
plt.figure(figsize=(6, 6))
plt.grid(None)
plt.axis('off')
plt.imshow(img)

# %%
# Fonction de cross validation de score personalisée qui renvoie aussi proba d'appartenir à classe 1

def cv_score(clf, x, y, cv=5, beta = 2, resampling = None):
    cv_score = []
    y_pred_proba = []

    # creation de folds pour CV
    kf = StratifiedKFold(n_splits=cv, shuffle = False)
    
    for train_indices, valid_indices in kf.split(x,y):
        # Entrainement pour le fold considéré
        xtrn, ytrn = x.iloc[train_indices], y.iloc[train_indices]
        # Validation
        xval, yval = x.iloc[valid_indices], y.iloc[valid_indices]

        # Entraînement en fonction de rebalancing ou pas
        if resampling is not None :
            # Resample train set
            xtrn_rs, ytrn_rs = resampling.fit_resample(xtrn, ytrn)
            clf.fit(xtrn_rs, ytrn_rs)
        else:
            clf.fit(xtrn, ytrn)

        # Prédiction sur jeu de test
        ypred = clf.predict(xval)
        
        # Sauvegarde des probas pour la classe 1
        yprob = clf.predict_proba(xval)
        y_pred_proba+=(list(yprob[:,1]))

        # Enregistrement des scores
        score = round(fbeta_score(yval, ypred, beta = beta),3)
        
        cv_score.append(score)
    
    return np.array(cv_score), np.array(y_pred_proba)

# %% [markdown]
# <a id="section3"> </a>
# # 3. Comparaison de plusieurs Classifiers et definition de fonctions

# %% [markdown]
# Je vais commencer par tester une série de Classifiers en utilisant leurs paramètres standards avec cross validation sur la métrique de score présentée ci-dessus pour ne retenir que les 3 plus performants

# %%
# Ajustement des noms de colonnes pour algorithme LGBM

import re
Xtrain = Xtrain.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
Xtest = Xtest.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %%
# Comparaison de 7 algorithmes de classification

classifiers = [LogisticRegression(), 
               KNeighborsClassifier(), 
               DecisionTreeClassifier(),
               LinearDiscriminantAnalysis(),
               QuadraticDiscriminantAnalysis(),
               RandomForestClassifier(random_state=2),
               lgb.LGBMClassifier()
              ]

# Enregistrement des scores pour comparaison visuelle
log_cols=["Classifier", "F2-score"]
log = pd.DataFrame(columns=log_cols)

# Création d'un scorer pour cross validation du score FBeta et calcul de ces scores pour chaque classifier

scorer_beta = make_scorer(fbeta_score, beta=2, average = 'weighted')

for clf in classifiers:
    F_Beta2_scores = cross_val_score(clf, Xtrain, ytrain, cv=5, scoring=scorer_beta)
    name = clf.__class__.__name__
    log_entry = pd.DataFrame([[name, F_Beta2_scores.mean()]], columns=log_cols)
    log = log.append(log_entry)

log.plot(x="Classifier", y=["F2-score"], kind="bar")
plt.title("Comparaison classifiers F2 score balanced")
plt.show()

# %% [markdown]
# Je retiens donc les 3 modèles les plus performants selon la mesure F2 score:

# %%
log.nlargest(3,['F2-score'])
# Out:
#                Classifier  F2-score
# 0      LogisticRegression  0.904474
# 0  RandomForestClassifier  0.903871
# 0          LGBMClassifier  0.903500

# %% [markdown]
# Ces performances ont permis d'identifier 3 classifiers que je vais tenter d'optimiser en fonction du jeu de données.
#
# Je vais maintenant développer 2 fonctions qui seront utiles lors de l'optimisation de ces 3 modèles

# %%
# Creation d'une fonction qui indique le seuil optimal qui maximise le score F2

def threshold_selection(Y_proba, Ytrain):
    
    scores = []
    for threshold in np.linspace(0, 1, num=101):
        y_pred = (Y_proba > threshold)*1
        score = fbeta_score(Ytrain, y_pred, beta = 2)
        scores.append(score) 

    scores = np.asarray(scores)
    best_threshold, best_score = (scores.argmax()*.01, round(scores.max(),3))
    
    print('Best Threshold :', best_threshold)
    print('Best Score :', best_score)

    plt.plot(np.linspace(0, 1, num=101), scores, lw=1)
    plt.axvline(best_threshold, ls='--', lw=1, c='r')
    plt.xlabel('Threshold')
    plt.ylabel('Score performed')
    plt.show()

# %%
# Création d'une fonction qui fit le modèle sur les données d'entraînement, fait tourner le modèle sur le jeu 
# de données test, calcule le score F2, et fournit la matrice de confusion

def make_pred(clf, x_train, y_train, x_test, y_test, thresh):
    
    clf.fit(x_train, y_train)
    probas = clf.predict_proba(x_test)[:,1]
    predictions = (probas > thresh)*1
    
    # calcul du F2 score
    score = round(fbeta_score(y_test, predictions, beta = 2),3)
    
    cm=confusion_matrix(y_test, predictions, normalize='true')*100
        
    # Affichage du score et de la confusion matrix
    ax = sns.heatmap(cm, annot=True, cmap='RdBu', center=0, cbar=False)
    ax.set_title('Confusion matrix (%)')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
    
    print('Score sur le jeu de données Test avec seuil de {} : {}'.format(thresh, score))

# %%
# Création d'un Dataframe pour enregistrer les scores de chaque modèle

log_cols=["Logistic Regression", "Random Forest", "LGBM"]
indexes = ["Paramètre_Class", "Smote", "Under_Sampling"]
scores_log = pd.DataFrame(index = indexes, columns=log_cols)

# %% [markdown]
# Enfin je vais définir une baseline pour notre modèle et calculer plusieurs mesures de performances afin de comparer les optimisations apportées par la suite.
#
# Je choisis un DummyClassifier qui prédit systématiquement la classe minoritaire afin d'avoir un recall maximum et un cv_score considéré comme ma baseline

# %%
# Définition d'une baseline avec un Dummy Classifier

model = DummyClassifier(strategy='constant', constant=1)

y_proba = cv_score(model,Xtrain, ytrain, cv = 5, beta = 2)[1]

threshold_selection(y_proba, ytrain)
# Out:
# Best Threshold : 0.0
# Best Score : 0.304

# %%
make_pred(model, Xtrain, ytrain, Xtest, ytest, thresh = 0)

print("Recall = ", round(recall_score(ytest, model.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, model.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, model.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0 : 0.304
# Recall =  1.0
# Precision =  0.08
# AUC score =  0.5

# %% [markdown]
# La baseline à laquelle nous allons comparer les 3 modèle a un score de 0.304

# %% [markdown]
# <a id="section4"> </a>
# # 4. Optimization des performances - Logistic Regression

# %% [markdown]
# Nous commençons notre analyse avec le modèle Logistic Regression.
#
# Dans un premier temps nous essaierons de remédier à déséquilibre entre les classes en utilisant un paramètre propre au classifier, puis utiliserons deux techniques de resampling, une couvrant la classe minoritaire et l'autre la classe majoritaire.

# %% [markdown]
# <a id="section4.1"> </a>
# # 4.1 Rebalancing par le paramètre du classifier class_weight = 'balanced'

# %% [markdown]
# Le paramètre "class_weight" est utilisé pour pénaliser différement les erreurs de classifications selon qu'il s'agit de la classe majoritaire ou de la minoritaire. En fixant ce paramètre à 'balanced', le poids appliqué à la pénalité est inversement proportionnel à la fréquence de la classe.

# %%
# Je commence par une recherche sur grille des meilleurs paramètres du modèle

clf = LogisticRegression(class_weight = 'balanced')

ftwo_scorer = make_scorer(fbeta_score, beta=2)

# use a full grid over all parameters
grid_values = {'penalty': ['l1','l2'], 'C': [0.1,1,10,100,1000]}

# run grid search
grid = GridSearchCV(clf, param_grid=grid_values, cv=5, scoring = ftwo_scorer)
grid.fit(Xtrain, ytrain)

print("Grid-Search with F2-score")
print("Best parameters:", grid.best_params_)
print("Best cross-validation score (F2-score)): {:.3f}".format(grid.best_score_))
# Out:
# Grid-Search with F2-score
# Best parameters: {'C': 0.1, 'penalty': 'l2'}
# Best cross-validation score (F2-score)): 0.404

# %%
# Optimisation du seuil en application la fonction au modèle optimisé à l'étape précédente

clf_reg_bal = LogisticRegression(C = 0.1,
                        penalty = 'l2',
                        class_weight = 'balanced')

y_proba = cv_score(clf_reg_bal,Xtrain, ytrain, cv = 5, beta = 2)[1]

threshold_selection(y_proba, ytrain)
# Out:
# Best Threshold : 0.44
# Best Score : 0.394

# %% [markdown]
# Maintenant que nous avons les meilleurs paramètres pour le modèle, nous pouvons optimiser la performance du modèle en jouant sur la valeur du seuil ('Threshold') à partir duquel on décide de l'appartenance à la classe 1

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(clf_reg_bal, Xtrain, ytrain, Xtest, ytest, thresh = 0.44)

print("Recall = ", round(recall_score(ytest, clf_reg_bal.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, clf_reg_bal.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, clf_reg_bal.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.44 : 0.407
# Recall =  0.65
# Precision =  0.16
# AUC score =  0.75

# %% [markdown]
# Le score est supérieur à la baseline. Le modèle identifie correctement 62% des personnes solvables et 74% des personnes faisant défaut, avec un recall de 65%. Le % de Faux Négatifs (TypeII Error) est toutefois assez élevé à 26%.

# %%
scores_log.loc["Paramètre_Class", "Logistic Regression"] = 0.407

# %% [markdown]
# <a id="section4.2"> </a>
# # 4.2 Rebalancing par oversampling de la classe minoritaire (SMOTE)

# %% [markdown]
# Synthetic Minority Oversampling Technique (SMOTE) crée artificiellement des observations additionnelles dans la classe minoritaire (ici TARGET = 1) afin de rééquilibrer la distribution de la variable.
#
# SMOTE choisit aléatoirement une instance a de la classe minoritaire et cherche ses k plus proches voisins (ici, k=5). Une instance b est alors créée en choisissant aléatoirement parmi ces k voisins, puis connectée à l'instance a pour créer un segment dans l'espace des feautres. Les autres instances synthétiques sont générées par une combinaisons convexe des 2 instances a et b.

# %%
# Application de l'oversampling appliqué au jeu de données d'entraînement

smote = SMOTE(random_state=2)
Xsmot, ysmot = smote.fit_resample(Xtrain, ytrain)

# %%
# On remarque l'équilibre entre les classes 0 et 1 post oversampling

print(Counter(ytrain))
print(Counter(ysmot))
# Out:
# Counter({0.0: 10345, 1.0: 905})
# Counter({0.0: 10345, 1.0: 10345})

# %%
# Visualisation UMAP post SMOTE : création du df

matrix_2d = umap.fit_transform(Xsmot)

colors = ['G' if i==0 else 'R' for i in ysmot]

df_umap = pd.DataFrame(matrix_2d)
df_umap['Class'] = pd.DataFrame(ysmot)["TARGET"].values
df_umap['color'] = colors
df_umap.columns = ['x','y','Class','color']
cols = ['Class','color','x','y']
df_umap = df_umap[cols]

# Visualisation

fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(df_umap[df_umap['Class']==1].x.values, df_umap[df_umap['Class']==1].y.values,
           c='red', s=10, alpha=0.5, label='Default')
ax.scatter(df_umap[df_umap['Class']==0].x.values, df_umap[df_umap['Class']==0].y.values,
           c='green', s=10, alpha=0.5, label='Paid')
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend()
plt.show();

# %% [markdown]
# L'utilisation de Smote n'a pas amélioré la situation en termes de séparabilité des données

# %%
# Je commence par une recherche sur grille des meilleurs paramètres du modèle

clf = LogisticRegression()

ftwo_scorer = make_scorer(fbeta_score, beta=2)

# use a full grid over all parameters
grid_values = {'penalty': ['l1','l2'], 'C': [0.001,0.01,0.1,1,10,100,1000]}

# run grid search
grid = GridSearchCV(clf, param_grid=grid_values, cv=5, scoring = ftwo_scorer)
grid.fit(Xtrain, ytrain)

print("Grid-Search with F2-score")
print("Best parameters:", grid.best_params_)
print("Best cross-validation score (F2-score)): {:.3f}".format(grid.best_score_))
# Out:
# Grid-Search with F2-score
# Best parameters: {'C': 1000, 'penalty': 'l2'}
# Best cross-validation score (F2-score)): 0.039

# %%
# Optimisation du seuil en application la fonction au modèle optimisé à l'étape précédente

clf_reg = LogisticRegression(C = 1000,
                        penalty = 'l2')

y_proba = cv_score(clf_reg,Xtrain, ytrain, cv = 5, beta = 2, resampling = smote)[1]

threshold_selection(y_proba, ytrain)
# Out:
# Best Threshold : 0.45
# Best Score : 0.383

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(clf_reg, Xsmot, ysmot, Xtest, ytest, thresh = 0.45)

print("Recall = ", round(recall_score(ytest, clf_reg.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, clf_reg.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, clf_reg.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.45 : 0.4
# Recall =  0.61
# Precision =  0.16
# AUC score =  0.74

# %% [markdown]
# Le modèle a un score très légèrement inférieur mais reste meilleur par rapport à la baseline. Il identifie correctement 67% des personnes solvables et 68% des personnes faisant défaut, avec un recall en baisse à 61%. Les erreurs de Type II sont aussi légèrement en baisse avec 32% de Faux Négatifs.

# %%
scores_log.loc["Smote", "Logistic Regression"] = 0.4

# %% [markdown]
# <a id="section4.3"> </a>
# # 4.3 Rebalancing par undersampling de la classe majoritaire

# %% [markdown]
# Contrairement à la méthode précédente qui conste à créer synthétiquement des données pour la classe minoritaire, la méthode d'undersampling permet de réduire des données de la classe majoritaire.
#
# Plutôt que de choisir une méthode basée sur une suppression aléatoire, je choisis la méthode Near Miss dans sa version 3 qui ne conserve que les éléments de la classe majoritaire qui ont une distance minimum avec chacun des éléments de la classe minoritaire.

# %%
under_sampler = NearMiss(version=3)
x_resamp, y_resamp = under_sampler.fit_resample(Xtrain, ytrain)

print(Counter(ytrain))
print(Counter(y_resamp))
# Out:
# Counter({0.0: 10345, 1.0: 905})
# Counter({0.0: 905, 1.0: 905})

# %%
# Visualisation UMAP post Undersampling : création du df

matrix_2d = umap.fit_transform(x_resamp)

colors = ['G' if i==0 else 'R' for i in y_resamp]

df_umap = pd.DataFrame(matrix_2d)
df_umap['Class'] = pd.DataFrame(y_resamp)["TARGET"].values
df_umap['color'] = colors
df_umap.columns = ['x','y','Class','color']
cols = ['Class','color','x','y']
df_umap = df_umap[cols]

# Visualisation

fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(df_umap[df_umap['Class']==1].x.values, df_umap[df_umap['Class']==1].y.values,
           c='red', s=10, alpha=0.5, label='Default')
ax.scatter(df_umap[df_umap['Class']==0].x.values, df_umap[df_umap['Class']==0].y.values,
           c='green', s=10, alpha=0.5, label='Paid')
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend()
plt.show();

# %% [markdown]
# Ici il semblerait que la méthode d'UnderSampling choisie permette d'obtenir des données légèrement mieux séparables

# %%
# Optimisation du seuil en application la fonction au modèle optimisé après recherche sur grille

y_proba_unders = cv_score(clf_reg,Xtrain, ytrain, cv = 5, beta = 2, resampling = under_sampler)[1]

threshold_selection(y_proba_unders, ytrain)
# Out:
# Best Threshold : 0.61
# Best Score : 0.332

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(clf_reg, x_resamp, y_resamp, Xtest, ytest, thresh = 0.61)

print("Recall = ", round(recall_score(ytest, clf_reg.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, clf_reg.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, clf_reg.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.61 : 0.324
# Recall =  0.69
# Precision =  0.12
# AUC score =  0.66

# %% [markdown]
# Le modèle a le moins bon score car il identifie mal les personnes n'ayant pas fait défaut et notamment, surestime les personnes identifiée comme ayant fait défaut alors qu'elles sont solvables (Faux Positifs). C'est toutefois le meilleur Recall avec 69% grâce au faible nombre d'erreurs de Type II (Faux Negatifs)

# %%
scores_log.loc["Under_Sampling", "Logistic Regression"] = 0.324

# %% [markdown]
# <a id="section5"> </a>
# # 5. Optimization des performances - Random Forest Classifier

# %% [markdown]
# Nous passons désormais au modèle de classification basé sur les Random Forest.
#
# Nous suivrons la même méthode pour tenter de résoudre les problèmes liés au déséquilibre entre les classes de clients.

# %% [markdown]
# <a id="section5.1"> </a>
# # 5.1 Rebalancing par le paramètre du classifier class_weight = 'balanced'

# %%
# Recherche sur grille des meilleurs paramètres du modèle

clf = RandomForestClassifier(random_state=2,
                             class_weight = 'balanced')


param_grid = {'n_estimators' : [50,100,150], 
              'max_depth': [3, 5, None],
              'max_features': [1, 3, 10],
              'min_samples_split': [2, 3, 10],
             'min_samples_leaf' : [1, 16, 64]}

ftwo_scorer = make_scorer(fbeta_score, beta=2)

# run grid search
grid = RandomizedSearchCV(clf, param_grid, cv=5,scoring=ftwo_scorer,n_iter = 10)

grid.fit(Xtrain, ytrain)

print("Grid-Search with F2-score")
print("Best parameters:", grid.best_params_)
print("Best cross-validation score (F2-score)): {:.3f}".format(grid.best_score_))
# Out:
# Grid-Search with F2-score
# Best parameters: {'n_estimators': 150, 'min_samples_split': 10, 'min_samples_leaf': 16, 'max_features': 3, 'max_depth': 3}
# Best cross-validation score (F2-score)): 0.378

# %%
# Optimisation du seuil en application la fonction au modèle optimisé à l'étape précédente

clf_rf_bal = RandomForestClassifier(random_state=2,
                                    class_weight = 'balanced',
                                    n_estimators = 150,
                                    max_depth = 3,
                                    max_features = 3,
                                    min_samples_split = 10,
                                    min_samples_leaf = 16)

y_proba = cv_score(clf_rf_bal,Xtrain, ytrain, cv = 5, beta = 2)[1]

threshold_selection(y_proba, ytrain)
# Out:
# Best Threshold : 0.5
# Best Score : 0.369

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(clf_rf_bal, Xtrain, ytrain, Xtest, ytest, thresh = 0.5)

print("Recall = ", round(recall_score(ytest, clf_rf_bal.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, clf_rf_bal.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, clf_rf_bal.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.5 : 0.409
# Recall =  0.66
# Precision =  0.16
# AUC score =  0.74

# %% [markdown]
# Le modèle a un bon score de 0.41. Il identifie correctement 70% des personnes solvables et 66% des personnes faisant défaut, avec un recall plus faible que le modèle précédent à 66%.

# %%
scores_log.loc["Paramètre_Class", "Random Forest"] = 0.409

# %% [markdown]
# <a id="section5.2"> </a>
# # 5.2 Rebalancing par oversampling de la classe minoritaire SMOTE

# %%
clf = RandomForestClassifier(random_state=2)


param_grid = {'n_estimators' : [50,100,150], 
              'max_depth': [3, 5,10, None],
              'max_features': [1, 3, 10],
              'min_samples_split': [2, 3, 10],
             'min_samples_leaf' : [1, 16, 64]}

ftwo_scorer = make_scorer(fbeta_score, beta=2)

# run grid search
grid = RandomizedSearchCV(clf, param_grid, cv=5,scoring=ftwo_scorer,n_iter = 10)

grid.fit(Xtrain, ytrain)

print("Grid-Search with F2-score")
print("Best parameters:", grid.best_params_)
print("Best cross-validation score (F2-score)): {:.3f}".format(grid.best_score_))
# Out:
# Grid-Search with F2-score
# Best parameters: {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 3, 'max_depth': None}
# Best cross-validation score (F2-score)): 0.000

# %%
# Optimisation du seuil en application la fonction au modèle optimisé à l'étape précédente

clf_rf = RandomForestClassifier(random_state=2,
                                n_estimators = 50,
                                max_depth = None,
                                max_features = 3,
                                min_samples_split = 2,
                                min_samples_leaf = 1)

y_proba = cv_score(clf_rf,Xtrain, ytrain, cv = 5, beta = 2, resampling = smote)[1]

threshold_selection(y_proba, ytrain)
# Out:
# Best Threshold : 0.16
# Best Score : 0.347

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(clf_rf, Xsmot, ysmot, Xtest, ytest, thresh = 0.16)

print("Recall = ", round(recall_score(ytest, clf_rf.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, clf_rf.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, clf_rf.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.16 : 0.364
# Recall =  0.0
# Precision =  0.0
# AUC score =  0.68

# %% [markdown]
# Le modèle souffre ici du déséquilibre et la méthode Smote dégrade le score. Le modèle a de très mauvais résultat avec la classe Négative.

# %%
scores_log.loc["Smote","Random Forest"] = 0.364

# %% [markdown]
# <a id="section5.3"> </a>
# # 5.3 Rebalancing par undersampling de la classe majoritaire

# %%
# Optimisation du seuil en application la fonction au modèle optimisé après recherche sur grille

y_proba_unders = cv_score(clf_rf,Xtrain, ytrain, cv = 5, beta = 2, resampling = under_sampler)[1]

threshold_selection(y_proba_unders, ytrain)
# Out:
# Best Threshold : 0.46
# Best Score : 0.325

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(clf_rf, x_resamp, y_resamp, Xtest, ytest, thresh = 0.46)

print("Recall = ", round(recall_score(ytest, clf_rf.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, clf_rf.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, clf_rf.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.46 : 0.333
# Recall =  0.66
# Precision =  0.11
# AUC score =  0.64

# %% [markdown]
# Le score reste faible même si légèrement supérieur à Smote.  Le nombre de FN est bas à 25% mais le modèle fait un très mauvais travail avec les clients ayant remboursé leur prêt.

# %%
scores_log.loc["Under_Sampling", "Random Forest"] = 0.333

# %% [markdown]
# <a id="section6"> </a>
# # 6. Optimization des performances - LGBM Classifier

# %% [markdown]
# Enfin, je vais utiliser un classifier qui se base sur les techniques de Gradient Boosting qui font partie des méthodes ensemblistes construites sur des arbres de décision et optimisant une fonction de perte à l'aide de descente de gradient.
#
# A nouveau, les 3 mêmes approches que précédemment seront utilisées pour gérer le déséquilibre de classe.

# %% [markdown]
# <a id="section6.1"> </a>
# # 6.1 Rebalancing par le paramètre du classifier class_weight = 'balanced'

# %%
# Recherche sur grille des meilleurs paramètres du modèle

lgbc = lgb.LGBMClassifier(random_state=2,
                          class_weight = 'balanced')

param_grid = {'objective' : ['binary'],
              'boosting' : ['gbdt', 'dart', 'goss'],
              'n_estimators': [250, 500, 750], 
              'learning_rate' : [0.005, 0.01],
              'max_depth' : [5, 10, 20, None],
              'num_leaves' : [4, 16, 64, 128],
              'min_data_in_leaf' : [100, 500], 
              'reg_alpha' : [1,1.2, 1.4],
              'reg_lambda' : [1,1.2,1.4]}

ftwo_scorer = make_scorer(fbeta_score, beta=2)

grid = RandomizedSearchCV(lgbc, param_grid, n_iter = 50, cv = 5, scoring = ftwo_scorer, verbose=500)

grid.fit(Xtrain, ytrain)

print("Grid-Search with F2-score")
print("Best parameters:", grid.best_params_)
print("Best cross-validation score (F2-score)): {:.3f}".format(grid.best_score_))
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss, score=0.414, total=   1.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss, score=0.395, total=   0.9s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss, score=0.369, total=   1.1s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.9s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss, score=0.369, total=   1.1s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.1s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=goss, score=0.421, total=   1.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.0s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.403, total=   1.6s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    6.6s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.381, total=   1.6s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    8.2s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.368, total=   1.4s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    9.7s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.365, total=   1.4s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   11.1s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.404, total=   1.4s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   12.5s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.407, total=   0.5s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   13.0s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.390, total=   0.5s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   13.5s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.358, total=   0.5s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   14.0s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.372, total=   0.5s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   14.5s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.401, total=   0.5s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   15.0s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.330, total=   5.5s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   20.5s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.325, total=   5.6s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   26.1s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.260, total=   5.5s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   31.6s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.331, total=   6.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   37.6s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.380, total=   5.8s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   43.4s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss, score=0.395, total=   3.1s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   46.5s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss, score=0.401, total=   3.1s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   49.6s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss, score=0.372, total=   3.1s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   52.8s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss, score=0.358, total=   3.2s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   56.0s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=goss, score=0.420, total=   3.1s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   59.1s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.408, total=   3.5s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  1.0min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.397, total=   3.7s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  1.1min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.375, total=   3.5s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  1.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.363, total=   3.6s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  1.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.409, total=   3.6s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  1.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.430, total=   0.8s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:  1.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.401, total=   0.8s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:  1.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.371, total=   0.8s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:  1.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.358, total=   0.8s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:  1.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.423, total=   0.8s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:  1.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.410, total=   3.5s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  1.4min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.393, total=   3.8s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:  1.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.369, total=   3.6s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:  1.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.363, total=   3.6s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:  1.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=5, learning_rate=0.01, boosting=dart, score=0.403, total=   3.6s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  1.6min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart, score=0.428, total=   9.5s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:  1.8min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart, score=0.400, total=   9.5s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:  2.0min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart, score=0.364, total=   9.6s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:  2.1min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart, score=0.355, total=   9.9s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:  2.3min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart, score=0.406, total=   9.4s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  2.4min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.400, total=   2.4s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:  2.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.399, total=   2.3s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:  2.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.349, total=   2.4s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:  2.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.377, total=   2.4s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:  2.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.435, total=   2.4s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  2.6min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.419, total=   6.4s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:  2.8min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.393, total=   6.7s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:  2.9min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.371, total=   6.5s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:  3.0min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.359, total=   6.5s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:  3.1min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.409, total=   6.7s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:  3.2min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.414, total=   3.7s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:  3.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.406, total=   3.6s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:  3.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.360, total=   3.6s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:  3.4min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.375, total=   3.8s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:  3.4min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.437, total=   3.6s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  3.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.401, total=   1.6s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:  3.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.407, total=   1.6s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:  3.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.369, total=   1.6s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:  3.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.348, total=   1.6s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:  3.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.413, total=   1.7s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:  3.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart, score=0.408, total=   3.7s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:  3.7min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart, score=0.392, total=   3.7s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:  3.8min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart, score=0.381, total=   3.7s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:  3.8min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart, score=0.363, total=   3.7s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:  3.9min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=dart, score=0.409, total=   3.8s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  3.9min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart, score=0.405, total=   0.8s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:  4.0min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart, score=0.381, total=   0.9s
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  4.0min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart, score=0.366, total=   0.9s
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:  4.0min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart, score=0.369, total=   0.9s
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:  4.0min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=dart, score=0.387, total=   0.9s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  4.0min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.420, total=   9.2s
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:  4.2min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.402, total=   8.6s
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed:  4.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.356, total=   8.5s
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed:  4.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.356, total=   8.9s
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed:  4.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.417, total=   8.6s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  4.7min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.405, total=   1.9s
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:  4.8min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.418, total=   2.0s
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed:  4.8min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.367, total=   1.9s
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed:  4.8min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.374, total=   2.0s
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:  4.9min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.422, total=   1.9s
# [Parallel(n_jobs=1)]: Done  85 out of  85 | elapsed:  4.9min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart, score=0.408, total=   3.6s
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed:  5.0min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart, score=0.391, total=   3.7s
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:  5.0min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart, score=0.384, total=   3.6s
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed:  5.1min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart, score=0.362, total=   3.6s
# [Parallel(n_jobs=1)]: Done  89 out of  89 | elapsed:  5.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.01, boosting=dart, score=0.409, total=   3.8s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:  5.2min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.423, total=   1.4s
# [Parallel(n_jobs=1)]: Done  91 out of  91 | elapsed:  5.2min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.420, total=   1.4s
# [Parallel(n_jobs=1)]: Done  92 out of  92 | elapsed:  5.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.365, total=   1.4s
# [Parallel(n_jobs=1)]: Done  93 out of  93 | elapsed:  5.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.372, total=   1.4s
# [Parallel(n_jobs=1)]: Done  94 out of  94 | elapsed:  5.3min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.426, total=   1.4s
# [Parallel(n_jobs=1)]: Done  95 out of  95 | elapsed:  5.3min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.421, total=   0.7s
# [Parallel(n_jobs=1)]: Done  96 out of  96 | elapsed:  5.3min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.394, total=   0.7s
# [Parallel(n_jobs=1)]: Done  97 out of  97 | elapsed:  5.4min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.374, total=   0.7s
# [Parallel(n_jobs=1)]: Done  98 out of  98 | elapsed:  5.4min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.360, total=   0.7s
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed:  5.4min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.409, total=   0.7s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  5.4min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.393, total=   8.8s
# [Parallel(n_jobs=1)]: Done 101 out of 101 | elapsed:  5.5min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.384, total=   9.0s
# [Parallel(n_jobs=1)]: Done 102 out of 102 | elapsed:  5.7min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.358, total=   8.5s
# [Parallel(n_jobs=1)]: Done 103 out of 103 | elapsed:  5.8min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.344, total=   8.8s
# [Parallel(n_jobs=1)]: Done 104 out of 104 | elapsed:  6.0min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=dart, score=0.392, total=   9.5s
# [Parallel(n_jobs=1)]: Done 105 out of 105 | elapsed:  6.1min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.416, total=   1.0s
# [Parallel(n_jobs=1)]: Done 106 out of 106 | elapsed:  6.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.389, total=   1.0s
# [Parallel(n_jobs=1)]: Done 107 out of 107 | elapsed:  6.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.375, total=   1.0s
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed:  6.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.368, total=   1.0s
# [Parallel(n_jobs=1)]: Done 109 out of 109 | elapsed:  6.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=None, learning_rate=0.005, boosting=goss, score=0.414, total=   1.0s
# [Parallel(n_jobs=1)]: Done 110 out of 110 | elapsed:  6.2min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart, score=0.402, total=   3.6s
# [Parallel(n_jobs=1)]: Done 111 out of 111 | elapsed:  6.3min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart, score=0.383, total=   3.7s
# [Parallel(n_jobs=1)]: Done 112 out of 112 | elapsed:  6.3min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart, score=0.370, total=   3.6s
# [Parallel(n_jobs=1)]: Done 113 out of 113 | elapsed:  6.4min remaining:    0.0s
# ...
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart, score=0.359, total=   2.1s
# [Parallel(n_jobs=1)]: Done 214 out of 214 | elapsed: 11.4min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.01, boosting=dart, score=0.394, total=   2.1s
# [Parallel(n_jobs=1)]: Done 215 out of 215 | elapsed: 11.4min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss, score=0.434, total=   0.8s
# [Parallel(n_jobs=1)]: Done 216 out of 216 | elapsed: 11.5min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss, score=0.410, total=   0.8s
# [Parallel(n_jobs=1)]: Done 217 out of 217 | elapsed: 11.5min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss, score=0.376, total=   0.8s
# [Parallel(n_jobs=1)]: Done 218 out of 218 | elapsed: 11.5min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss, score=0.370, total=   0.8s
# [Parallel(n_jobs=1)]: Done 219 out of 219 | elapsed: 11.5min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=goss, score=0.429, total=   0.8s
# [Parallel(n_jobs=1)]: Done 220 out of 220 | elapsed: 11.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart, score=0.405, total=   0.9s
# [Parallel(n_jobs=1)]: Done 221 out of 221 | elapsed: 11.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart, score=0.381, total=   0.9s
# [Parallel(n_jobs=1)]: Done 222 out of 222 | elapsed: 11.5min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart, score=0.366, total=   0.9s
# [Parallel(n_jobs=1)]: Done 223 out of 223 | elapsed: 11.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart, score=0.369, total=   0.9s
# [Parallel(n_jobs=1)]: Done 224 out of 224 | elapsed: 11.6min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=20, learning_rate=0.005, boosting=dart, score=0.387, total=   0.9s
# [Parallel(n_jobs=1)]: Done 225 out of 225 | elapsed: 11.6min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.417, total=   1.9s
# [Parallel(n_jobs=1)]: Done 226 out of 226 | elapsed: 11.6min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.419, total=   1.9s
# [Parallel(n_jobs=1)]: Done 227 out of 227 | elapsed: 11.7min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.364, total=   1.9s
# [Parallel(n_jobs=1)]: Done 228 out of 228 | elapsed: 11.7min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.376, total=   1.9s
# [Parallel(n_jobs=1)]: Done 229 out of 229 | elapsed: 11.7min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.430, total=   1.9s
# [Parallel(n_jobs=1)]: Done 230 out of 230 | elapsed: 11.8min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.396, total=   1.3s
# [Parallel(n_jobs=1)]: Done 231 out of 231 | elapsed: 11.8min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.378, total=   1.3s
# [Parallel(n_jobs=1)]: Done 232 out of 232 | elapsed: 11.8min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.368, total=   1.3s
# [Parallel(n_jobs=1)]: Done 233 out of 233 | elapsed: 11.8min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.368, total=   1.3s
# [Parallel(n_jobs=1)]: Done 234 out of 234 | elapsed: 11.8min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=dart, score=0.408, total=   1.3s
# [Parallel(n_jobs=1)]: Done 235 out of 235 | elapsed: 11.9min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.409, total=   2.2s
# [Parallel(n_jobs=1)]: Done 236 out of 236 | elapsed: 11.9min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.401, total=   2.2s
# [Parallel(n_jobs=1)]: Done 237 out of 237 | elapsed: 11.9min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.337, total=   2.2s
# [Parallel(n_jobs=1)]: Done 238 out of 238 | elapsed: 12.0min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.378, total=   2.3s
# [Parallel(n_jobs=1)]: Done 239 out of 239 | elapsed: 12.0min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=gbdt, score=0.430, total=   2.2s
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed: 12.0min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.414, total=   0.5s
# [Parallel(n_jobs=1)]: Done 241 out of 241 | elapsed: 12.1min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.394, total=   0.5s
# [Parallel(n_jobs=1)]: Done 242 out of 242 | elapsed: 12.1min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.368, total=   0.5s
# [Parallel(n_jobs=1)]: Done 243 out of 243 | elapsed: 12.1min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.371, total=   0.5s
# [Parallel(n_jobs=1)]: Done 244 out of 244 | elapsed: 12.1min remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.4, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=100, max_depth=10, learning_rate=0.01, boosting=goss, score=0.416, total=   0.5s
# [Parallel(n_jobs=1)]: Done 245 out of 245 | elapsed: 12.1min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart, score=0.413, total=   4.8s
# [Parallel(n_jobs=1)]: Done 246 out of 246 | elapsed: 12.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart, score=0.375, total=   4.5s
# [Parallel(n_jobs=1)]: Done 247 out of 247 | elapsed: 12.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart, score=0.368, total=   4.3s
# [Parallel(n_jobs=1)]: Done 248 out of 248 | elapsed: 12.3min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart, score=0.350, total=   4.7s
# [Parallel(n_jobs=1)]: Done 249 out of 249 | elapsed: 12.4min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=16, n_estimators=500, min_data_in_leaf=100, max_depth=10, learning_rate=0.005, boosting=dart, score=0.374, total=   4.4s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed: 12.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed: 12.5min finished
# Grid-Search with F2-score
# Best parameters: {'reg_lambda': 1, 'reg_alpha': 1.2, 'objective': 'binary', 'num_leaves': 128, 'n_estimators': 750, 'min_data_in_leaf': 500, 'max_depth': 20, 'learning_rate': 0.01, 'boosting': 'goss'}
# Best cross-validation score (F2-score)): 0.405

# %%
# Optimisation du seuil en application la fonction au modèle optimisé à l'étape précédente

lgbc_bal = lgb.LGBMClassifier(random_state=2,
                              objective = 'binary', 
                              num_leaves = 128, 
                              n_estimators = 750, 
                              min_data_in_leaf = 500, 
                              max_depth = 20, 
                              learning_rate = 0.01, 
                              class_weight = 'balanced', 
                              boosting = 'goss',
                              reg_alpha = 1,
                              reg_lambda = 1.2)

y_proba = cv_score(lgbc_bal, Xtrain, ytrain, cv = 5, beta = 2)[1]

threshold_selection(y_proba, ytrain)
# Out:
# Best Threshold : 0.46
# Best Score : 0.393

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(lgbc_bal, Xtrain, ytrain, Xtest, ytest, thresh = 0.46)

print("Recall = ", round(recall_score(ytest, lgbc_bal.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, lgbc_bal.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, lgbc_bal.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.46 : 0.412
# Recall =  0.66
# Precision =  0.17
# AUC score =  0.75

# %% [markdown]
# Le score est très bon, c'est le meilleur pour le moment. Le modèle identifie 66% des personnes solvables et 71% des personnes faisant défaut, avec un des recall les plus élevés à 66%.

# %%
scores_log.loc["Paramètre_Class", "LGBM"] = 0.412

# %% [markdown]
# <a id="section6.2"> </a>
# # 6.2 Rebalancing par oversampling de la classe minoritaire

# %%
lgbc = lgb.LGBMClassifier(random_state=2)

param_grid = {'objective' : ['binary'],
              'boosting' : ['gbdt', 'dart', 'goss'],
              'n_estimators': [250, 500, 750], 
              'learning_rate' : [0.005, 0.01],
              'max_depth' : [5, 10, 20, None],
              'num_leaves' : [4, 16, 64, 128],
              'min_data_in_leaf' : [50, 100, 500], 
              'reg_alpha' : [1,1.2, 1.4],
              'reg_lambda' : [1,1.2,1.4]}

ftwo_scorer = make_scorer(fbeta_score, beta=2)

grid = RandomizedSearchCV(lgbc, param_grid, n_iter = 50, cv = 5, scoring = ftwo_scorer, verbose=500)

grid.fit(Xtrain, ytrain)

print("Grid-Search with F2-score")
print("Best parameters:", grid.best_params_)
print("Best cross-validation score (F2-score)): {:.3f}".format(grid.best_score_))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.2s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.2s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.2s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.1s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.3s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.1s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.4s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=100, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.5s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.007, total=   3.8s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    9.3s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.027, total=   3.8s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   13.2s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.007, total=   3.9s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   17.1s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.020, total=   4.1s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   21.2s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1.4, objective=binary, num_leaves=64, n_estimators=500, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=gbdt, score=0.007, total=   4.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   25.2s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   0.8s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   26.0s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   26.7s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   27.3s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   28.0s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=128, n_estimators=250, min_data_in_leaf=500, max_depth=5, learning_rate=0.005, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   28.7s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   0.5s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   29.2s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   0.5s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   29.7s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   0.5s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   30.1s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   0.5s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   30.6s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=4, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   0.5s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   31.1s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.1s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   32.3s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.2s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   33.4s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.1s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   34.6s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.2s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   35.8s remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=4, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=gbdt, score=0.000, total=   1.1s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   36.9s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.007, total=   1.3s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   38.2s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.000, total=   1.4s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   39.6s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.000, total=   1.3s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   40.9s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.000, total=   1.3s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   42.2s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=64, n_estimators=250, min_data_in_leaf=100, max_depth=None, learning_rate=0.01, boosting=goss, score=0.000, total=   1.3s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   43.5s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   1.3s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:   44.8s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   1.3s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:   46.1s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   1.2s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:   47.3s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   1.2s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:   48.5s remaining:    0.0s
# [CV] reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss
# [CV]  reg_lambda=1, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=750, min_data_in_leaf=500, max_depth=20, learning_rate=0.005, boosting=goss, score=0.000, total=   1.2s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:   49.7s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.007, total=   3.1s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:   52.8s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.014, total=   2.9s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:   55.7s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.007, total=   3.4s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:   59.1s remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.007, total=   3.3s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:  1.0min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt
# [CV]  reg_lambda=1.4, reg_alpha=1, objective=binary, num_leaves=16, n_estimators=750, min_data_in_leaf=50, max_depth=None, learning_rate=0.005, boosting=gbdt, score=0.000, total=   3.2s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  1.1min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:  1.1min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:  1.1min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:  1.1min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:  1.1min remaining:    0.0s
# [CV] reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt
# [CV]  reg_lambda=1.2, reg_alpha=1.2, objective=binary, num_leaves=16, n_estimators=250, min_data_in_leaf=500, max_depth=20, learning_rate=0.01, boosting=gbdt, score=0.000, total=   0.7s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  1.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart, score=0.000, total=   2.4s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:  1.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart, score=0.000, total=   2.4s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:  1.2min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart, score=0.000, total=   2.5s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:  1.3min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart, score=0.000, total=   2.4s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:  1.3min remaining:    0.0s
# [CV] reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart
# [CV]  reg_lambda=1.4, reg_alpha=1.2, objective=binary, num_leaves=128, n_estimators=500, min_data_in_leaf=500, max_depth=10, learning_rate=0.005, boosting=dart, score=0.000, total=   2.3s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.4min finished
# Grid-Search with F2-score
# Best parameters: {'reg_lambda': 1.4, 'reg_alpha': 1.4, 'objective': 'binary', 'num_leaves': 64, 'n_estimators': 500, 'min_data_in_leaf': 100, 'max_depth': None, 'learning_rate': 0.01, 'boosting': 'gbdt'}
# Best cross-validation score (F2-score)): 0.014

# %%
# Optimisation du seuil en application la fonction au modèle optimisé à l'étape précédente

clf_lgbc = lgb.LGBMClassifier(random_state=2, 
                              objective = 'binary', 
                              num_leaves = 64, 
                              n_estimators = 500, 
                              min_data_in_leaf = 100, 
                              max_depth = None, 
                              learning_rate = 0.01, 
                              boosting = 'gbdt',
                              reg_alpha = 1.4,
                              reg_lambda = 1.4)

y_proba = cv_score(clf_lgbc,Xtrain, ytrain, cv = 5, beta = 2, resampling = smote)[1]

threshold_selection(y_proba, ytrain)
# Out:
# Best Threshold : 0.08
# Best Score : 0.373

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(clf_lgbc, Xsmot, ysmot, Xtest, ytest, thresh = 0.08)

print("Recall = ", round(recall_score(ytest, clf_lgbc.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, clf_lgbc.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, clf_lgbc.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.08 : 0.402
# Recall =  0.01
# Precision =  0.31
# AUC score =  0.73

# %% [markdown]
# Le score est moins bon que le précédent avec cette méthode mais reste correct. A noter toutefois que le recall est proche de zéro, au profit d'une précision de 31%.

# %%
scores_log.loc["Smote","LGBM"] = 0.402

# %% [markdown]
# <a id="section6.3"> </a>
# # 6.3 Rebalancing par undersampling de la classe majoritaire

# %%
# Optimisation du seuil en application la fonction au modèle optimisé après recherche sur grille

y_proba_unders = cv_score(clf_lgbc, Xtrain, ytrain, cv = 5, beta = 2, resampling = under_sampler)[1]

threshold_selection(y_proba_unders, ytrain)
# Out:
# Best Threshold : 0.38
# Best Score : 0.338

# %%
# Prévisions sur jeu de données test en utilisant modèle optimisé précédemment

make_pred(clf_lgbc, x_resamp, y_resamp, Xtest, ytest, thresh = 0.38)

print("Recall = ", round(recall_score(ytest, clf_lgbc.predict(Xtest)),2))
print("Precision = ", round(precision_score(ytest, clf_lgbc.predict(Xtest)),2))
print("AUC score = ", round(roc_auc_score(ytest, clf_lgbc.predict_proba(Xtest)[:, 1]),2))
# Out:
# Score sur le jeu de données Test avec seuil de 0.38 : 0.348
# Recall =  0.67
# Precision =  0.11
# AUC score =  0.66

# %% [markdown]
# Le score est encore moins bon même si le recall est l'un des meilleurs. Les erreurs de type II sont à 18%.

# %%
scores_log.loc["Under_Sampling", "LGBM"] = 0.348

# %% [markdown]
# <a id="section7"> </a>
# # 7. Analyse des résultats

# %%
scores_log
# Out:
#                 Logistic Regression Random Forest   LGBM
# Paramètre_Class               0.407         0.409  0.412
# Smote                           0.4         0.364  0.402
# Under_Sampling                0.324         0.333  0.348

# %%
ax = scores_log.plot.bar()
plt.setp(ax.get_xticklabels(), rotation=30, ha="right",rotation_mode="anchor");
plt.ylim(0, 0.45);
plt.text(1.5, 0.39, ('best score = {}'.format(scores_log.max().max())), color='b')
plt.axhline(scores_log.max().max(), ls='--', lw=2, c='b');
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');
plt.title('Scores performed on Evaluation set');

# %% [markdown]
# On remarque que dans les 3 cas, l'utilisation du paramètre class = weighted des classifiers produit les meilleurs scores.
#
# A noter que dans le cadre de la Logistic Regression et dans une moindre mesure, pour le LGBM, la strategie de rebalancing par Smote donne aussi des résultats acceptables.
#
# Enfin, le modèle ayant le meilleur score est le LGBM avec un score de 0.412. Ce modèle a obtenu le recall le plus élevé à 66% avec des erreurs de Type I de 34% et des erreurs de Type II de 29%
#
# Pour rappel, la score de la baseline est de 0.3

# %% [markdown]
# <a id="section8"> </a>
# # 8. Interprétabilité du modèle

# %% [markdown]
# Pour interpréter les résultats des modèles, je vais retenir pour chacun des classifiers celui dont le score est le plus élevé, puis utiliser les deux méthodes suivantes:
# - l'étude de l'importance des features principaux (top 10)
# - la méthode SHAP basée sur les shapley values

# %% [markdown]
# <a id="section8.1"> </a>
# ## 8.1 Analyse globale du modèle: importance des variables

# %%
# Calcul des 10 Features les plus importants pour chaque modèle

lgbc_bal.fit(Xtrain, ytrain)
clf_rf_bal.fit(Xtrain, ytrain)
clf_reg_bal.fit(Xtrain,ytrain)

# Pour le modèle LGBC avec balancing de classe minoritaire par le modèle
lgb_feat_imp = pd.DataFrame((lgbc_bal.feature_importances_ / sum(lgbc_bal.feature_importances_))*100, index=X.columns, columns=['Light GBM'])

# Pour le modèle Random Forrest avec balancing de classe minoritaire par le modèle
rf_feat_imp = pd.DataFrame((clf_rf_bal.feature_importances_ / sum(clf_rf_bal.feature_importances_))*100, index=X.columns, columns=['Random Forest'])

# Pour le modèle Logistic Regression avec balancing de classe minoritaire par le modèle
feature_importance = (abs(clf_reg_bal.coef_[0])/ (sum(abs(clf_reg_bal.coef_[0]))))*100
sorted_idx = np.argsort(feature_importance)[len(feature_importance) - 10:len(feature_importance)]
pos = np.arange(sorted_idx.shape[0]) + .5

# %%
# Représentation graphique de ces features les plus importants pour les 3 modèles

fig, ax = plt.subplots(3, 1, figsize=(10,10) )

ax[0].barh(np.array(X.columns)[sorted_idx], feature_importance[sorted_idx], align='center', color='dodgerblue')
rf_feat_imp.sort_values('Random Forest')[-10::].plot.barh(ax=ax[1], color = 'limegreen', legend= None)
lgb_feat_imp.sort_values('Light GBM')[-10::].plot.barh(ax=ax[2], color='gold', legend=None)

ax[0].set_title('Logistic Regression')
ax[1].set_title('Random Forrest')
ax[2].set_title('Light GBM')

fig.subplots_adjust(wspace=0.5);

# %% [markdown]
# **Plusieurs commentaires suite à ces résultats:**
#
# - on remarque que pour les 3 modèles, les scores attribués par des organismes externes ont le plus d'impact sur les prédictions (le plus frappant étant pour le Random Forrest)
# - l'âge est aussi un facteur important
# - le feature LTV (rapport entre le prêt et la valeur du bien financé) est aussi un feature important commun aux 3 modèles
# - La Logistic Regression, contrairement aux 2 autres modèles, est fortement influencée par le type de société dans laquelle le client travaille
# - Enfin il est assez surprenant de voir que le nombre de jours depuis le dernier changement de téléphone soit un feature relativement important pour ces 2 modèles
#
#
# Toutefois, cette analyse ne permet pas de voir comment un feature donné contribue en terme de prédiction de défaut. Pour cela nous passons à la méthode d'analyse suivante.

# %%
# Sauvegarde du modèle ayant eu le meilleur score pour utilisation dans le Dashboard

with open('model.pickle', 'wb') as file :
    pickle.dump(lgbc_bal, file)

# %% [markdown]
# <a id="section8.2"> </a>
# ## 8.2 Analyse locale du modèle: SHAP

# %% [markdown]
# SHAP (SHapley Additive exPlanations) est une approche provenant de la théorie des jeux et basée sur les valeurs de Shapley.
#
# L’idée proposée par les auteurs de cette méthode est de calculer la valeur de Shapley pour toutes les variables à chaque exemple du dataset. Cette approche explique la sortie d’un modèle par la somme des effets de chaque variable Xi. L’idée est de moyenner l’impact qu’une variable a pour toutes les combinaisons de variables possibles.

# %% [markdown]
# ### Préparation du modèle

# %%
# Import du module SHAP, initialisation et import du modèle

import shap
shap.initjs()

with open('model.pickle', 'rb') as file : 
    LGB = pickle.load(file)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# TreeExplainer, optimisé pour les arbres de décision et ensembles d’arbres, permet de réduire la complexité du modèle SHAP

# %%
explainer = shap.TreeExplainer(LGB, 
                               model_output = 'probability',
                               data = Xtrain.sample(200),
                               feature_dependence='independent')

shap_values = explainer.shap_values(Xtest, ytest)
# Out:
#  99%|===================| 3729/3750 [01:16<00:00]

# %% [markdown]
# ### Summary Plot

# %% [markdown]
# Le Summary Plot est un graph dans lequel les valeurs de Shap sont représentées pour chaque variable dans leur ordre d’importance, chaque point représente une valeur de Shap (pour un exemple), les points rouges représentent des valeurs élevées de la variable et les points bleus des valeurs basses de la variable.
#
# A noter que ce type de représentation permet de voir la densité des différentes valeurs prises pour chaque variable.
#
# Cette méthode confirme globalement l'ordre d'importance des features obtenu précédemment mais information supplémentaire, il permet de voir l'impact de chaque variable sur une prédiction.
#
# Par exemple, on peut voir que plus un score fourni par l'agence de notation 3 est élevée, et plus la valeur de la prédiction sera faible (valeur Shap négative) et donc le client sera en capacité de rembourser son prêt.
#
# Au contraire, plus le montant de l'Annuité est élevé et plus la valeur de la prédiction sera importante, traduisant un client potentiellement en défaut.
#
# Il est aussi intéressant de noter que le modèle indique que le genre du client influence la prédiction et que selon le jeu de données (mais qu'il convient de ne pas généraliser), un code gender élevé (donc de sexe masculin) influencera la prédiction en faveur d'un défaut.
#
# Enfin, pour revenir au cas de la variable "nombre de jours depuis le dernier changement de téléphone" dont les valeurs sont positives, on remarque qu'un client qui a changé récemment de numéro de téléphone a plus de chance de faire défaut. Cela est logique puisqu'un client ayant changé récemment de téléphone est soit un client jeune et donc avec un pouvoir d'achat moindre, soit une personne changeant fréquemment et donc potientiellement moins stable dans ses dépenses.

# %%
shap.summary_plot(shap_values, Xtest)

# %% [markdown]
# ### Force Plot

# %% [markdown]
# Les diagrammes de type Force Plot ont un intérêt supplémentaire car ils permettent pour chaque prédiction de voir la contribution et l'impact des différents features.
#
# Les features qui apparaissent en rouge sont ceux qui feront augmenter la prédiction (à savoir ici la probabilité de défaut) et inversement, les features en bleu feront baisser la valeur de prédiction et contribueront donc à indiquer un client qui rembourse son prêt.

# %%
# Je commence par définir une fonction qui va représenter le diagramme force_plot ainsi que la classe réelle 
# du client, et les probabilités d'appartenance à chacune des classes

def shap_plot(i):
    print(LGB.predict_proba(Xtest.iloc[i:i+1]).round(2))
    print('True class :', ytest.iloc[i])
    return(shap.force_plot(explainer.expected_value, shap_values[i], Xtest.iloc[i]))

# %%
# Voyons pour un client une première représentation

shap_plot(3)
# Out:
# [[0.78 0.22]]
# True class : 0.0
# <div id='iGXRSB4F90ET7URIV1TVM'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.37952599573914747, "outValue": 0.22118936500744638, "link": "identity", "featureNames": ["NAME_CONTRACT_TYPE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "CNT_CHILDREN", "AMT_INCOME_TOTAL", "AMT_ANNUITY", "AMT_GOODS_PRICE", "REGION_POPULATION_RELATIVE", "DAYS_BIRTH", "DAYS_REGISTRATION", "DAYS_ID_PUBLISH", "OWN_CAR_AGE", "FLAG_MOBIL", "FLAG_EMP_PHONE", "FLAG_WORK_PHONE", "FLAG_CONT_MOBILE", "FLAG_PHONE", "FLAG_EMAIL", "CNT_FAM_MEMBERS", "REGION_RATING_CLIENT_W_CITY", "HOUR_APPR_PROCESS_START", "REG_REGION_NOT_LIVE_REGION", "REG_REGION_NOT_WORK_REGION", "LIVE_REGION_NOT_WORK_REGION", "REG_CITY_NOT_LIVE_CITY", "REG_CITY_NOT_WORK_CITY", "LIVE_CITY_NOT_WORK_CITY", "EXT_SOURCE_1", "EXT_SOURCE_2", "EXT_SOURCE_3", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "DAYS_LAST_PHONE_CHANGE", "FLAG_DOCUMENT_2", "FLAG_DOCUMENT_3", "FLAG_DOCUMENT_4", "FLAG_DOCUMENT_5", "FLAG_DOCUMENT_6", "FLAG_DOCUMENT_7", "FLAG_DOCUMENT_8", "FLAG_DOCUMENT_9", "FLAG_DOCUMENT_10", "FLAG_DOCUMENT_11", "FLAG_DOCUMENT_12", "FLAG_DOCUMENT_13", "FLAG_DOCUMENT_14", "FLAG_DOCUMENT_15", "FLAG_DOCUMENT_16", "FLAG_DOCUMENT_17", "FLAG_DOCUMENT_18", "FLAG_DOCUMENT_19", "FLAG_DOCUMENT_20", "FLAG_DOCUMENT_21", "AMT_REQ_CREDIT_BUREAU_HOUR", "AMT_REQ_CREDIT_BUREAU_DAY", "AMT_REQ_CREDIT_BUREAU_WEEK", "AMT_REQ_CREDIT_BUREAU_MON", "AMT_REQ_CREDIT_BUREAU_QRT", "AMT_REQ_CREDIT_BUREAU_YEAR", "train_test", "Living_info_prct", "ratio_credit_income", "ratio_income_annuity", "TENOR", "Life_employed", "LTV", "NAME_TYPE_SUITE_Children", "NAME_TYPE_SUITE_Family", "NAME_TYPE_SUITE_Groupofpeople", "NAME_TYPE_SUITE_Other_A", "NAME_TYPE_SUITE_Other_B", "NAME_TYPE_SUITE_Spousepartner", "NAME_TYPE_SUITE_Unaccompanied", "NAME_INCOME_TYPE_Businessman", "NAME_INCOME_TYPE_Commercialassociate", "NAME_INCOME_TYPE_Maternityleave", "NAME_INCOME_TYPE_Pensioner", "NAME_INCOME_TYPE_Stateservant", "NAME_INCOME_TYPE_Student", "NAME_INCOME_TYPE_Unemployed", "NAME_INCOME_TYPE_Working", "NAME_EDUCATION_TYPE_Academicdegree", "NAME_EDUCATION_TYPE_Highereducation", "NAME_EDUCATION_TYPE_Incompletehigher", "NAME_EDUCATION_TYPE_Lowersecondary", "NAME_EDUCATION_TYPE_Secondarysecondaryspecial", "NAME_FAMILY_STATUS_Civilmarriage", "NAME_FAMILY_STATUS_Married", "NAME_FAMILY_STATUS_Separated", "NAME_FAMILY_STATUS_Singlenotmarried", "NAME_FAMILY_STATUS_Unknown", "NAME_FAMILY_STATUS_Widow", "NAME_HOUSING_TYPE_Coopapartment", "NAME_HOUSING_TYPE_Houseapartment", "NAME_HOUSING_TYPE_Municipalapartment", "NAME_HOUSING_TYPE_Officeapartment", "NAME_HOUSING_TYPE_Rentedapartment", "NAME_HOUSING_TYPE_Withparents", "OCCUPATION_TYPE_Accountants", "OCCUPATION_TYPE_Cleaningstaff", "OCCUPATION_TYPE_Cookingstaff", "OCCUPATION_TYPE_Corestaff", "OCCUPATION_TYPE_Drivers", "OCCUPATION_TYPE_HRstaff", "OCCUPATION_TYPE_Highskilltechstaff", "OCCUPATION_TYPE_ITstaff", "OCCUPATION_TYPE_Laborers", "OCCUPATION_TYPE_LowskillLaborers", "OCCUPATION_TYPE_Managers", "OCCUPATION_TYPE_Medicinestaff", "OCCUPATION_TYPE_Privateservicestaff", "OCCUPATION_TYPE_Realtyagents", "OCCUPATION_TYPE_Salesstaff", "OCCUPATION_TYPE_Secretaries", "OCCUPATION_TYPE_Securitystaff", "OCCUPATION_TYPE_Waitersbarmenstaff", "WEEKDAY_APPR_PROCESS_START_FRIDAY", "WEEKDAY_APPR_PROCESS_START_MONDAY", "WEEKDAY_APPR_PROCESS_START_SATURDAY", "WEEKDAY_APPR_PROCESS_START_SUNDAY", "WEEKDAY_APPR_PROCESS_START_THURSDAY", "WEEKDAY_APPR_PROCESS_START_TUESDAY", "WEEKDAY_APPR_PROCESS_START_WEDNESDAY", "ORGANIZATION_TYPE_Advertising", "ORGANIZATION_TYPE_Agriculture", "ORGANIZATION_TYPE_Bank", "ORGANIZATION_TYPE_BusinessEntityType1", "ORGANIZATION_TYPE_BusinessEntityType2", "ORGANIZATION_TYPE_BusinessEntityType3", "ORGANIZATION_TYPE_Cleaning", "ORGANIZATION_TYPE_Construction", "ORGANIZATION_TYPE_Culture", "ORGANIZATION_TYPE_Electricity", "ORGANIZATION_TYPE_Emergency", "ORGANIZATION_TYPE_Government", "ORGANIZATION_TYPE_Hotel", "ORGANIZATION_TYPE_Housing", "ORGAN ...

# %% [markdown]
# Ici nous pouvons voir que la prédiction est correcte (individu qui rembourse son prêt).
#
# On remarque immédiatement que les bons scores obtenus auprès des organismes de notation contribuent fortement à une prédiction en faveur d'un remboursement (ce sont les 3 blocs principaux par la taille).

# %%
# Observation pour un second client

shap_plot(1375)
# Out:
# [[0.73 0.27]]
# True class : 0.0
# <div id='iWBQGIOQ3GF1CJYT1IBA2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.37952599573914747, "outValue": 0.26501491151968504, "link": "identity", "featureNames": ["NAME_CONTRACT_TYPE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "CNT_CHILDREN", "AMT_INCOME_TOTAL", "AMT_ANNUITY", "AMT_GOODS_PRICE", "REGION_POPULATION_RELATIVE", "DAYS_BIRTH", "DAYS_REGISTRATION", "DAYS_ID_PUBLISH", "OWN_CAR_AGE", "FLAG_MOBIL", "FLAG_EMP_PHONE", "FLAG_WORK_PHONE", "FLAG_CONT_MOBILE", "FLAG_PHONE", "FLAG_EMAIL", "CNT_FAM_MEMBERS", "REGION_RATING_CLIENT_W_CITY", "HOUR_APPR_PROCESS_START", "REG_REGION_NOT_LIVE_REGION", "REG_REGION_NOT_WORK_REGION", "LIVE_REGION_NOT_WORK_REGION", "REG_CITY_NOT_LIVE_CITY", "REG_CITY_NOT_WORK_CITY", "LIVE_CITY_NOT_WORK_CITY", "EXT_SOURCE_1", "EXT_SOURCE_2", "EXT_SOURCE_3", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "DAYS_LAST_PHONE_CHANGE", "FLAG_DOCUMENT_2", "FLAG_DOCUMENT_3", "FLAG_DOCUMENT_4", "FLAG_DOCUMENT_5", "FLAG_DOCUMENT_6", "FLAG_DOCUMENT_7", "FLAG_DOCUMENT_8", "FLAG_DOCUMENT_9", "FLAG_DOCUMENT_10", "FLAG_DOCUMENT_11", "FLAG_DOCUMENT_12", "FLAG_DOCUMENT_13", "FLAG_DOCUMENT_14", "FLAG_DOCUMENT_15", "FLAG_DOCUMENT_16", "FLAG_DOCUMENT_17", "FLAG_DOCUMENT_18", "FLAG_DOCUMENT_19", "FLAG_DOCUMENT_20", "FLAG_DOCUMENT_21", "AMT_REQ_CREDIT_BUREAU_HOUR", "AMT_REQ_CREDIT_BUREAU_DAY", "AMT_REQ_CREDIT_BUREAU_WEEK", "AMT_REQ_CREDIT_BUREAU_MON", "AMT_REQ_CREDIT_BUREAU_QRT", "AMT_REQ_CREDIT_BUREAU_YEAR", "train_test", "Living_info_prct", "ratio_credit_income", "ratio_income_annuity", "TENOR", "Life_employed", "LTV", "NAME_TYPE_SUITE_Children", "NAME_TYPE_SUITE_Family", "NAME_TYPE_SUITE_Groupofpeople", "NAME_TYPE_SUITE_Other_A", "NAME_TYPE_SUITE_Other_B", "NAME_TYPE_SUITE_Spousepartner", "NAME_TYPE_SUITE_Unaccompanied", "NAME_INCOME_TYPE_Businessman", "NAME_INCOME_TYPE_Commercialassociate", "NAME_INCOME_TYPE_Maternityleave", "NAME_INCOME_TYPE_Pensioner", "NAME_INCOME_TYPE_Stateservant", "NAME_INCOME_TYPE_Student", "NAME_INCOME_TYPE_Unemployed", "NAME_INCOME_TYPE_Working", "NAME_EDUCATION_TYPE_Academicdegree", "NAME_EDUCATION_TYPE_Highereducation", "NAME_EDUCATION_TYPE_Incompletehigher", "NAME_EDUCATION_TYPE_Lowersecondary", "NAME_EDUCATION_TYPE_Secondarysecondaryspecial", "NAME_FAMILY_STATUS_Civilmarriage", "NAME_FAMILY_STATUS_Married", "NAME_FAMILY_STATUS_Separated", "NAME_FAMILY_STATUS_Singlenotmarried", "NAME_FAMILY_STATUS_Unknown", "NAME_FAMILY_STATUS_Widow", "NAME_HOUSING_TYPE_Coopapartment", "NAME_HOUSING_TYPE_Houseapartment", "NAME_HOUSING_TYPE_Municipalapartment", "NAME_HOUSING_TYPE_Officeapartment", "NAME_HOUSING_TYPE_Rentedapartment", "NAME_HOUSING_TYPE_Withparents", "OCCUPATION_TYPE_Accountants", "OCCUPATION_TYPE_Cleaningstaff", "OCCUPATION_TYPE_Cookingstaff", "OCCUPATION_TYPE_Corestaff", "OCCUPATION_TYPE_Drivers", "OCCUPATION_TYPE_HRstaff", "OCCUPATION_TYPE_Highskilltechstaff", "OCCUPATION_TYPE_ITstaff", "OCCUPATION_TYPE_Laborers", "OCCUPATION_TYPE_LowskillLaborers", "OCCUPATION_TYPE_Managers", "OCCUPATION_TYPE_Medicinestaff", "OCCUPATION_TYPE_Privateservicestaff", "OCCUPATION_TYPE_Realtyagents", "OCCUPATION_TYPE_Salesstaff", "OCCUPATION_TYPE_Secretaries", "OCCUPATION_TYPE_Securitystaff", "OCCUPATION_TYPE_Waitersbarmenstaff", "WEEKDAY_APPR_PROCESS_START_FRIDAY", "WEEKDAY_APPR_PROCESS_START_MONDAY", "WEEKDAY_APPR_PROCESS_START_SATURDAY", "WEEKDAY_APPR_PROCESS_START_SUNDAY", "WEEKDAY_APPR_PROCESS_START_THURSDAY", "WEEKDAY_APPR_PROCESS_START_TUESDAY", "WEEKDAY_APPR_PROCESS_START_WEDNESDAY", "ORGANIZATION_TYPE_Advertising", "ORGANIZATION_TYPE_Agriculture", "ORGANIZATION_TYPE_Bank", "ORGANIZATION_TYPE_BusinessEntityType1", "ORGANIZATION_TYPE_BusinessEntityType2", "ORGANIZATION_TYPE_BusinessEntityType3", "ORGANIZATION_TYPE_Cleaning", "ORGANIZATION_TYPE_Construction", "ORGANIZATION_TYPE_Culture", "ORGANIZATION_TYPE_Electricity", "ORGANIZATION_TYPE_Emergency", "ORGANIZATION_TYPE_Government", "ORGANIZATION_TYPE_Hotel", "ORGANIZATION_TYPE_Housing", "ORGAN ...

# %% [markdown]
# A nouveau une prédiction correcte pour un individu qui rembourse son prêt.
#
# Le score donné par l'organismes 3 contribue à cette prédiction ainsi que la valeur de LTV , alors que le score fourni par l'organisme 2 vient relever la valeur de la probabilité de défaut.

# %%
# Observation pour un troisième client

shap_plot(475)
# Out:
# [[0.32 0.68]]
# True class : 1.0
# <div id='iVNDBZN6ZTVTBC8WKMLPZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.37952599573914747, "outValue": 0.6833758066779434, "link": "identity", "featureNames": ["NAME_CONTRACT_TYPE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "CNT_CHILDREN", "AMT_INCOME_TOTAL", "AMT_ANNUITY", "AMT_GOODS_PRICE", "REGION_POPULATION_RELATIVE", "DAYS_BIRTH", "DAYS_REGISTRATION", "DAYS_ID_PUBLISH", "OWN_CAR_AGE", "FLAG_MOBIL", "FLAG_EMP_PHONE", "FLAG_WORK_PHONE", "FLAG_CONT_MOBILE", "FLAG_PHONE", "FLAG_EMAIL", "CNT_FAM_MEMBERS", "REGION_RATING_CLIENT_W_CITY", "HOUR_APPR_PROCESS_START", "REG_REGION_NOT_LIVE_REGION", "REG_REGION_NOT_WORK_REGION", "LIVE_REGION_NOT_WORK_REGION", "REG_CITY_NOT_LIVE_CITY", "REG_CITY_NOT_WORK_CITY", "LIVE_CITY_NOT_WORK_CITY", "EXT_SOURCE_1", "EXT_SOURCE_2", "EXT_SOURCE_3", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "DAYS_LAST_PHONE_CHANGE", "FLAG_DOCUMENT_2", "FLAG_DOCUMENT_3", "FLAG_DOCUMENT_4", "FLAG_DOCUMENT_5", "FLAG_DOCUMENT_6", "FLAG_DOCUMENT_7", "FLAG_DOCUMENT_8", "FLAG_DOCUMENT_9", "FLAG_DOCUMENT_10", "FLAG_DOCUMENT_11", "FLAG_DOCUMENT_12", "FLAG_DOCUMENT_13", "FLAG_DOCUMENT_14", "FLAG_DOCUMENT_15", "FLAG_DOCUMENT_16", "FLAG_DOCUMENT_17", "FLAG_DOCUMENT_18", "FLAG_DOCUMENT_19", "FLAG_DOCUMENT_20", "FLAG_DOCUMENT_21", "AMT_REQ_CREDIT_BUREAU_HOUR", "AMT_REQ_CREDIT_BUREAU_DAY", "AMT_REQ_CREDIT_BUREAU_WEEK", "AMT_REQ_CREDIT_BUREAU_MON", "AMT_REQ_CREDIT_BUREAU_QRT", "AMT_REQ_CREDIT_BUREAU_YEAR", "train_test", "Living_info_prct", "ratio_credit_income", "ratio_income_annuity", "TENOR", "Life_employed", "LTV", "NAME_TYPE_SUITE_Children", "NAME_TYPE_SUITE_Family", "NAME_TYPE_SUITE_Groupofpeople", "NAME_TYPE_SUITE_Other_A", "NAME_TYPE_SUITE_Other_B", "NAME_TYPE_SUITE_Spousepartner", "NAME_TYPE_SUITE_Unaccompanied", "NAME_INCOME_TYPE_Businessman", "NAME_INCOME_TYPE_Commercialassociate", "NAME_INCOME_TYPE_Maternityleave", "NAME_INCOME_TYPE_Pensioner", "NAME_INCOME_TYPE_Stateservant", "NAME_INCOME_TYPE_Student", "NAME_INCOME_TYPE_Unemployed", "NAME_INCOME_TYPE_Working", "NAME_EDUCATION_TYPE_Academicdegree", "NAME_EDUCATION_TYPE_Highereducation", "NAME_EDUCATION_TYPE_Incompletehigher", "NAME_EDUCATION_TYPE_Lowersecondary", "NAME_EDUCATION_TYPE_Secondarysecondaryspecial", "NAME_FAMILY_STATUS_Civilmarriage", "NAME_FAMILY_STATUS_Married", "NAME_FAMILY_STATUS_Separated", "NAME_FAMILY_STATUS_Singlenotmarried", "NAME_FAMILY_STATUS_Unknown", "NAME_FAMILY_STATUS_Widow", "NAME_HOUSING_TYPE_Coopapartment", "NAME_HOUSING_TYPE_Houseapartment", "NAME_HOUSING_TYPE_Municipalapartment", "NAME_HOUSING_TYPE_Officeapartment", "NAME_HOUSING_TYPE_Rentedapartment", "NAME_HOUSING_TYPE_Withparents", "OCCUPATION_TYPE_Accountants", "OCCUPATION_TYPE_Cleaningstaff", "OCCUPATION_TYPE_Cookingstaff", "OCCUPATION_TYPE_Corestaff", "OCCUPATION_TYPE_Drivers", "OCCUPATION_TYPE_HRstaff", "OCCUPATION_TYPE_Highskilltechstaff", "OCCUPATION_TYPE_ITstaff", "OCCUPATION_TYPE_Laborers", "OCCUPATION_TYPE_LowskillLaborers", "OCCUPATION_TYPE_Managers", "OCCUPATION_TYPE_Medicinestaff", "OCCUPATION_TYPE_Privateservicestaff", "OCCUPATION_TYPE_Realtyagents", "OCCUPATION_TYPE_Salesstaff", "OCCUPATION_TYPE_Secretaries", "OCCUPATION_TYPE_Securitystaff", "OCCUPATION_TYPE_Waitersbarmenstaff", "WEEKDAY_APPR_PROCESS_START_FRIDAY", "WEEKDAY_APPR_PROCESS_START_MONDAY", "WEEKDAY_APPR_PROCESS_START_SATURDAY", "WEEKDAY_APPR_PROCESS_START_SUNDAY", "WEEKDAY_APPR_PROCESS_START_THURSDAY", "WEEKDAY_APPR_PROCESS_START_TUESDAY", "WEEKDAY_APPR_PROCESS_START_WEDNESDAY", "ORGANIZATION_TYPE_Advertising", "ORGANIZATION_TYPE_Agriculture", "ORGANIZATION_TYPE_Bank", "ORGANIZATION_TYPE_BusinessEntityType1", "ORGANIZATION_TYPE_BusinessEntityType2", "ORGANIZATION_TYPE_BusinessEntityType3", "ORGANIZATION_TYPE_Cleaning", "ORGANIZATION_TYPE_Construction", "ORGANIZATION_TYPE_Culture", "ORGANIZATION_TYPE_Electricity", "ORGANIZATION_TYPE_Emergency", "ORGANIZATION_TYPE_Government", "ORGANIZATION_TYPE_Hotel", "ORGANIZATION_TYPE_Housing", "ORGANI ...

# %% [markdown]
# Nous voyons cette fois un client dont la prédiction est un défaut. Cela est essentiellement dû au faible score donné par les organismes 2 (surtout) et 3, ainsi que par le fait que le client soit de genre masculin.

# %%
# Dernier exemple

shap_plot(2001)
# Out:
# [[0.68 0.32]]
# True class : 1.0
# <div id='iR7OPXOL5CSHRO1DA7DWF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.37952599573914747, "outValue": 0.3198929488558157, "link": "identity", "featureNames": ["NAME_CONTRACT_TYPE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "CNT_CHILDREN", "AMT_INCOME_TOTAL", "AMT_ANNUITY", "AMT_GOODS_PRICE", "REGION_POPULATION_RELATIVE", "DAYS_BIRTH", "DAYS_REGISTRATION", "DAYS_ID_PUBLISH", "OWN_CAR_AGE", "FLAG_MOBIL", "FLAG_EMP_PHONE", "FLAG_WORK_PHONE", "FLAG_CONT_MOBILE", "FLAG_PHONE", "FLAG_EMAIL", "CNT_FAM_MEMBERS", "REGION_RATING_CLIENT_W_CITY", "HOUR_APPR_PROCESS_START", "REG_REGION_NOT_LIVE_REGION", "REG_REGION_NOT_WORK_REGION", "LIVE_REGION_NOT_WORK_REGION", "REG_CITY_NOT_LIVE_CITY", "REG_CITY_NOT_WORK_CITY", "LIVE_CITY_NOT_WORK_CITY", "EXT_SOURCE_1", "EXT_SOURCE_2", "EXT_SOURCE_3", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "DAYS_LAST_PHONE_CHANGE", "FLAG_DOCUMENT_2", "FLAG_DOCUMENT_3", "FLAG_DOCUMENT_4", "FLAG_DOCUMENT_5", "FLAG_DOCUMENT_6", "FLAG_DOCUMENT_7", "FLAG_DOCUMENT_8", "FLAG_DOCUMENT_9", "FLAG_DOCUMENT_10", "FLAG_DOCUMENT_11", "FLAG_DOCUMENT_12", "FLAG_DOCUMENT_13", "FLAG_DOCUMENT_14", "FLAG_DOCUMENT_15", "FLAG_DOCUMENT_16", "FLAG_DOCUMENT_17", "FLAG_DOCUMENT_18", "FLAG_DOCUMENT_19", "FLAG_DOCUMENT_20", "FLAG_DOCUMENT_21", "AMT_REQ_CREDIT_BUREAU_HOUR", "AMT_REQ_CREDIT_BUREAU_DAY", "AMT_REQ_CREDIT_BUREAU_WEEK", "AMT_REQ_CREDIT_BUREAU_MON", "AMT_REQ_CREDIT_BUREAU_QRT", "AMT_REQ_CREDIT_BUREAU_YEAR", "train_test", "Living_info_prct", "ratio_credit_income", "ratio_income_annuity", "TENOR", "Life_employed", "LTV", "NAME_TYPE_SUITE_Children", "NAME_TYPE_SUITE_Family", "NAME_TYPE_SUITE_Groupofpeople", "NAME_TYPE_SUITE_Other_A", "NAME_TYPE_SUITE_Other_B", "NAME_TYPE_SUITE_Spousepartner", "NAME_TYPE_SUITE_Unaccompanied", "NAME_INCOME_TYPE_Businessman", "NAME_INCOME_TYPE_Commercialassociate", "NAME_INCOME_TYPE_Maternityleave", "NAME_INCOME_TYPE_Pensioner", "NAME_INCOME_TYPE_Stateservant", "NAME_INCOME_TYPE_Student", "NAME_INCOME_TYPE_Unemployed", "NAME_INCOME_TYPE_Working", "NAME_EDUCATION_TYPE_Academicdegree", "NAME_EDUCATION_TYPE_Highereducation", "NAME_EDUCATION_TYPE_Incompletehigher", "NAME_EDUCATION_TYPE_Lowersecondary", "NAME_EDUCATION_TYPE_Secondarysecondaryspecial", "NAME_FAMILY_STATUS_Civilmarriage", "NAME_FAMILY_STATUS_Married", "NAME_FAMILY_STATUS_Separated", "NAME_FAMILY_STATUS_Singlenotmarried", "NAME_FAMILY_STATUS_Unknown", "NAME_FAMILY_STATUS_Widow", "NAME_HOUSING_TYPE_Coopapartment", "NAME_HOUSING_TYPE_Houseapartment", "NAME_HOUSING_TYPE_Municipalapartment", "NAME_HOUSING_TYPE_Officeapartment", "NAME_HOUSING_TYPE_Rentedapartment", "NAME_HOUSING_TYPE_Withparents", "OCCUPATION_TYPE_Accountants", "OCCUPATION_TYPE_Cleaningstaff", "OCCUPATION_TYPE_Cookingstaff", "OCCUPATION_TYPE_Corestaff", "OCCUPATION_TYPE_Drivers", "OCCUPATION_TYPE_HRstaff", "OCCUPATION_TYPE_Highskilltechstaff", "OCCUPATION_TYPE_ITstaff", "OCCUPATION_TYPE_Laborers", "OCCUPATION_TYPE_LowskillLaborers", "OCCUPATION_TYPE_Managers", "OCCUPATION_TYPE_Medicinestaff", "OCCUPATION_TYPE_Privateservicestaff", "OCCUPATION_TYPE_Realtyagents", "OCCUPATION_TYPE_Salesstaff", "OCCUPATION_TYPE_Secretaries", "OCCUPATION_TYPE_Securitystaff", "OCCUPATION_TYPE_Waitersbarmenstaff", "WEEKDAY_APPR_PROCESS_START_FRIDAY", "WEEKDAY_APPR_PROCESS_START_MONDAY", "WEEKDAY_APPR_PROCESS_START_SATURDAY", "WEEKDAY_APPR_PROCESS_START_SUNDAY", "WEEKDAY_APPR_PROCESS_START_THURSDAY", "WEEKDAY_APPR_PROCESS_START_TUESDAY", "WEEKDAY_APPR_PROCESS_START_WEDNESDAY", "ORGANIZATION_TYPE_Advertising", "ORGANIZATION_TYPE_Agriculture", "ORGANIZATION_TYPE_Bank", "ORGANIZATION_TYPE_BusinessEntityType1", "ORGANIZATION_TYPE_BusinessEntityType2", "ORGANIZATION_TYPE_BusinessEntityType3", "ORGANIZATION_TYPE_Cleaning", "ORGANIZATION_TYPE_Construction", "ORGANIZATION_TYPE_Culture", "ORGANIZATION_TYPE_Electricity", "ORGANIZATION_TYPE_Emergency", "ORGANIZATION_TYPE_Government", "ORGANIZATION_TYPE_Hotel", "ORGANIZATION_TYPE_Housing", "ORGANI ...

# %% [markdown]
# Enfin il s'agit ici d'une prédiction incorrecte (Faux Positif). Le modèle se base essentiellement sur le score donné par l'organisme 3 et le montant de l'annuité, ce qui semble fausser la prédiction.
